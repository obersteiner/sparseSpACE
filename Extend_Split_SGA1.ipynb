# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sys import path
#path.append('../../../src/')
#path.append('../../../src/tools')
import numpy as np

#from numpy import *
import scipy as sp
from spatiallyAdaptiveExtendSplit import *
from spatiallyAdaptiveSplit import *
from spatiallyAdaptiveSingleDimension import *
from spatiallyAdaptiveCell import *
from GridOperation import *

from PerformTestCase import *
from Function import *
from ErrorCalculator import *
import math

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid = TrapezoidalGrid(a, b, dim)

f = FunctionGriebel()
reference_solution = f.getAnalyticSolutionIntegral(a,b)
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, version=0, no_initial_splitting=False, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, version=0, no_initial_splitting=False, automatic_extend_split=True, split_single_dim=False, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend,1,2, errorOperator, 'Extend scheme min=1 max=2 split=0'),(adaptiveCombiInstanceExtend2,1,2, errorOperator, 'Extend scheme min=1 max=2 split=0 Automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 2, dim, 9, grid, 1, 5)
print("#Points:", adaptiveCombiInstanceExtend.get_total_num_points())
print("#Points(single-dim. split):", adaptiveCombiInstanceExtend2.get_total_num_points())
# Out:
# Exact integral 1.0
# Reference solution: 1.0
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-fe955f26b77f> in <module>
#      14
#      15 algorithmArray = [(adaptiveCombiInstanceExtend,1,2, errorOperator, 'Extend scheme min=1 max=2 split=0')]#,(adaptiveCombiInstanceExtend2,1,2, errorOperator, 'Extend scheme min=1 max=2 split=0 Automatic Split')]
# ---> 16 performTestcaseArbitraryDim(f, a, b, algorithmArray, 2, dim, 9, grid, 1, 5)
#      17 print("#Points:", adaptiveCombiInstanceExtend.get_total_num_points())
#      18 #print("#Points(single-dim. split):", adaptiveCombiInstanceExtend2.get_total_num_points())
#
# ...

# %%
dim = 3
a = np.zeros(dim)
b = np.ones(dim)
grid = TrapezoidalGrid(a, b, dim)
f = FunctionGriebel()
reference_solution = f.getAnalyticSolutionIntegral(a,b)
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, version=0, no_initial_splitting=False, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, version=0, no_initial_splitting=False, automatic_extend_split=True, split_single_dim=False, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 split=0'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 3, dim, 9, grid, 1, 5)
print("#Points:", adaptiveCombiInstanceExtend.get_total_num_points())
print("#Points (single-dim. split):", adaptiveCombiInstanceExtend2.get_total_num_points())
# Out:
# Exact integral 0.9999999999999998
# Reference solution: 0.9999999999999998
# 0 [1, 1, 2] 1.0
# 1 [1, 2, 1] 1.0
# 2 [2, 1, 1] 1.0
# 3 [1, 1, 1] -2.0
# max surplus error: 0.003158892574627725 total surplus error: 0.20617199668414124
# combiintegral: 0.8236549544267637
# Current error: 0.17634504557323608
# Finished refinement
# Refined  2  times
# max surplus error: 0.0014698157888594437 total surplus error: 0.10449952570974122
# combiintegral: 0.858162198782599
# Current error: 0.14183780121740078
# New scheme
# 0 [1, 1, 3] 1.0
# 1 [1, 2, 2] 1.0
# 2 [1, 3, 1] 1.0
# 3 [2, 1, 2] 1.0
# 4 [2, 2, 1] 1.0
# 5 [3, 1, 1] 1.0
# 6 [1, 1, 2] -2.0
# 7 [1, 2, 1] -2.0
# 8 [2, 1, 1] -2.0
# 9 [1, 1, 1] 1.0
# Finished refinement
# Refined  1  times
# max surplus error: 0.00095416889133856 total surplus error: 0.08669599585772118
# combiintegral: 0.869754984707768
# Current error: 0.13024501529223179
# Finished refinement
# Refined  1  times
# ...

# %%
#New min
dim = 3
a = np.zeros(dim)
b = np.ones(dim)
grid = TrapezoidalGrid(a, b, dim)
f = FunctionGriebel()
reference_solution = f.getAnalyticSolutionIntegral(a,b)
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=False, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 split=0'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 3, dim, 9, grid, 1, 5)
print("#Points:", adaptiveCombiInstanceExtend.get_total_num_points())
print("#Points (single-dim. split):", adaptiveCombiInstanceExtend2.get_total_num_points())
# Out:
# Exact integral 0.9999999999999998
# Reference solution: 0.9999999999999998
# 0 [1, 1, 2] 1.0
# 1 [1, 2, 1] 1.0
# 2 [2, 1, 1] 1.0
# 3 [1, 1, 1] -2.0
# max surplus error: 0.003158892574627725 total surplus error: 0.20617199668414124
# combiintegral: 0.8236549544267637
# Current error: 0.17634504557323608
# Finished refinement
# Refined  2  times
# max surplus error: 0.0014698157888594437 total surplus error: 0.10449952570974122
# combiintegral: 0.858162198782599
# Current error: 0.14183780121740078
# New scheme
# 0 [1, 1, 3] 1.0
# 1 [1, 2, 2] 1.0
# 2 [1, 3, 1] 1.0
# 3 [2, 1, 2] 1.0
# 4 [2, 2, 1] 1.0
# 5 [3, 1, 1] 1.0
# 6 [1, 1, 2] -2.0
# 7 [1, 2, 1] -2.0
# 8 [2, 1, 1] -2.0
# 9 [1, 1, 1] 1.0
# Finished refinement
# Refined  1  times
# max surplus error: 0.00095416889133856 total surplus error: 0.08669599585772118
# combiintegral: 0.869754984707768
# Current error: 0.13024501529223179
# Finished refinement
# Refined  1  times
# ...

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=TrapezoidalGrid(a, b, dim)
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
reference_solution = f.getAnalyticSolutionIntegral(a,b)
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 5, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend,1,2, errorOperator,'Extend scheme min=1 max=2 split=3'),(adaptiveCombiInstanceExtend2,1,2, errorOperator,'Extend scheme min=1 max=2 Automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 4, dim, 7, grid, 1, 6)
print("#Points:", adaptiveCombiInstanceExtend.get_total_num_points())
print("#Points:", adaptiveCombiInstanceExtend2.get_total_num_points())
# Out:
# Cannot plot function with dim > 2
# Exact integral 1.1714979705007044e-06
# Reference solution: 1.1714979705007044e-06
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max surplus error: 2.6759733866455956e-05 total surplus error: 0.002997090193598365
# combiintegral: -0.001258118918969234
# Current error: 1074.9403316520534
# Split in dimension 2 , maxTwinError = [0.00125812]
# Finished refinement
# Refined  1  times
# max surplus error: 1.9583209069151816e-06 total surplus error: 0.0002193319759620616
# combiintegral: -0.0006208656005383389
# Current error: 530.9758225556102
# New scheme
# 0 [1, 1, 1, 1, 3] 1.0
# 1 [1, 1, 1, 2, 2] 1.0
# 2 [1, 1, 1, 3, 1] 1.0
# 3 [1, 1, 2, 1, 2] 1.0
# 4 [1, 1, 2, 2, 1] 1.0
# 5 [1, 1, 3, 1, 1] 1.0
# 6 [1, 2, 1, 1, 2] 1.0
# 7 [1, 2, 1, 2, 1] 1.0
# 8 [1, 2, 2, 1, 1] 1.0
# 9 [1, 3, 1, 1, 1] 1.0
# 10 [2, 1, 1, 1, 2] 1.0
# 11 [2, 1, 1, 2, 1] 1.0
# ...

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=TrapezoidalGrid(a, b, dim)
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
reference_solution = f.getAnalyticSolutionIntegral(a,b)
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 5, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=3'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 3, dim, 7, grid, 1, 6)
print("#Points:", adaptiveCombiInstanceExtend.get_total_num_points())
print("#Points:", adaptiveCombiInstanceExtend2.get_total_num_points())
# Out:
# Cannot plot function with dim > 2
# Exact integral 1.1714979705007044e-06
# Reference solution: 1.1714979705007044e-06
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max surplus error: 2.6759733866455956e-05 total surplus error: 0.002997090193598365
# combiintegral: -0.001258118918969234
# Current error: 1074.9403316520534
# Split in dimension 2 , maxTwinError = [0.00125812]
# Finished refinement
# Refined  1  times
# max surplus error: 1.9583209069151816e-06 total surplus error: 0.0002193319759620616
# combiintegral: -0.0006208656005383389
# Current error: 530.9758225556102
# New scheme
# 0 [1, 1, 1, 1, 3] 1.0
# 1 [1, 1, 1, 2, 2] 1.0
# 2 [1, 1, 1, 3, 1] 1.0
# 3 [1, 1, 2, 1, 2] 1.0
# 4 [1, 1, 2, 2, 1] 1.0
# 5 [1, 1, 3, 1, 1] 1.0
# 6 [1, 2, 1, 1, 2] 1.0
# 7 [1, 2, 1, 2, 1] 1.0
# 8 [1, 2, 2, 1, 1] 1.0
# 9 [1, 3, 1, 1, 1] 1.0
# 10 [2, 1, 1, 1, 2] 1.0
# 11 [2, 1, 1, 2, 1] 1.0
# ...

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=TrapezoidalGrid(a, b, dim)
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzCornerPeak(coeffs=coefficients)
reference_solution = f.getAnalyticSolutionIntegral(a,b)
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 2, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=3'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 2, dim, 6, grid, 1, 6)
print("#Points:", adaptiveCombiInstanceExtend.get_total_num_points())
print("#Points (automatic split):", adaptiveCombiInstanceExtend2.get_total_num_points())
# Out:
# Cannot plot function with dim > 2
# Exact integral 2.6025382796216128e-05
# Reference solution: 2.6025382796216128e-05
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max surplus error: 3.390712092002564e-05 total surplus error: 0.004884643959791192
# combiintegral: -0.0012818370237687045
# Current error: 50.253339856928946
# New scheme
# 0 [1, 1, 1, 1, 3] 1.0
# 1 [1, 1, 1, 2, 2] 1.0
# 2 [1, 1, 1, 3, 1] 1.0
# 3 [1, 1, 2, 1, 2] 1.0
# 4 [1, 1, 2, 2, 1] 1.0
# 5 [1, 1, 3, 1, 1] 1.0
# 6 [1, 2, 1, 1, 2] 1.0
# 7 [1, 2, 1, 2, 1] 1.0
# 8 [1, 2, 2, 1, 1] 1.0
# 9 [1, 3, 1, 1, 1] 1.0
# 10 [2, 1, 1, 1, 2] 1.0
# 11 [2, 1, 1, 2, 1] 1.0
# 12 [2, 1, 2, 1, 1] 1.0
# 13 [2, 2, 1, 1, 1] 1.0
# 14 [3, 1, 1, 1, 1] 1.0
# 15 [1, 1, 1, 1, 2] -4.0
# 16 [1, 1, 1, 2, 1] -4.0
# 17 [1, 1, 2, 1, 1] -4.0
# 18 [1, 2, 1, 1, 1] -4.0
# 19 [2, 1, 1, 1, 1] -4.0
# 20 [1, 1, 1, 1, 1] 6.0
# Finished refinement
# ...

# %%
#New min
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=TrapezoidalGrid(a, b, dim)
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzCornerPeak(coeffs=coefficients)
reference_solution = f.getAnalyticSolutionIntegral(a,b)
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 2, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=3'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 2, dim, 7, grid, 1, 6)
print("#Points:", adaptiveCombiInstanceExtend.get_total_num_points())
print("#Points (automatic split):", adaptiveCombiInstanceExtend2.get_total_num_points())
# Out:
# Cannot plot function with dim > 2
# Exact integral 2.6025382796216128e-05
# Reference solution: 2.6025382796216128e-05
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max surplus error: 3.390712092002564e-05 total surplus error: 0.004884643959791192
# combiintegral: -0.0012818370237687045
# Current error: 50.253339856928946
# New scheme
# 0 [1, 1, 1, 1, 3] 1.0
# 1 [1, 1, 1, 2, 2] 1.0
# 2 [1, 1, 1, 3, 1] 1.0
# 3 [1, 1, 2, 1, 2] 1.0
# 4 [1, 1, 2, 2, 1] 1.0
# 5 [1, 1, 3, 1, 1] 1.0
# 6 [1, 2, 1, 1, 2] 1.0
# 7 [1, 2, 1, 2, 1] 1.0
# 8 [1, 2, 2, 1, 1] 1.0
# 9 [1, 3, 1, 1, 1] 1.0
# 10 [2, 1, 1, 1, 2] 1.0
# 11 [2, 1, 1, 2, 1] 1.0
# 12 [2, 1, 2, 1, 1] 1.0
# 13 [2, 2, 1, 1, 1] 1.0
# 14 [3, 1, 1, 1, 1] 1.0
# 15 [1, 1, 1, 1, 2] -4.0
# 16 [1, 1, 1, 2, 1] -4.0
# 17 [1, 1, 2, 1, 1] -4.0
# 18 [1, 2, 1, 1, 1] -4.0
# 19 [2, 1, 1, 1, 1] -4.0
# 20 [1, 1, 1, 1, 1] 6.0
# Finished refinement
# ...

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=TrapezoidalGrid(a, b, dim)
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ float(10**1) * (d+1) for d in range(dim)])
f = GenzProductPeak(midpoint=midpoint,coefficients=coefficients)
reference_solution = f.getAnalyticSolutionIntegral(a,b)
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=3')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 1, dim, 8, grid, 1, 6)
print("#Points:", adaptiveCombiInstanceExtend.get_total_num_points())
# Out:
# Cannot plot function with dim > 2
# Exact integral 2295.504403148864
# Reference solution: 2295.504403148864
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max surplus error: 28236.810689098435 total surplus error: 3448819.3093164833
# combiintegral: -1213724.237573469
# Current error: 529.7396686795894
# Split in dimension 3 , maxTwinError = [1144516.46848617]
# Finished refinement
# Refined  1  times
# max surplus error: 1769.214831864401 total surplus error: 493042.45194694796
# combiintegral: -635489.1697766131
# Current error: 277.8407539993734
# Split in dimension 0 , maxTwinError = [1098252.35219408]
# New scheme
# 0 [1, 1, 1, 1, 3] 1.0
# 1 [1, 1, 1, 2, 2] 1.0
# 2 [1, 1, 1, 3, 1] 1.0
# 3 [1, 1, 2, 1, 2] 1.0
# 4 [1, 1, 2, 2, 1] 1.0
# 5 [1, 1, 3, 1, 1] 1.0
# 6 [1, 2, 1, 1, 2] 1.0
# 7 [1, 2, 1, 2, 1] 1.0
# 8 [1, 2, 2, 1, 1] 1.0
# 9 [1, 3, 1, 1, 1] 1.0
# 10 [2, 1, 1, 1, 2] 1.0
# ...

# %%
#New min
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=TrapezoidalGrid(a, b, dim)
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ float(10**1) * (d+1) for d in range(dim)])
f = GenzProductPeak(midpoint=midpoint,coefficients=coefficients)
reference_solution = f.getAnalyticSolutionIntegral(a,b)
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=3')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 1, dim, 8, grid, 1, 6)
print("#Points:", adaptiveCombiInstanceExtend.get_total_num_points())
# Out:
# Cannot plot function with dim > 2
# Exact integral 2295.504403148864
# Reference solution: 2295.504403148864
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max surplus error: 28236.810689098435 total surplus error: 3448819.3093164833
# combiintegral: -1213724.237573469
# Current error: 529.7396686795894
# Split in dimension 3 , maxTwinError = [1144516.46848617]
# Finished refinement
# Refined  1  times
# max surplus error: 1769.214831864401 total surplus error: 493042.45194694796
# combiintegral: -635489.1697766131
# Current error: 277.8407539993734
# Split in dimension 0 , maxTwinError = [1098252.35219408]
# New scheme
# 0 [1, 1, 1, 1, 3] 1.0
# 1 [1, 1, 1, 2, 2] 1.0
# 2 [1, 1, 1, 3, 1] 1.0
# 3 [1, 1, 2, 1, 2] 1.0
# 4 [1, 1, 2, 2, 1] 1.0
# 5 [1, 1, 3, 1, 1] 1.0
# 6 [1, 2, 1, 1, 2] 1.0
# 7 [1, 2, 1, 2, 1] 1.0
# 8 [1, 2, 2, 1, 1] 1.0
# 9 [1, 3, 1, 1, 1] 1.0
# 10 [2, 1, 1, 1, 2] 1.0
# ...

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=TrapezoidalGrid(a, b, dim)
midpoint = np.ones(dim) * 0.2
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
reference_solution = f.getAnalyticSolutionIntegral(a,b)
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=3')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 2, dim, 7, grid, 1, 5)
print("#Points:", adaptiveCombiInstanceExtend.get_total_num_points())
# Out:
# Cannot plot function with dim > 2
# Exact integral 7.821417442052503e-05
# Reference solution: 7.821417442052503e-05
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max surplus error: 3.106253487723214e-05 total surplus error: 0.00347900390625
# combiintegral: -0.00146484375
# Current error: 19.728622540003368
# Split in dimension 0 , maxTwinError = [0.00146484]
# Finished refinement
# Refined  1  times
# max surplus error: 6.027208176027986e-06 total surplus error: 0.0006750473157151344
# combiintegral: -0.0003015151842848656
# Current error: 4.8549941429253485
# Split in dimension 1 , maxTwinError = [0.00073242]
# Finished refinement
# Refined  1  times
# max surplus error: 3.043700911356921e-06 total surplus error: 0.00034089450207197515
# combiintegral: 3.937931778710954e-05
# Current error: 0.496519421462108
# Split in dimension 2 , maxTwinError = [0.00036621]
# ...

# %%
#New min
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=TrapezoidalGrid(a, b, dim)
midpoint = np.ones(dim) * 0.2
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
reference_solution = f.getAnalyticSolutionIntegral(a,b)
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0, automatic_extend_split=False, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=3')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 3, dim, 9, grid, 1, 5)
print("#Points:", adaptiveCombiInstanceExtend.get_total_num_points())
# Out:
# Cannot plot function with dim > 2
# Exact integral 7.821417442052503e-05
# Reference solution: 7.821417442052503e-05
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max surplus error: 3.106253487723214e-05 total surplus error: 0.00347900390625
# combiintegral: -0.00146484375
# Current error: 19.728622540003368
# Split in dimension 0 , maxTwinError = [0.00146484]
# Finished refinement
# Refined  1  times
# max surplus error: 6.027208176027986e-06 total surplus error: 0.0006750473157151344
# combiintegral: -0.0003015151842848656
# Current error: 4.8549941429253485
# Split in dimension 1 , maxTwinError = [0.00073242]
# Finished refinement
# Refined  1  times
# max surplus error: 3.043700911356921e-06 total surplus error: 0.00034089450207197515
# combiintegral: 3.937931778710954e-05
# Current error: 0.496519421462108
# Split in dimension 2 , maxTwinError = [0.00036621]
# ...

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
print(np.inner([],[]))
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**1.2 * (d+1) for d in range(dim)])
grid=TrapezoidalGrid(a, b, dim, boundary=False) #boundary = True #Im integrator.
f = GenzC0(midpoint=midpoint, coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 4, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 4, grid, no_initial_splitting=False, version=0, automatic_extend_split=False, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split = 4'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 1, dim, 7, grid, 1, 6, minTol=-3)
print("#Points:", adaptiveCombiInstanceExtend.get_total_num_points())
print("#Points (automatic split):", adaptiveCombiInstanceExtend2.get_total_num_points())

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
print(np.inner([],[]))
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**1.2 * (d+1) for d in range(dim)])
grid=TrapezoidalGrid(a, b, dim, boundary=False)
f = GenzC0(midpoint=midpoint, coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 4 , grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 4, grid, no_initial_splitting=False, version=0, automatic_extend_split=False, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split = 4'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 1, dim, 9, grid, 1, 6, minTol=-3)
print("#Points:", adaptiveCombiInstanceExtend.get_total_num_points())
print("#Points (automatic split):", adaptiveCombiInstanceExtend2.get_total_num_points())

# %%
#New min
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
print(np.inner([],[]))
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
grid=TrapezoidalGrid(a, b, dim, boundary=False)
f = GenzC0(midpoint=midpoint, coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 4, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 4, grid, no_initial_splitting=False, version=0, automatic_extend_split=False, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split = 4'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 1, dim, 9, grid, 1, 6, minTol=-3)
print("#Points:", adaptiveCombiInstanceExtend.get_total_num_points())
print("#Points (automatic split):", adaptiveCombiInstanceExtend2.get_total_num_points())

# %%
#New min
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
print(np.inner([],[]))
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
grid=TrapezoidalGrid(a, b, dim, boundary=False)
f = GenzC0(midpoint=midpoint, coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 4, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 4, grid, no_initial_splitting=False, version=0, automatic_extend_split=False, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split = 4'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 2, dim, 10, grid, 1, 6, minTol=-3)
print("#Points:", adaptiveCombiInstanceExtend.get_total_num_points())
print("#Points (automatic split):", adaptiveCombiInstanceExtend2.get_total_num_points())

# %%
#TODO: Modify?
#results for C0 Test-case
x_standard_1 = [11, 71, 351, 1471, 5503, 18943, 61183, 187903] 
err_standard_1 = [16644.069661617246, 2019.7849757319057, 4415.4947531629914, 3310.5334984239789, 734.485252984201, 520.16776756062552, 617.33525472331837, 344.3441234481383]
x_standard_2 = [1863, 9423, 38943, 142143, 476287] 
err_standard_2 = [488.8113728567173, 75.533433881051792, 90.751153944018412, 60.369886363400823, 13.659214245315066]
x_standard_3 = [112847, 524447] 
err_standard_3 = [15.017241075346963, 4.2430812802970932]
x_adaptive_split = [11, 1863, 3745, 5125, 7775, 12775, 14759, 17469, 18739, 19653, 19969, 20341, 23305, 23975, 24291, 24923, 25145, 31973, 32289, 33669, 33985, 35627, 38127, 40231, 42361, 62463, 63117, 64295, 67063, 68013, 76107, 77615, 78937, 91667, 94261, 95635, 99043, 101357, 103729, 118011, 131739, 133009, 150715, 152447, 155607, 160035, 165535, 183919, 191507, 205631, 232105, 253635, 264621, 267195, 269819, 294713, 300495, 303879, 325355, 326899, 332045, 354987, 356275, 383213, 384801, 385229, 397137, 434365, 445653, 467085, 493893, 510629, 545177]
err_adaptive_split = [16644.069661617239, 488.81137285671804, 461.44875861354575, 434.08614437037352, 379.360915884029, 343.85814285138605, 314.46048891084627, 280.99275557557115, 226.26752708922695, 222.19744769449159, 220.16240799712392, 218.12736829975623, 162.80969019779346, 133.41203625725322, 106.04942201408097, 51.324193527736391, 23.961579284564124, 21.581907300927828, 19.546867603559946, 18.954417987941735, 18.77136629689279, 18.178916681274579, 16.810965758989216, 14.727294835738594, 13.542395604502174, 11.116469916169073, 10.524020300550864, 7.3040813719465403, 7.2900220258411119, 6.5278327534503129, 5.6749971230145642, 4.8906478765155317, 4.2009358091318276, 3.9623266100134256, 3.8562162184160544, 3.7924596504665384, 3.7284022521954356, 3.6745596200391391, 3.3987095716691766, 3.1767472787258622, 2.4378816641887275, 2.4201857845249743, 2.3494536259026799, 2.2354686298780058, 1.5214006704545953, 1.3007869005687414, 1.295648786352823, 1.2712998815865375, 1.2514246136757692, 1.168938823421517, 1.0861541719926548, 0.98947347399423224, 0.92662251251555205, 0.85673988619513985, 0.84160776432154349, 0.6486446558206993, 0.64231279104923911, 0.64215863677288454, 0.62354842007125211, 0.61646504299323701, 0.60726095979001349, 0.52427872230721628, 0.52385094403042332, 0.33230550432938244, 0.33164875284106388, 0.33152619231277008, 0.32391544916078618, 0.29329320229274869, 0.2725653145242905, 0.26462364381860176, 0.22961186932556332, 0.20650796524992052, 0.095812967668421775]
err_surplus_split =  [16643.069661617243, 1256.4020891753898, 810.39777007357088, 727.22186802721308, 597.31060851673124, 419.46617254691046, 358.35819991517349, 272.75197611023788, 217.54087145202004, 189.26631364425384, 177.22067121786426, 166.89145077230708, 125.43985989154579, 110.36499093733629, 102.61572197097011, 92.214624479573885, 87.892743947029814, 53.477869381732035, 51.450519960167128, 48.541603883107463, 46.919711111548388, 44.917391610688469, 41.410060769678125, 39.657249883528685, 38.00330800140074, 24.081912921320203, 23.553108044303254, 22.664144280925512, 21.916320316685137, 21.276219734781598, 17.7836395714552, 17.279291386468199, 16.60943920341661, 12.85626523661128, 12.303776886764297, 12.036816883638823, 11.614597471845094, 11.393734626354846, 11.099205816312288, 9.5906155716593027, 8.3428774302437567, 8.2629404815390934, 7.2448416907675082, 7.0689663760694517, 7.0660533993747361, 6.8295914096468477, 6.6828209266370537, 6.102159328590397, 5.8163017061390256, 5.3159376658681934, 4.5880646622427275, 4.0199059861376956, 3.850639156236872, 3.7793510748261232, 3.7343421647505859, 3.3687297944657515, 3.2926492306246571, 3.2636477433597051, 3.0316633343792652, 3.0062023374092344, 2.963456145348311, 2.75079097811691, 2.7445082614572529, 2.5470069773188606, 2.5280298930943816, 2.5214827874586256, 2.4431292318571027, 2.2606030958393819, 2.1874567268113694, 2.0783404018830214, 1.9603083659803149, 1.8836029149039291, 1.8130626628407622]
x_adaptive_auto = [11, 1863, 2103, 2343, 2643, 3195, 7829, 8919, 11397, 11561, 12909, 13385, 13757, 13885, 13937, 13959, 20864, 58305, 58317, 60289, 67335, 67717, 68099, 68321, 68901, 91522, 110193, 113669, 114257, 115807, 122927, 149639, 149753, 169789, 170731, 171143, 172173, 215045, 216045, 218177, 228867, 288411, 288567, 292249] 
err_adaptive_auto = [16644.069661617239, 488.81137285671804, 476.87123191339845, 464.93109097007886, 441.05080908343967, 393.29024531016137, 361.26980463405124, 335.35448305004451, 305.36908207130233, 257.60851829802402, 253.53843890328866, 251.503399205921, 249.46835950855331, 201.70779573527503, 176.06505514533802, 152.18477325869893, 95.517981021003948, 20.860601411087838, 3.0196804755512661, 7.124273928551256, 9.5039459121876479, 11.538985609555532, 11.722037300604477, 11.905088991653422, 13.975668430627591, 8.0433411967425812, 0.40469951595628412, 0.77934313837599178, 2.8701951620983679, 2.9348554282847226, 3.1466102172195161, 3.3984275894655216, 3.4042881779168184, 3.4463369842614959, 3.52898306638353, 3.6203351343443031, 3.6647228157824729, 5.7054671414552711, 5.7303055805116285, 5.8205176315242095, 4.5003099294144517, 0.29233593366737048, 0.2212564504547811, 0.0034321453354958509]
err_surplus_auto = [16643.069661617243, 1256.4020891753898, 1036.8361805038594, 817.27027183232872, 752.72594524518513, 663.12867629473158, 505.63852025462427, 466.23586235464131, 402.2251080856152, 391.80993743153618, 363.53537962377254, 351.4897371973845, 341.16051675182752, 357.84046750127482, 366.30924601195863, 380.3351554320414, 387.82961510354733, 138.7634163045781, 157.04212816765218, 134.71437365244358, 100.29949908714428, 98.272149665579349, 96.650256894020075, 95.810363298611719, 94.032001469640051, 75.137656423517043, 44.269333265492207, 39.962092170445771, 38.087580158590221, 36.423067762183528, 33.378006739437119, 24.211414830827607, 24.042264793765924, 20.865405530379306, 19.512399295602176, 18.964106883385536, 18.812976398401393, 14.101272080884822, 13.79984488932428, 13.364688376699098, 13.427798335601068, 13.696286197965311, 13.666293291027527, 13.471832977581952]

plt.loglog(x_standard_1,err_standard_1, label="Standard Combi lmin=1")
plt.loglog(x_standard_2,err_standard_2, label="Standard Combi lmin=2")
plt.loglog(x_standard_3,err_standard_3, label="Standard Combi lmin=3")
plt.loglog(x_adaptive_split,err_adaptive_split, label="Extend-Split depth=4")
plt.loglog(x_adaptive_split,err_surplus_split, label="Extend-Split depth=4 surplusses")
plt.loglog(x_adaptive_auto,err_adaptive_auto, label="Extend-Split auto")
plt.loglog(x_adaptive_auto,err_surplus_auto, label="Extend-Split auto surplusses")
plt.legend()
plt.show()

# %%
#Modify?
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
grid=GaussLegendreGrid(a, b, dim=dim)
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, no_initial_splitting=False, version=0, automatic_extend_split=False, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend3 = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 2, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Optimized Split=2'), (adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Optimized Split=0'), (adaptiveCombiInstanceExtend3, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Optimized Split=1')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 9, dim, 8, grid, 1, 3)

# %%
#Modify?
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
grid=GaussLegendreGrid(a, b, dim=dim)
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, no_initial_splitting=False, version=0)
adaptiveCombiInstanceExtend3 = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 2, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Optimized Split=1')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 11, dim, 8, grid, 1, 3)

# %%
#Modify?
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
grid=TrapezoidalGrid()
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
f.plot(a, b)

errorOperator = ErrorCalculatorAnalyticCell()
errorOperator2 = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptivExtendScheme(a, b, 5, grid, no_initial_splitting=False)
adaptiveCombiInstanceExtend = SpatiallyAdaptivExtendScheme(a, b, 2, grid, no_initial_splitting=False, automatic_extend_split=True)
adaptiveCombiInstanceCell = SpatiallyAdaptivCellScheme(a, b, grid)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator2, 'Extend scheme min=1 max=2 Optimized'),(adaptiveCombiInstanceCell, 3, 3, errorOperator, 'Cell scheme min=1 max=2 Optimized')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, errorOperator, 7, dim, 15, grid, 1, 6)

# %%
#Necessary?
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
grid = GaussLegendreGrid(a, b, dim)
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
f.plot(a, b)

errorOperator = ErrorCalculatorAnalyticCell()
errorOperator2 = ErrorCalculatorAnalytic()

adaptiveCombiInstanceExtend = SpatiallyAdaptivExtendScheme(a, b, 2, grid, no_initial_splitting=False, automatic_extend_split=True)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator2,'Extend scheme min=1 max=2 Optimized')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, errorOperator, 9, dim, 8, grid, 1, 6)

# %%
#New min
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
grid = GaussLegendreGrid(a, b, dim)
f = Function2Jakeman(midpoints,coefficients)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 5, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 2, grid, no_initial_splitting=False, version=0, automatic_extend_split=False, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator,'Extend scheme min=1 max=2 Split=2'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator,'Extend scheme min=1 max=2 Automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 8, dim, 9, grid, 1, 6)

# %%
#New min
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
grid = GaussLegendreGrid(a, b, dim)
f = GenzCornerPeak(coeffs=coefficients)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 2, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0, automatic_extend_split=False, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=1'), (adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 6, dim, 8, grid, 1, 6)

# %%
#Modify?
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
grid=GaussLegendreGrid(a, b, dim)
f = GenzC0(midpoint=midpoint,coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 4, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0, automatic_extend_split=False, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Optimized')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 2, dim, 8, grid, 1, 6, minTol=-3)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
grid=GaussLegendreGrid(a, b, dim)
f = GenzC0(midpoint=midpoint,coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 4, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0, automatic_extend_split=False, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 1, dim, 8, grid, 1, 6, minTol=-3)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.2
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
grid=GaussLegendreGrid(a, b, dim)
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0, automatic_extend_split=False, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend,1,2, errorOperator,'Extend scheme min=1 max=2 Automatic split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 2, dim, 7, grid, 1, 5)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.2
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
grid=GaussLegendreGrid(a, b, dim)
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0, automatic_extend_split=False, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Automatic split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 1, dim, 7, grid, 1, 5)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=GaussLegendreGrid(a, b, dim)
f = FunctionGriebel()
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)


errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, no_initial_splitting=False, version=0, automatic_extend_split=False, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend,1,2, errorOperator, 'Extend scheme min=1 max=2 split=0'),(adaptiveCombiInstanceExtend2,1,2, errorOperator, 'Extend scheme min=1 max=2 automatic_split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 4, dim, 8, grid, 1, 3)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ float(10**1) * (d+1) for d in range(dim)])
grid=GaussLegendreGrid(a, b, dim)
f = GenzProductPeak(midpoint=midpoint, coefficients=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0, automatic_extend_split=False, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=4')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 3, dim, 8, grid, 1, 6)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ float(10**1) * (d+1) for d in range(dim)])
grid=GaussLegendreGrid(a, b, dim)
f = GenzProductPeak(midpoint=midpoint, coefficients=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0, automatic_extend_split=False, split_single_dim=True, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 automatic split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 2, dim, 8, grid, 1, 6)
