# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sys import path
#path.append('../../../src/')
#path.append('../../../src/tools')
import numpy as np

#from numpy import *
import scipy as sp
from spatiallyAdaptiveExtendSplit import *
from spatiallyAdaptiveSplit import *
from spatiallyAdaptiveSingleDimension import *
from spatiallyAdaptiveCell import *
from GridOperation import *

from PerformTestCase import *
from Function import *
from ErrorCalculator import *
import math

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid = TrapezoidalGrid(a, b, dim)

f = FunctionGriebel()
operation = Integration(f=f, grid=grid, dim=dim)
#f = Function2Jakeman(midpoints,coefficients)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, version=0, no_initial_splitting=False, automatic_extend_split=False, split_single_dim=False, operation=operation)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, version=0, no_initial_splitting=False, automatic_extend_split=True, split_single_dim=False, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend,1,2, errorOperator, 'Extend scheme min=1 max=2 split=0'),(adaptiveCombiInstanceExtend2,1,2, errorOperator, 'Extend scheme min=1 max=2 automatic_split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 2, dim, 9, grid, 1, 5)
# Out:
# Cannot plot function with dim > 2
# Exact integral 1.0
# Reference solution: 1.0
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max surplus error: 0.00018889466389102844 total surplus error: 0.31414053573801154
# combiintegral: 0.603350063259646
# Current error: 0.31414053573801154
# New scheme
# 0 [1, 1, 1, 1, 3] 1.0
# 1 [1, 1, 1, 2, 2] 1.0
# 2 [1, 1, 1, 3, 1] 1.0
# 3 [1, 1, 2, 1, 2] 1.0
# 4 [1, 1, 2, 2, 1] 1.0
# 5 [1, 1, 3, 1, 1] 1.0
# 6 [1, 2, 1, 1, 2] 1.0
# 7 [1, 2, 1, 2, 1] 1.0
# 8 [1, 2, 2, 1, 1] 1.0
# 9 [1, 3, 1, 1, 1] 1.0
# 10 [2, 1, 1, 1, 2] 1.0
# 11 [2, 1, 1, 2, 1] 1.0
# 12 [2, 1, 2, 1, 1] 1.0
# 13 [2, 2, 1, 1, 1] 1.0
# 14 [3, 1, 1, 1, 1] 1.0
# 15 [1, 1, 1, 1, 2] -4.0
# 16 [1, 1, 1, 2, 1] -4.0
# 17 [1, 1, 2, 1, 1] -4.0
# 18 [1, 2, 1, 1, 1] -4.0
# 19 [2, 1, 1, 1, 1] -4.0
# 20 [1, 1, 1, 1, 1] 6.0
# Finished refinement
# Refined  1  times
# max surplus error: 0.00018889466389102844 total surplus error: 0.29880489325316756
# combiintegral: 0.6091706231305974
# Current error: 0.29880489325316756
# Finished refinement
# Refined  5  times
# max surplus error: 0.0001475950548835327 total surplus error: 0.22582476884100133
# combiintegral: 0.6382734224853537
# Current error: 0.22582476884100133
# Finished refinement
# Refined  1  times
# max surplus error: 0.00012988770665130965 total surplus error: 0.2151146825649968
# combiintegral: 0.6440939823563051
# Current error: 0.2151146825649968
# Finished refinement
# Refined  1  times
# max surplus error: 0.00011572182806553136 total surplus error: 0.20638781929100125
# combiintegral: 0.6499145422272565
# Current error: 0.20638781929100125
# Finished refinement
# Refined  3  times
# max surplus error: 0.00010125784482764379 total surplus error: 0.18579451058341556
# combiintegral: 0.6660785707092242
# Current error: 0.18579451058341556
# Finished refinement
# Refined  2  times
# max surplus error: 8.709196624186531e-05 total surplus error: 0.17385286655344162
# combiintegral: 0.6764220393202406
# Current error: 0.17385286655344162
# Finished refinement
# Refined  3  times
# max surplus error: 7.292608765608688e-05 total surplus error: 0.16195617694790787
# combiintegral: 0.6919372422367652
# Current error: 0.16195617694790787
# Finished refinement
# Refined  2  times
# max surplus error: 6.259978336886216e-05 total surplus error: 0.15636084652436266
# combiintegral: 0.7022807108477817
# Current error: 0.15636084652436266
# Finished refinement
# Refined  1  times
# max surplus error: 5.521873942386383e-05 total surplus error: 0.15517023065800128
# combiintegral: 0.7081012707187331
# Current error: 0.15517023065800128
# Finished refinement
# Refined  4  times
# max surplus error: 4.5861101061006135e-05 total surplus error: 0.1487369389420658
# combiintegral: 0.7249806010431749
# Current error: 0.1487369389420658
# Finished refinement
# Refined  1  times
# max surplus error: 3.896687668959285e-05 total surplus error: 0.1475030276295447
# combiintegral: 0.728883133049486
# Current error: 0.1475030276295447
# Finished refinement
# Refined  2  times
# max surplus error: 2.5395898253747855e-05 total surplus error: 0.143314525985563
# combiintegral: 0.7331376459791655
# Current error: 0.143314525985563
# Finished refinement
# Refined  1  times
# max surplus error: 1.9076076181468687e-05 total surplus error: 0.14314508719357996
# combiintegral: 0.7358125477916018
# Current error: 0.14314508719357996
# Finished refinement
# Refined  5  times
# max surplus error: 1.6535681451565956e-05 total surplus error: 0.15547296699614224
# combiintegral: 0.7588230302557887
# Current error: 0.15547296699614224
# New scheme
# 0 [1, 1, 1, 1, 4] 1.0
# 1 [1, 1, 1, 2, 3] 1.0
# 2 [1, 1, 1, 3, 2] 1.0
# 3 [1, 1, 1, 4, 1] 1.0
# 4 [1, 1, 2, 1, 3] 1.0
# 5 [1, 1, 2, 2, 2] 1.0
# 6 [1, 1, 2, 3, 1] 1.0
# 7 [1, 1, 3, 1, 2] 1.0
# 8 [1, 1, 3, 2, 1] 1.0
# 9 [1, 1, 4, 1, 1] 1.0
# 10 [1, 2, 1, 1, 3] 1.0
# 11 [1, 2, 1, 2, 2] 1.0
# 12 [1, 2, 1, 3, 1] 1.0
# 13 [1, 2, 2, 1, 2] 1.0
# 14 [1, 2, 2, 2, 1] 1.0
# 15 [1, 2, 3, 1, 1] 1.0
# 16 [1, 3, 1, 1, 2] 1.0
# 17 [1, 3, 1, 2, 1] 1.0
# 18 [1, 3, 2, 1, 1] 1.0
# 19 [1, 4, 1, 1, 1] 1.0
# 20 [2, 1, 1, 1, 3] 1.0
# 21 [2, 1, 1, 2, 2] 1.0
# 22 [2, 1, 1, 3, 1] 1.0
# 23 [2, 1, 2, 1, 2] 1.0
# 24 [2, 1, 2, 2, 1] 1.0
# 25 [2, 1, 3, 1, 1] 1.0
# 26 [2, 2, 1, 1, 2] 1.0
# 27 [2, 2, 1, 2, 1] 1.0
# 28 [2, 2, 2, 1, 1] 1.0
# 29 [2, 3, 1, 1, 1] 1.0
# 30 [3, 1, 1, 1, 2] 1.0
# 31 [3, 1, 1, 2, 1] 1.0
# 32 [3, 1, 2, 1, 1] 1.0
# 33 [3, 2, 1, 1, 1] 1.0
# 34 [4, 1, 1, 1, 1] 1.0
# 35 [1, 1, 1, 1, 3] -4.0
# 36 [1, 1, 1, 2, 2] -4.0
# 37 [1, 1, 1, 3, 1] -4.0
# 38 [1, 1, 2, 1, 2] -4.0
# 39 [1, 1, 2, 2, 1] -4.0
# 40 [1, 1, 3, 1, 1] -4.0
# 41 [1, 2, 1, 1, 2] -4.0
# 42 [1, 2, 1, 2, 1] -4.0
# 43 [1, 2, 2, 1, 1] -4.0
# 44 [1, 3, 1, 1, 1] -4.0
# 45 [2, 1, 1, 1, 2] -4.0
# 46 [2, 1, 1, 2, 1] -4.0
# 47 [2, 1, 2, 1, 1] -4.0
# 48 [2, 2, 1, 1, 1] -4.0
# 49 [3, 1, 1, 1, 1] -4.0
# 50 [1, 1, 1, 1, 2] 6.0
# 51 [1, 1, 1, 2, 1] 6.0
# 52 [1, 1, 2, 1, 1] 6.0
# 53 [1, 2, 1, 1, 1] 6.0
# 54 [2, 1, 1, 1, 1] 6.0
# 55 [1, 1, 1, 1, 1] -4.0
# Finished refinement
# Refined  1  times
# max surplus error: 1.6535681451565956e-05 total surplus error: 0.15302341480035622
# combiintegral: 0.7621940379309544
# Current error: 0.15302341480035622
# Finished refinement
# Refined  9  times
# max surplus error: 1.4692427004284815e-05 total surplus error: 0.13097744503828085
# combiintegral: 0.7925331070074204
# Current error: 0.13097744503828085
# Finished refinement
# Refined  10  times
# max surplus error: 1.3074137763741616e-05 total surplus error: 0.11577843650121158
# combiintegral: 0.8290514415254413
# Current error: 0.11577843650121158
# Finished refinement
# Refined  5  times
# max surplus error: 1.1086738654294399e-05 total surplus error: 0.10306911691808196
# combiintegral: 0.8393526044064823
# Current error: 0.10306911691808196
# Finished refinement
# Refined  5  times
# max surplus error: 7.599152876240682e-06 total surplus error: 0.0997751558262257
# combiintegral: 0.85557130334618
# Current error: 0.0997751558262257
# Finished refinement
# Refined  1  times
# max surplus error: 3.5385983060090835e-06 total surplus error: 0.09965553256530028
# combiintegral: 0.8581265818976924
# Current error: 0.09965553256530028
# New scheme
# 0 [1, 1, 1, 1, 5] 1.0
# 1 [1, 1, 1, 2, 4] 1.0
# 2 [1, 1, 1, 3, 3] 1.0
# 3 [1, 1, 1, 4, 2] 1.0
# 4 [1, 1, 1, 5, 1] 1.0
# 5 [1, 1, 2, 1, 4] 1.0
# 6 [1, 1, 2, 2, 3] 1.0
# 71 [1, 1, 1, 2, 3] -4.0
# 72 [1, 1, 1, 3, 2] -4.0
# 73 [1, 1, 1, 4, 1] -4.0
# 74 [1, 1, 2, 1, 3] -4.0
# 75 [1, 1, 2, 2, 2] -4.0
# 76 [1, 1, 2, 3, 1] -4.0
# 77 [1, 1, 3, 1, 2] -4.0
# 78 [1, 1, 3, 2, 1] -4.0
# 79 [1, 1, 4, 1, 1] -4.0
# 80 [1, 2, 1, 1, 3] -4.0
# 81 [1, 2, 1, 2, 2] -4.0
# 82 [1, 2, 1, 3, 1] -4.0
# 83 [1, 2, 2, 1, 2] -4.0
# 84 [1, 2, 2, 2, 1] -4.0
# 85 [1, 2, 3, 1, 1] -4.0
# 86 [1, 3, 1, 1, 2] -4.0
# 87 [1, 3, 1, 2, 1] -4.0
# 88 [1, 3, 2, 1, 1] -4.0
# 89 [1, 4, 1, 1, 1] -4.0
# 90 [2, 1, 1, 1, 3] -4.0
# 91 [2, 1, 1, 2, 2] -4.0
# 92 [2, 1, 1, 3, 1] -4.0
# 93 [2, 1, 2, 1, 2] -4.0
# 94 [2, 1, 2, 2, 1] -4.0
# 95 [2, 1, 3, 1, 1] -4.0
# 96 [2, 2, 1, 1, 2] -4.0
# 97 [2, 2, 1, 2, 1] -4.0
# 98 [2, 2, 2, 1, 1] -4.0
# 99 [2, 3, 1, 1, 1] -4.0
# 100 [3, 1, 1, 1, 2] -4.0
# 101 [3, 1, 1, 2, 1] -4.0
# 102 [3, 1, 2, 1, 1] -4.0
# 103 [3, 2, 1, 1, 1] -4.0
# 104 [4, 1, 1, 1, 1] -4.0
# 105 [1, 1, 1, 1, 3] 6.0
# 106 [1, 1, 1, 2, 2] 6.0
# 107 [1, 1, 1, 3, 1] 6.0
# 108 [1, 1, 2, 1, 2] 6.0
# 109 [1, 1, 2, 2, 1] 6.0
# 110 [1, 1, 3, 1, 1] 6.0
# 111 [1, 2, 1, 1, 2] 6.0
# 112 [1, 2, 1, 2, 1] 6.0
# 113 [1, 2, 2, 1, 1] 6.0
# 114 [1, 3, 1, 1, 1] 6.0
# 115 [2, 1, 1, 1, 2] 6.0
# 116 [2, 1, 1, 2, 1] 6.0
# 117 [2, 1, 2, 1, 1] 6.0
# 118 [2, 2, 1, 1, 1] 6.0
# 119 [3, 1, 1, 1, 1] 6.0
# 120 [1, 1, 1, 1, 2] -4.0
# 121 [1, 1, 1, 2, 1] -4.0
# 122 [1, 1, 2, 1, 1] -4.0
# 123 [1, 2, 1, 1, 1] -4.0
# 124 [2, 1, 1, 1, 1] -4.0
# 125 [1, 1, 1, 1, 1] 1.0
# Finished refinement
# Refined  1  times
# max surplus error: 3.5385983060090835e-06 total surplus error: 0.09812410714931834
# combiintegral: 0.8599661641568774
# Current error: 0.09812410714931834
# Finished refinement
# Refined  19  times
# max surplus error: 3.1431587092445594e-06 total surplus error: 0.07133640886750846
# combiintegral: 0.900035869469577
# Current error: 0.07133640886750846
# Finished refinement
# Refined  5  times
# max surplus error: 2.476045108053579e-06 total surplus error: 0.06711720719509323
# combiintegral: 0.9120353667368691
# Current error: 0.06711720719509323
# Finished refinement
# Refined  1  times
# max surplus error: 1.9963493955535546e-06 total surplus error: 0.06669454482856427
# combiintegral: 0.91416798292185
# Current error: 0.06669454482856427
# Finished refinement
# Refined  5  times
# max surplus error: 9.999458050254726e-07 total surplus error: 0.06095280044340888
# combiintegral: 0.9187274014177773
# Current error: 0.06095280044340888
# Finished refinement
# Refined  1  times
# max surplus error: 8.327201434620048e-07 total surplus error: 0.06069308215473933
# combiintegral: 0.918819664052478
# Current error: 0.06069308215473933
# New scheme
# 0 [1, 1, 1, 1, 6] 1.0
# 1 [1, 1, 1, 2, 5] 1.0
# 2 [1, 1, 1, 3, 4] 1.0
# 3 [1, 1, 1, 4, 3] 1.0
# 4 [1, 1, 1, 5, 2] 1.0
# 5 [1, 1, 1, 6, 1] 1.0
# 6 [1, 1, 2, 1, 5] 1.0
# 7 [1, 1, 2, 2, 4] 1.0
# 8 [1, 1, 2, 3, 3] 1.0
# 9 [1, 1, 2, 4, 2] 1.0
# 10 [1, 1, 2, 5, 1] 1.0
# 11 [1, 1, 3, 1, 4] 1.0
# 12 [1, 1, 3, 2, 3] 1.0
# 13 [1, 1, 3, 3, 2] 1.0
# 14 [1, 1, 3, 4, 1] 1.0
# 15 [1, 1, 4, 1, 3] 1.0
# 16 [1, 1, 4, 2, 2] 1.0
# 17 [1, 1, 4, 3, 1] 1.0
# 18 [1, 1, 5, 1, 2] 1.0
# 19 [1, 1, 5, 2, 1] 1.0
# 20 [1, 1, 6, 1, 1] 1.0
# 21 [1, 2, 1, 1, 5] 1.0
# 22 [1, 2, 1, 2, 4] 1.0
# 23 [1, 2, 1, 3, 3] 1.0
# 24 [1, 2, 1, 4, 2] 1.0
# 25 [1, 2, 1, 5, 1] 1.0
# 26 [1, 2, 2, 1, 4] 1.0
# 27 [1, 2, 2, 2, 3] 1.0
# 28 [1, 2, 2, 3, 2] 1.0
# 29 [1, 2, 2, 4, 1] 1.0
# 30 [1, 2, 3, 1, 3] 1.0
# 31 [1, 2, 3, 2, 2] 1.0
# 32 [1, 2, 3, 3, 1] 1.0
# 33 [1, 2, 4, 1, 2] 1.0
# 34 [1, 2, 4, 2, 1] 1.0
# 35 [1, 2, 5, 1, 1] 1.0
# 36 [1, 3, 1, 1, 4] 1.0
# 37 [1, 3, 1, 2, 3] 1.0
# 38 [1, 3, 1, 3, 2] 1.0
# 39 [1, 3, 1, 4, 1] 1.0
# 40 [1, 3, 2, 1, 3] 1.0
# 41 [1, 3, 2, 2, 2] 1.0
# 42 [1, 3, 2, 3, 1] 1.0
# 43 [1, 3, 3, 1, 2] 1.0
# 44 [1, 3, 3, 2, 1] 1.0
# 45 [1, 3, 4, 1, 1] 1.0
# 46 [1, 4, 1, 1, 3] 1.0
# 47 [1, 4, 1, 2, 2] 1.0
# 48 [1, 4, 1, 3, 1] 1.0
# 49 [1, 4, 2, 1, 2] 1.0
# 50 [1, 4, 2, 2, 1] 1.0
# 51 [1, 4, 3, 1, 1] 1.0
# 245 [3, 1, 1, 1, 1] -4.0
# 246 [1, 1, 1, 1, 2] 1.0
# 247 [1, 1, 1, 2, 1] 1.0
# 248 [1, 1, 2, 1, 1] 1.0
# 249 [1, 2, 1, 1, 1] 1.0
# 250 [2, 1, 1, 1, 1] 1.0
# Finished refinement
# Refined  1  times
# max surplus error: 8.327201434620048e-07 total surplus error: 0.0597640228672712
# combiintegral: 0.9202419512630117
# Current error: 0.0597640228672712
# Finished refinement
# Refined  14  times
# max surplus error: 7.39977857384565e-07 total surplus error: 0.04760049789316132
# combiintegral: 0.9412400420381603
# Current error: 0.04760049789316132
# Finished refinement
# Refined  1  times
# max surplus error: 6.38300575705837e-07 total surplus error: 0.04708903563520727
# combiintegral: 0.9428611959651864
# Current error: 0.04708903563520727
# Finished refinement
# Refined  10  times
# max surplus error: 3.1640655766146456e-07 total surplus error: 0.0383417303832509
# combiintegral: 0.9525097133049157
# Current error: 0.0383417303832509
# Finished refinement
# Refined  5  times
# max surplus error: 2.1119427747995232e-07 total surplus error: 0.035786840737566585
# combiintegral: 0.9545142421551498
# Current error: 0.035786840737566585
# New scheme
# 0 [1, 1, 1, 1, 7] 1.0
# 1 [1, 1, 1, 2, 6] 1.0
# 2 [1, 1, 1, 3, 5] 1.0
# 3 [1, 1, 1, 4, 4] 1.0
# 4 [1, 1, 1, 5, 3] 1.0
# 5 [1, 1, 1, 6, 2] 1.0
# 6 [1, 1, 1, 7, 1] 1.0
# 7 [1, 1, 2, 1, 6] 1.0
# 8 [1, 1, 2, 2, 5] 1.0
# 9 [1, 1, 2, 3, 4] 1.0
# 10 [1, 1, 2, 4, 3] 1.0
# 11 [1, 1, 2, 5, 2] 1.0
# 12 [1, 1, 2, 6, 1] 1.0
# 13 [1, 1, 3, 1, 5] 1.0
# 14 [1, 1, 3, 2, 4] 1.0
# 15 [1, 1, 3, 3, 3] 1.0
# 16 [1, 1, 3, 4, 2] 1.0
# 17 [1, 1, 3, 5, 1] 1.0
# 18 [1, 1, 4, 1, 4] 1.0
# 19 [1, 1, 4, 2, 3] 1.0
# 20 [1, 1, 4, 3, 2] 1.0
# 21 [1, 1, 4, 4, 1] 1.0
# 22 [1, 1, 5, 1, 3] 1.0
# 23 [1, 1, 5, 2, 2] 1.0
# 24 [1, 1, 5, 3, 1] 1.0
# 25 [1, 1, 6, 1, 2] 1.0
# 26 [1, 1, 6, 2, 1] 1.0
# 27 [1, 1, 7, 1, 1] 1.0
# 28 [1, 2, 1, 1, 6] 1.0
# 29 [1, 2, 1, 2, 5] 1.0
# 30 [1, 2, 1, 3, 4] 1.0
# 31 [1, 2, 1, 4, 3] 1.0
# 32 [1, 2, 1, 5, 2] 1.0
# 33 [1, 2, 1, 6, 1] 1.0
# 34 [1, 2, 2, 1, 5] 1.0
# 35 [1, 2, 2, 2, 4] 1.0
# 36 [1, 2, 2, 3, 3] 1.0
# 37 [1, 2, 2, 4, 2] 1.0
# 38 [1, 2, 2, 5, 1] 1.0
# 39 [1, 2, 3, 1, 4] 1.0
# 425 [1, 4, 1, 1, 1] -4.0
# 426 [2, 1, 1, 1, 3] -4.0
# 427 [2, 1, 1, 2, 2] -4.0
# 428 [2, 1, 1, 3, 1] -4.0
# 429 [2, 1, 2, 1, 2] -4.0
# 430 [2, 1, 2, 2, 1] -4.0
# 431 [2, 1, 3, 1, 1] -4.0
# 432 [2, 2, 1, 1, 2] -4.0
# 433 [2, 2, 1, 2, 1] -4.0
# 434 [2, 2, 2, 1, 1] -4.0
# 435 [2, 3, 1, 1, 1] -4.0
# 436 [3, 1, 1, 1, 2] -4.0
# 437 [3, 1, 1, 2, 1] -4.0
# 438 [3, 1, 2, 1, 1] -4.0
# 439 [3, 2, 1, 1, 1] -4.0
# 440 [4, 1, 1, 1, 1] -4.0
# 441 [1, 1, 1, 1, 3] 1.0
# 442 [1, 1, 1, 2, 2] 1.0
# 443 [1, 1, 1, 3, 1] 1.0
# 444 [1, 1, 2, 1, 2] 1.0
# 445 [1, 1, 2, 2, 1] 1.0
# 446 [1, 1, 3, 1, 1] 1.0
# 447 [1, 2, 1, 1, 2] 1.0
# 448 [1, 2, 1, 2, 1] 1.0
# 449 [1, 2, 2, 1, 1] 1.0
# 450 [1, 3, 1, 1, 1] 1.0
# 451 [2, 1, 1, 1, 2] 1.0
# 452 [2, 1, 1, 2, 1] 1.0
# 453 [2, 1, 2, 1, 1] 1.0
# 454 [2, 2, 1, 1, 1] 1.0
# 455 [3, 1, 1, 1, 1] 1.0
# Finished refinement
# Refined  1  times
# max surplus error: 2.1119427747995232e-07 total surplus error: 0.03520377908220412
# combiintegral: 0.9555706816758565
# Current error: 0.03520377908220412
# Finished refinement
# Refined  5  times
# max surplus error: 1.8321360434581542e-07 total surplus error: 0.03240051761187085
# combiintegral: 0.9609465788368796
# Current error: 0.03240051761187085
# Finished refinement
# Refined  10  times
# max surplus error: 1.2428851397517745e-07 total surplus error: 0.026399750980393995
# combiintegral: 0.9691686843106765
# Current error: 0.026399750980393995
# Finished refinement
# Refined  10  times
# max surplus error: 8.940177780950946e-08 total surplus error: 0.021671022967761064
# combiintegral: 0.9740884736375126
# Current error: 0.021671022967761064
# Finished refinement
# Refined  1  times
# max surplus error: 5.656514425589667e-08 total surplus error: 0.0216027623893586
# combiintegral: 0.9741124756938059
# Current error: 0.0216027623893586
# New scheme
# 0 [1, 1, 1, 1, 8] 1.0
# 1 [1, 1, 1, 2, 7] 1.0
# 2 [1, 1, 1, 3, 6] 1.0
# 3 [1, 1, 1, 4, 5] 1.0
# 4 [1, 1, 1, 5, 4] 1.0
# 5 [1, 1, 1, 6, 3] 1.0
# 6 [1, 1, 1, 7, 2] 1.0
# 7 [1, 1, 1, 8, 1] 1.0
# 8 [1, 1, 2, 1, 7] 1.0
# 9 [1, 1, 2, 2, 6] 1.0
# 10 [1, 1, 2, 3, 5] 1.0
# 11 [1, 1, 2, 4, 4] 1.0
# 12 [1, 1, 2, 5, 3] 1.0
# 13 [1, 1, 2, 6, 2] 1.0
# 14 [1, 1, 2, 7, 1] 1.0
# 336 [1, 1, 1, 7, 1] -4.0
# 337 [1, 1, 2, 1, 6] -4.0
# 338 [1, 1, 2, 2, 5] -4.0
# 339 [1, 1, 2, 3, 4] -4.0
# 340 [1, 1, 2, 4, 3] -4.0
# 341 [1, 1, 2, 5, 2] -4.0
# 342 [1, 1, 2, 6, 1] -4.0
# 343 [1, 1, 3, 1, 5] -4.0
# 344 [1, 1, 3, 2, 4] -4.0
# 345 [1, 1, 3, 3, 3] -4.0
# 346 [1, 1, 3, 4, 2] -4.0
# 347 [1, 1, 3, 5, 1] -4.0
# 348 [1, 1, 4, 1, 4] -4.0
# 349 [1, 1, 4, 2, 3] -4.0
# 350 [1, 1, 4, 3, 2] -4.0
# 351 [1, 1, 4, 4, 1] -4.0
# 352 [1, 1, 5, 1, 3] -4.0
# 353 [1, 1, 5, 2, 2] -4.0
# 354 [1, 1, 5, 3, 1] -4.0
# 355 [1, 1, 6, 1, 2] -4.0
# 356 [1, 1, 6, 2, 1] -4.0
# 357 [1, 1, 7, 1, 1] -4.0
# 358 [1, 2, 1, 1, 6] -4.0
# 359 [1, 2, 1, 2, 5] -4.0
# 360 [1, 2, 1, 3, 4] -4.0
# 361 [1, 2, 1, 4, 3] -4.0
# 362 [1, 2, 1, 5, 2] -4.0
# 363 [1, 2, 1, 6, 1] -4.0
# 364 [1, 2, 2, 1, 5] -4.0
# 365 [1, 2, 2, 2, 4] -4.0
# 366 [1, 2, 2, 3, 3] -4.0
# 367 [1, 2, 2, 4, 2] -4.0
# 368 [1, 2, 2, 5, 1] -4.0
# 369 [1, 2, 3, 1, 4] -4.0
# 370 [1, 2, 3, 2, 3] -4.0
# 371 [1, 2, 3, 3, 2] -4.0
# 372 [1, 2, 3, 4, 1] -4.0
# 373 [1, 2, 4, 1, 3] -4.0
# 374 [1, 2, 4, 2, 2] -4.0
# 375 [1, 2, 4, 3, 1] -4.0
# 376 [1, 2, 5, 1, 2] -4.0
# 377 [1, 2, 5, 2, 1] -4.0
# 378 [1, 2, 6, 1, 1] -4.0
# 379 [1, 3, 1, 1, 5] -4.0
# 380 [1, 3, 1, 2, 4] -4.0
# 381 [1, 3, 1, 3, 3] -4.0
# 382 [1, 3, 1, 4, 2] -4.0
# 383 [1, 3, 1, 5, 1] -4.0
# 384 [1, 3, 2, 1, 4] -4.0
# 385 [1, 3, 2, 2, 3] -4.0
# 386 [1, 3, 2, 3, 2] -4.0
# 387 [1, 3, 2, 4, 1] -4.0
# 388 [1, 3, 3, 1, 3] -4.0
# 389 [1, 3, 3, 2, 2] -4.0
# 390 [1, 3, 3, 3, 1] -4.0
# 391 [1, 3, 4, 1, 2] -4.0
# 392 [1, 3, 4, 2, 1] -4.0
# 393 [1, 3, 5, 1, 1] -4.0
# 394 [1, 4, 1, 1, 4] -4.0
# 395 [1, 4, 1, 2, 3] -4.0
# 396 [1, 4, 1, 3, 2] -4.0
# 397 [1, 4, 1, 4, 1] -4.0
# 398 [1, 4, 2, 1, 3] -4.0
# 399 [1, 4, 2, 2, 2] -4.0
# 721 [3, 1, 1, 1, 3] -4.0
# 722 [3, 1, 1, 2, 2] -4.0
# 723 [3, 1, 1, 3, 1] -4.0
# 724 [3, 1, 2, 1, 2] -4.0
# 725 [3, 1, 2, 2, 1] -4.0
# 726 [3, 1, 3, 1, 1] -4.0
# 727 [3, 2, 1, 1, 2] -4.0
# 728 [3, 2, 1, 2, 1] -4.0
# 729 [3, 2, 2, 1, 1] -4.0
# 730 [3, 3, 1, 1, 1] -4.0
# 731 [4, 1, 1, 1, 2] -4.0
# 732 [4, 1, 1, 2, 1] -4.0
# 733 [4, 1, 2, 1, 1] -4.0
# 734 [4, 2, 1, 1, 1] -4.0
# 735 [5, 1, 1, 1, 1] -4.0
# 736 [1, 1, 1, 1, 4] 1.0
# 737 [1, 1, 1, 2, 3] 1.0
# 738 [1, 1, 1, 3, 2] 1.0
# 739 [1, 1, 1, 4, 1] 1.0
# 740 [1, 1, 2, 1, 3] 1.0
# 741 [1, 1, 2, 2, 2] 1.0
# 742 [1, 1, 2, 3, 1] 1.0
# 743 [1, 1, 3, 1, 2] 1.0
# 744 [1, 1, 3, 2, 1] 1.0
# 745 [1, 1, 4, 1, 1] 1.0
# 746 [1, 2, 1, 1, 3] 1.0
# 747 [1, 2, 1, 2, 2] 1.0
# 748 [1, 2, 1, 3, 1] 1.0
# 749 [1, 2, 2, 1, 2] 1.0
# 750 [1, 2, 2, 2, 1] 1.0
# 751 [1, 2, 3, 1, 1] 1.0
# 752 [1, 3, 1, 1, 2] 1.0
# 753 [1, 3, 1, 2, 1] 1.0
# 754 [1, 3, 2, 1, 1] 1.0
# 755 [1, 4, 1, 1, 1] 1.0
# 756 [2, 1, 1, 1, 3] 1.0
# 757 [2, 1, 1, 2, 2] 1.0
# 758 [2, 1, 1, 3, 1] 1.0
# 759 [2, 1, 2, 1, 2] 1.0
# 760 [2, 1, 2, 2, 1] 1.0
# 761 [2, 1, 3, 1, 1] 1.0
# 762 [2, 2, 1, 1, 2] 1.0
# 763 [2, 2, 1, 2, 1] 1.0
# 764 [2, 2, 2, 1, 1] 1.0
# 765 [2, 3, 1, 1, 1] 1.0
# 766 [3, 1, 1, 1, 2] 1.0
# 767 [3, 1, 1, 2, 1] 1.0
# 768 [3, 1, 2, 1, 1] 1.0
# 769 [3, 2, 1, 1, 1] 1.0
# 770 [4, 1, 1, 1, 1] 1.0
# Finished refinement
# Refined  6  times
# max surplus error: 5.656514425589667e-08 total surplus error: 0.020070430279092968
# combiintegral: 0.9756411119543502
# Current error: 0.020070430279092968
# Finished refinement
# Refined  5  times
# max surplus error: 4.043724720357547e-08 total surplus error: 0.018071577352235624
# combiintegral: 0.9790181561885245
# Current error: 0.018071577352235624
# Finished refinement
# Refined  10  times
# max surplus error: 2.4196081873294793e-08 total surplus error: 0.014441818229554503
# combiintegral: 0.9836105025399245
# Current error: 0.014441818229554503
# Finished refinement
# Refined  10  times

# %%
dim = 3
a = np.zeros(dim)
b = np.ones(dim)
grid = TrapezoidalGrid(a, b, dim)

f = FunctionGriebel()
operation = Integration(f=f, grid=grid, dim=dim, reference_solution = reference_solution)
#f = Function2Jakeman(midpoints,coefficients)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, version=0, no_initial_splitting=False, automatic_extend_split=False, split_single_dim=False, operation=operation)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, version=0, no_initial_splitting=False, automatic_extend_split=True, split_single_dim=False, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 split=0'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 automatic_split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 3, dim, 9, grid, 1, 5)

# %%
#New min
dim = 3
a = np.zeros(dim)
b = np.ones(dim)
grid = TrapezoidalGrid(a, b, dim)

f = FunctionGriebel()
operation = Integration(f=f, grid=grid, dim=dim)
#f = Function2Jakeman(midpoints,coefficients)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 split=0'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 automatic_split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 3, dim, 9, grid, 1, 5)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=TrapezoidalGrid(a, b, dim)
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 5, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=False)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0, automatic_extend_split=False, split_single_dim=False)

algorithmArray = [(adaptiveCombiInstanceExtend,1,2, errorOperator,'Extend scheme min=1 max=2 Split=3'),(adaptiveCombiInstanceExtend2,1,2, errorOperator2,'Extend scheme min=1 max=2 Automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 4, dim, 7, grid, 1, 6)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=TrapezoidalGrid(a, b, dim)
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 5, grid, no_initial_splitting=False, version=0, automatic_extend_split=True, split_single_dim=False)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0, automatic_extend_split=False, split_single_dim=False)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=3'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 3, dim, 7, grid, 1, 6)

# %%
#New min
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=TrapezoidalGrid(a, b, dim)
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 5, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=3'),(adaptiveCombiInstanceExtend2,1 , 2, errorOperator,'Extend scheme min=1 max=2 Automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 3, dim, 7, grid, 1, 6)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=TrapezoidalGrid(a, b, dim)
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzCornerPeak(coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 2, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=3'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 2, dim, 6, grid, 1, 6)

# %%
#New min
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=TrapezoidalGrid(a, b, dim)
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzCornerPeak(coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 2, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=3'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 2, dim, 7, grid, 1, 6)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=TrapezoidalGrid(a, b, dim)
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ float(10**1) * (d+1) for d in range(dim)])
f = GenzProductPeak(midpoint=midpoint,coefficients=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=3'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 1, dim, 8, grid, 1, 6)

# %%
#New min
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=TrapezoidalGrid(a, b, dim)
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ float(10**1) * (d+1) for d in range(dim)])
f = GenzProductPeak(midpoint=midpoint,coefficients=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=3'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 1, dim, 8, grid, 1, 6)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=TrapezoidalGrid(a, b, dim)
midpoint = np.ones(dim) * 0.2
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=3'), (adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Automatic split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 2, dim, 7, grid, 1, 5)

# %%
#New min
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=TrapezoidalGrid(a, b, dim)
midpoint = np.ones(dim) * 0.2
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=3'), (adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Automatic split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 3, dim, 9, grid, 1, 5)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
print(np.inner([],[]))
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**1.2 * (d+1) for d in range(dim)])
grid=TrapezoidalGrid(a, b, dim, boundary=False)
f = GenzC0(midpoint=midpoint, coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 4, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 4, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split = 4'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 1, dim, 7, grid, 1, 6, minTol=-3)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
print(np.inner([],[]))
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**1.2 * (d+1) for d in range(dim)])
grid=TrapezoidalGrid(a, b, dim, boundary=False)
f = GenzC0(midpoint=midpoint, coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 4 , grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 4, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split = 4'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 1, dim, 9, grid, 1, 6, minTol=-3)

# %%
#New min
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
print(np.inner([],[]))
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
grid=TrapezoidalGrid(a, b, dim, boundary=False)
f = GenzC0(midpoint=midpoint, coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 4, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 4, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split = 4'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 1, dim, 9, grid, 1, 6, minTol=-3)

# %%
#New min
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
print(np.inner([],[]))
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
grid=TrapezoidalGrid(a, b, dim, boundary=False)
f = GenzC0(midpoint=midpoint, coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 4, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 4, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split = 4'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 2, dim, 10, grid, 1, 6, minTol=-3)

# %%
#TODO: Modify?
#results for C0 Test-case
x_standard_1 = [11, 71, 351, 1471, 5503, 18943, 61183, 187903] 
err_standard_1 = [16644.069661617246, 2019.7849757319057, 4415.4947531629914, 3310.5334984239789, 734.485252984201, 520.16776756062552, 617.33525472331837, 344.3441234481383]
x_standard_2 = [1863, 9423, 38943, 142143, 476287] 
err_standard_2 = [488.8113728567173, 75.533433881051792, 90.751153944018412, 60.369886363400823, 13.659214245315066]
x_standard_3 = [112847, 524447] 
err_standard_3 = [15.017241075346963, 4.2430812802970932]
x_adaptive_auto = [11, 1863, 2103, 2343, 2643, 3195, 7829, 8919, 11397, 11561, 12909, 13385, 13757, 13885, 13937, 13959, 20864, 58305, 58317, 60289, 67335, 67717, 68099, 68321, 68901, 91522, 110193, 113669, 114257, 115807, 122927, 149639, 149753, 169789, 170731, 171143, 172173, 215045, 216045, 218177, 228867, 288411, 288567, 292249] 
err_adaptive_auto = [16644.069661617239, 488.81137285671804, 476.87123191339845, 464.93109097007886, 441.05080908343967, 393.29024531016137, 361.26980463405124, 335.35448305004451, 305.36908207130233, 257.60851829802402, 253.53843890328866, 251.503399205921, 249.46835950855331, 201.70779573527503, 176.06505514533802, 152.18477325869893, 95.517981021003948, 20.860601411087838, 3.0196804755512661, 7.124273928551256, 9.5039459121876479, 11.538985609555532, 11.722037300604477, 11.905088991653422, 13.975668430627591, 8.0433411967425812, 0.40469951595628412, 0.77934313837599178, 2.8701951620983679, 2.9348554282847226, 3.1466102172195161, 3.3984275894655216, 3.4042881779168184, 3.4463369842614959, 3.52898306638353, 3.6203351343443031, 3.6647228157824729, 5.7054671414552711, 5.7303055805116285, 5.8205176315242095, 4.5003099294144517, 0.29233593366737048, 0.2212564504547811, 0.0034321453354958509]
err_surplus_auto = [16643.069661617243, 1256.4020891753898, 1036.8361805038594, 817.27027183232872, 752.72594524518513, 663.12867629473158, 505.63852025462427, 466.23586235464131, 402.2251080856152, 391.80993743153618, 363.53537962377254, 351.4897371973845, 341.16051675182752, 357.84046750127482, 366.30924601195863, 380.3351554320414, 387.82961510354733, 138.7634163045781, 157.04212816765218, 134.71437365244358, 100.29949908714428, 98.272149665579349, 96.650256894020075, 95.810363298611719, 94.032001469640051, 75.137656423517043, 44.269333265492207, 39.962092170445771, 38.087580158590221, 36.423067762183528, 33.378006739437119, 24.211414830827607, 24.042264793765924, 20.865405530379306, 19.512399295602176, 18.964106883385536, 18.812976398401393, 14.101272080884822, 13.79984488932428, 13.364688376699098, 13.427798335601068, 13.696286197965311, 13.666293291027527, 13.471832977581952]

plt.loglog(x_standard_1,err_standard_1, label="Standard Combi lmin=1")
plt.loglog(x_standard_2,err_standard_2, label="Standard Combi lmin=2")
plt.loglog(x_standard_3,err_standard_3, label="Standard Combi lmin=3")
plt.loglog(x_adaptive_split,err_adaptive_split, label="Extend-Split depth=4")
plt.loglog(x_adaptive_split,err_surplus_split, label="Extend-Split depth=4 surplusses")
plt.loglog(x_adaptive_auto,err_adaptive_auto, label="Extend-Split auto")
plt.loglog(x_adaptive_auto,err_surplus_auto, label="Extend-Split auto surplusses")
plt.legend()
plt.show()

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
grid=GaussLegendreGrid(a, b, dim=dim)
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, no_initial_splitting=False, version=0)
adaptiveCombiInstanceExtend3 = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 2, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Optimized Split=2'), (adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Optimized Split=0'), (adaptiveCombiInstanceExtend3, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Optimized Split=1')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 9, dim, 8, grid, 1, 3)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
grid=GaussLegendreGrid(a, b, dim=dim)
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, no_initial_splitting=False, version=0)
adaptiveCombiInstanceExtend3 = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 2, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Optimized Split=1')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 11, dim, 8, grid, 1, 3)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
grid=TrapezoidalGrid()
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
f.plot(a, b)

errorOperator = ErrorCalculatorAnalyticCell()
errorOperator2 = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptivExtendScheme(a, b, 5, grid, no_initial_splitting=False)
adaptiveCombiInstanceExtend = SpatiallyAdaptivExtendScheme(a, b, 2, grid, no_initial_splitting=False, automatic_extend_split=True)
adaptiveCombiInstanceCell = SpatiallyAdaptivCellScheme(a, b, grid)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator2, 'Extend scheme min=1 max=2 Optimized'),(adaptiveCombiInstanceCell, 3, 3, errorOperator, 'Cell scheme min=1 max=2 Optimized')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, errorOperator, 7, dim, 15, grid, 1, 6)

# %%
#Necessary?
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
grid=TrapezoidalGrid()
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
f.plot(a, b)

errorOperator = ErrorCalculatorAnalyticCell()

adaptiveCombiInstanceCell = SpatiallyAdaptivCellScheme(a, b, grid)

algorithmArray = [(adaptiveCombiInstanceCell, 1, 1, errorOperator, 'Cell scheme min=1 max=2 Optimized')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, errorOperator, 8, dim, 10, grid, 1, 6)

# %%
#Necessary?
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
grid = GaussLegendreGrid(a, b, dim)
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
f.plot(a, b)

errorOperator = ErrorCalculatorAnalyticCell()
errorOperator2 = ErrorCalculatorAnalytic()

adaptiveCombiInstanceExtend = SpatiallyAdaptivExtendScheme(a, b, 2, grid, no_initial_splitting=False, automatic_extend_split=True)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator2,'Extend scheme min=1 max=2 Optimized')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, errorOperator, 9, dim, 8, grid, 1, 6)

# %%
#New min
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
grid = GaussLegendreGrid(a, b, dim)
f = Function2Jakeman(midpoints,coefficients)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 5, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 2, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator,'Extend scheme min=1 max=2 Split=2'),(adaptiveCombiInstanceExtend2, 1, 2, errorOperator,'Extend scheme min=1 max=2 Automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 8, dim, 9, grid, 1, 6)

# %%
#New min
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
grid = GaussLegendreGrid(a, b, dim)
f = GenzCornerPeak(coeffs=coefficients)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 2, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=1'), (adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 6, dim, 8, grid, 1, 6)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
grid=GaussLegendreGrid(a, b, dim)
f = GenzC0(midpoint=midpoint,coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 4, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Optimized')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 2, dim, 8, grid, 1, 6, minTol=-3)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
grid=GaussLegendreGrid(a, b, dim)
f = GenzC0(midpoint=midpoint,coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator=ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 4, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Automatic Split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 1, dim, 8, grid, 1, 6, minTol=-3)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.2
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
grid=GaussLegendreGrid(a, b, dim)
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend,1,2, errorOperator,'Extend scheme min=1 max=2 Automatic split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 2, dim, 7, grid, 1, 5)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.2
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
grid=GaussLegendreGrid(a, b, dim)
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0)

algorithmArray = [(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Automatic split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 1, dim, 7, grid, 1, 5)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
grid=GaussLegendreGrid(a, b, dim)
f = FunctionGriebel()
#f = Function2Jakeman(midpoints,coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)


errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, no_initial_splitting=False, version=0, automatic_extend_split=False)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 0, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)

algorithmArray = [(adaptiveCombiInstanceExtend,1,2, errorOperator, 'Extend scheme min=1 max=2 split=0'),(adaptiveCombiInstanceExtend2,1,2, errorOperator, 'Extend scheme min=1 max=2 automatic_split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 4, dim, 8, grid, 1, 3)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ float(10**1) * (d+1) for d in range(dim)])
grid=GaussLegendreGrid(a, b, dim)
f = GenzProductPeak(midpoint=midpoint, coefficients=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0, automatic_extend_split=False)

algorithmArray = [(adaptiveCombiInstanceExtend, 1, 2, errorOperator, 'Extend scheme min=1 max=2 Split=4')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 3, dim, 8, grid, 1, 6)

# %%
dim = 5
a = np.zeros(dim)
b = np.ones(dim)
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ float(10**1) * (d+1) for d in range(dim)])
grid=GaussLegendreGrid(a, b, dim)
f = GenzProductPeak(midpoint=midpoint, coefficients=coefficients)
operation = Integration(f=f, grid=grid, dim=dim)
f.plot(a, b)

errorOperator = ErrorCalculatorExtendSplit()

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(a, b, 3, grid, no_initial_splitting=False, version=0, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, 1, grid, no_initial_splitting=False, version=0, automatic_extend_split=False)

algorithmArray = [(adaptiveCombiInstanceExtend2, 1, 2, errorOperator, 'Extend scheme min=1 max=2 automatic split')]
performTestcaseArbitraryDim(f, a, b, algorithmArray, 2, dim, 8, grid, 1, 6)
