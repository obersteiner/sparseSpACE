# %% [markdown]
# ## SGA-Figures

# %% [markdown]
# # Block adaptive Full grid

# %%
# %matplotlib inline
import numpy as np
from spatiallyAdaptiveExtendSplit import *
from Function import *
from ErrorCalculator import *

# dimensionality of problem
dim = 2

# integration boundaries
a = np.zeros(dim)
b = np.ones(dim)

# define function
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
# plot function
f.plot(np.ones(dim)*a,np.ones(dim)*b)

# error estimator
errorOperator=ErrorCalculatorExtendSplit()

# used grid
grid=TrapezoidalGrid(a=a, b=b, dim=dim)

# initialize Extend-Split Strategy
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, number_of_refinements_before_extend=2,grid=grid,version=0)

# reference solution for the integration
reference_solution = f.getAnalyticSolutionIntegral(a,b)

# perform spatially adaptive integration
adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(minv=1,maxv=1,f=f,errorOperator=errorOperator,tol=2*10**-1, do_plot=True, reference_solution=reference_solution)
# Out:
# Reference solution: 0.124360029632
# 0 [1, 1] 1.0
# max surplus error: 0.01953125 total surplus error: 0.078125
# combiintegral: 0.0625
# Current error: 0.497426945098
# Finished refinement
# Refinement Graph:
# Combi Scheme:
# Resulting Sparse Grid:
# max surplus error: 0.00237382029502 total surplus error: 0.0259395171333
# combiintegral: 0.0884395171333
# Current error: 0.288842907203
# Finished refinement
# Refinement Graph:
# Combi Scheme:
# Resulting Sparse Grid:
# max surplus error: 0.00195768490552 total surplus error: 0.0172948504987
# combiintegral: 0.0875889025879
# Current error: 0.295682842414
# Finished refinement
# Refinement Graph:
# Combi Scheme:
# Resulting Sparse Grid:
# max surplus error: 0.00128475473615 total surplus error: 0.0155827309665
# combiintegral: 0.0946549479902
# Current error: 0.238863578031
# Finished refinement
# Refinement Graph:
# Combi Scheme:
# Resulting Sparse Grid:
# max surplus error: 0.000868619346645 total surplus error: 0.0143664516759
# ...

# %%
adaptiveCombiInstanceExtend.print_resulting_sparsegrid("block_adaptive_grid.svg")
adaptiveCombiInstanceExtend.print_resulting_sparsegrid("block_adaptive_grid.pdf")

# %% [markdown]
# # Split

# %%
# %matplotlib inline
import numpy as np
from spatiallyAdaptiveExtendSplit import *
from Function import *
from ErrorCalculator import *

# dimensionality of problem
dim = 2

# integration boundaries
a = np.zeros(dim)
b = np.ones(dim)

# define function
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
# plot function
f.plot(np.ones(dim)*a,np.ones(dim)*b)

# error estimator
errorOperator=ErrorCalculatorExtendSplit()

# used grid
grid=TrapezoidalGrid(a=a, b=b, dim=dim)

# initialize Extend-Split Strategy
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, number_of_refinements_before_extend=2,grid=grid,version=0)

# reference solution for the integration
reference_solution = f.getAnalyticSolutionIntegral(a,b)

# perform spatially adaptive integration
adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(minv=1,maxv=2,f=f,errorOperator=errorOperator,tol=2*10**-0, do_plot=True, reference_solution=reference_solution)
# Out:
# Reference solution: 0.124360029632
# 0 [1, 2] 1.0
# 1 [2, 1] 1.0
# 2 [1, 1] -1.0
# max surplus error: 0.00496352689675 total surplus error: 0.039708215174
# combiintegral: 0.086583215174
# Current error: 0.303769744748
# Number of refinements 0
# (<RefinementContainer.RefinementContainer at 0x7f949bfe1da0>,
#  [(array([1, 2]), 1.0), (array([2, 1]), 1.0), (array([1, 1]), -1.0)],
#  [2, 2],
#  0.086583215174002415,
#  32.0,
#  [0.30376974474763407],
#  [21],
#  [0.31930046407554302])

# %%
adaptiveCombiInstanceExtend.print_resulting_combi_scheme("standard_combi.pdf")
adaptiveCombiInstanceExtend.print_resulting_sparsegrid("standard_sparse_grid.pdf")
adaptiveCombiInstanceExtend.print_resulting_combi_scheme("standard_combi.svg")
adaptiveCombiInstanceExtend.print_resulting_sparsegrid("standard_sparse_grid.svg")

# %%
adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(minv=1,maxv=2,f=f,errorOperator=errorOperator,tol=2*10**-1, do_plot=True, reference_solution=reference_solution)
# Out:
# Reference solution: 0.124360029632
# 0 [1, 2] 1.0
# 1 [2, 1] 1.0
# 2 [1, 1] -1.0
# max surplus error: 0.00496352689675 total surplus error: 0.039708215174
# combiintegral: 0.086583215174
# Current error: 0.303769744748
# Finished refinement
# Refinement Graph:
# Combi Scheme:
# Resulting Sparse Grid:
# max surplus error: 0.000668116678629 total surplus error: 0.0106642128874
# combiintegral: 0.104281572115
# Current error: 0.161454267715
# Number of refinements 1
# (<RefinementContainer.RefinementContainer at 0x7f949d0b44e0>,
#  [(array([1, 2]), 1.0), (array([2, 1]), 1.0), (array([1, 1]), -1.0)],
#  [2, 2],
#  0.1042815721148615,
#  56.0,
#  [0.30376974474763407, 0.16145426771529511],
#  [21, 34],
#  [0.31930046407554302, 0.085752736782988004])

# %%
adaptiveCombiInstanceExtend.print_resulting_combi_scheme("combi_split.pdf")
adaptiveCombiInstanceExtend.print_resulting_sparsegrid("sparse_grid_split.pdf")
adaptiveCombiInstanceExtend.print_resulting_combi_scheme("combi_split.svg")
adaptiveCombiInstanceExtend.print_resulting_sparsegrid("sparse_grid_split.svg")

# %%
adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(minv=1,maxv=2,f=f,errorOperator=errorOperator,tol=1.6*10**-1, do_plot=True, reference_solution=reference_solution)
# Out:
# Reference solution: 0.124360029632
# 0 [1, 2] 1.0
# 1 [2, 1] 1.0
# 2 [1, 1] -1.0
# max surplus error: 0.00496352689675 total surplus error: 0.039708215174
# combiintegral: 0.086583215174
# Current error: 0.303769744748
# Finished refinement
# Refinement Graph:
# Combi Scheme:
# Resulting Sparse Grid:
# max surplus error: 0.000668116678629 total surplus error: 0.0106642128874
# combiintegral: 0.104281572115
# Current error: 0.161454267715
# Finished refinement
# Refinement Graph:
# Combi Scheme:
# Resulting Sparse Grid:
# max surplus error: 0.000317277544934 total surplus error: 0.00834091229738
# combiintegral: 0.108374607658
# Current error: 0.128541477688
# Number of refinements 2
# (<RefinementContainer.RefinementContainer at 0x7f949d6aeac8>,
#  [(array([1, 2]), 1.0), (array([2, 1]), 1.0), (array([1, 1]), -1.0)],
#  [2, 2],
#  0.10837460765796411,
#  80.0,
#  [0.30376974474763407, 0.16145426771529511, 0.12854147768775417],
#  [21, 34, 47],
# ...

# %%
adaptiveCombiInstanceExtend.print_resulting_combi_scheme("combi_split2.pdf")
adaptiveCombiInstanceExtend.print_resulting_sparsegrid("sparse_grid_split2.pdf")
adaptiveCombiInstanceExtend.print_resulting_combi_scheme("combi_split2.svg")
adaptiveCombiInstanceExtend.print_resulting_sparsegrid("sparse_grid_split2.svg")

# %% [markdown]
# # Extend

# %%
# %matplotlib inline
import numpy as np
from spatiallyAdaptiveExtendSplit import *
from Function import *
from ErrorCalculator import *

# dimensionality of problem
dim = 2

# integration boundaries
a = np.zeros(dim)
b = np.ones(dim)

# define function
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
# plot function
f.plot(np.ones(dim)*a,np.ones(dim)*b)

# error estimator
errorOperator=ErrorCalculatorExtendSplit()

# used grid
grid=TrapezoidalGrid(a=a, b=b, dim=dim)

# initialize Extend-Split Strategy
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, number_of_refinements_before_extend=0,grid=grid,version=0)

# reference solution for the integration
reference_solution = f.getAnalyticSolutionIntegral(a,b)

# perform spatially adaptive integration
adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(minv=1,maxv=2,f=f,errorOperator=errorOperator,tol=2*10**-1, do_plot=True, reference_solution=reference_solution)
# Out:
# Reference solution: 0.124360029632
# 0 [1, 2] 1.0
# 1 [2, 1] 1.0
# 2 [1, 1] -1.0
# max surplus error: 0.00496352689675 total surplus error: 0.039708215174
# combiintegral: 0.086583215174
# Current error: 0.303769744748
# New scheme
# 0 [1, 3] 1.0
# 1 [2, 2] 1.0
# 2 [3, 1] 1.0
# 3 [1, 2] -1.0
# 4 [2, 1] -1.0
# Finished refinement
# Refinement Graph:
# Combi Scheme:
# Resulting Sparse Grid:
# max surplus error: 0.000909970104967 total surplus error: 0.0154694917844
# combiintegral: 0.102052706958
# Current error: 0.179376948845
# Number of refinements 1
# (<RefinementContainer.RefinementContainer at 0x7f949d116c50>,
#  [(array([1, 3]), 1.0),
#   (array([2, 2]), 1.0),
#   (array([3, 1]), 1.0),
#   (array([1, 2]), -1.0),
#   (array([2, 1]), -1.0)],
#  [3, 3],
#  0.10205270695843802,
#  41.0,
#  [0.30376974474763407, 0.17937694884536443],
#  [21, 30],
#  [0.31930046407554302, 0.12439279590226962])

# %%
adaptiveCombiInstanceExtend.print_resulting_combi_scheme("combi_extend.pdf")
adaptiveCombiInstanceExtend.print_resulting_sparsegrid("sparse_grid_extend.pdf")
adaptiveCombiInstanceExtend.print_resulting_combi_scheme("combi_extend.svg")
adaptiveCombiInstanceExtend.print_resulting_sparsegrid("sparse_grid_extend.svg")
