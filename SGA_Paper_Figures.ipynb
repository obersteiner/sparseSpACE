# %% [markdown]
# ## SGA-Figures

# %% [markdown]
# # Block adaptive Full grid

# %%
# %matplotlib inline
import numpy as np
from spatiallyAdaptiveExtendSplit import *
from Function import *
from ErrorCalculator import *

# dimensionality of problem
dim = 2

# integration boundaries
a = np.zeros(dim)
b = np.ones(dim)

# define function
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
# plot function
f.plot(np.ones(dim)*a,np.ones(dim)*b)

# error estimator
errorOperator=ErrorCalculatorExtendSplit()

# used grid
grid=TrapezoidalGrid(a=a, b=b, dim=dim)

# initialize Extend-Split Strategy
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, number_of_refinements_before_extend=2,grid=grid,version=0)

# reference solution for the integration
reference_solution = f.getAnalyticSolutionIntegral(a,b)

# perform spatially adaptive integration
adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(minv=1,maxv=1,f=f,errorOperator=errorOperator,tol=2*10**-1, do_plot=True, reference_solution=reference_solution)
# Out:
# Reference solution: 0.124360029632
# 0 [1, 1] 1.0
# max surplus error: 0.046875 total surplus error: 0.1875
# combiintegral: 0.0625
# Current error: 0.497426945098
# Finished refinement
# Refinement Graph:
# Combi Scheme:
# Resulting Sparse Grid:
# max surplus error: 0.00488737240552 total surplus error: 0.0616364547732
# combiintegral: 0.0884395171333
# Current error: 0.288842907203
# Finished refinement
# Refinement Graph:
# Combi Scheme:
# Resulting Sparse Grid:
# max surplus error: 0.00421444223615 total surplus error: 0.0407572047339
# combiintegral: 0.0946549479902
# Current error: 0.238863578031
# Finished refinement
# Refinement Graph:
# Combi Scheme:
# Resulting Sparse Grid:
# max surplus error: 0.00184518184664 total surplus error: 0.0323610325875
# combiintegral: 0.099271242077
# Current error: 0.201743177686
# Finished refinement
# Refinement Graph:
# Combi Scheme:
# Resulting Sparse Grid:
# max surplus error: 0.00119389717511 total surplus error: 0.0330521981421
# combiintegral: 0.104939184002
# Current error: 0.156166299471
# Number of refinements 5
# (<RefinementContainer.RefinementContainer at 0x7f0e51b50d68>,
#  [(array([1, 1]), 1.0)],
#  [1, 1],
#  0.10493918400242849,
#  76.0,
#  [0.49742694509756946,
#   0.28884290720342765,
#   0.23886357803081862,
#   0.20174317768647229,
#   0.15616629947089994],
#  [9, 14, 23, 27, 30])

# %%
adaptiveCombiInstanceExtend.print_resulting_sparsegrid()

# %% [markdown]
# # Split

# %%
# %matplotlib inline
import numpy as np
from spatiallyAdaptiveExtendSplit import *
from Function import *
from ErrorCalculator import *

# dimensionality of problem
dim = 2

# integration boundaries
a = np.zeros(dim)
b = np.ones(dim)

# define function
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
# plot function
f.plot(np.ones(dim)*a,np.ones(dim)*b)

# error estimator
errorOperator=ErrorCalculatorExtendSplit()

# used grid
grid=TrapezoidalGrid(a=a, b=b, dim=dim)

# initialize Extend-Split Strategy
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, number_of_refinements_before_extend=2,grid=grid,version=0)

# reference solution for the integration
reference_solution = f.getAnalyticSolutionIntegral(a,b)

# perform spatially adaptive integration
adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(minv=1,maxv=2,f=f,errorOperator=errorOperator,tol=2*10**-0, do_plot=True, reference_solution=reference_solution)
# Out:
# Reference solution: 0.124360029632
# 0 [1, 2] 1.0
# 1 [2, 1] 1.0
# 2 [1, 1] -1.0
# max surplus error: 0.0108229018968 total surplus error: 0.086583215174
# combiintegral: 0.086583215174
# Current error: 0.303769744748
# Number of refinements 0
# (<RefinementContainer.RefinementContainer at 0x7f0e527e1438>,
#  [(array([1, 2]), 1.0), (array([2, 1]), 1.0), (array([1, 1]), -1.0)],
#  [2, 2],
#  0.086583215174002415,
#  32.0,
#  [0.30376974474763407],
#  [21])

# %%
adaptiveCombiInstanceExtend.print_resulting_combi_scheme()
adaptiveCombiInstanceExtend.print_resulting_sparsegrid()

# %%
adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(minv=1,maxv=2,f=f,errorOperator=errorOperator,tol=2*10**-1, do_plot=True, reference_solution=reference_solution)
# Out:
# Reference solution: 0.124360029632
# 0 [1, 2] 1.0
# 1 [2, 1] 1.0
# 2 [1, 1] -1.0
# max surplus error: 0.0108229018968 total surplus error: 0.086583215174
# combiintegral: 0.086583215174
# Current error: 0.303769744748
# Finished refinement
# Refinement Graph:
# Combi Scheme:
# Resulting Sparse Grid:
# max surplus error: 0.00153269816572 total surplus error: 0.0176983569409
# combiintegral: 0.104281572115
# Current error: 0.161454267715
# Number of refinements 1
# (<RefinementContainer.RefinementContainer at 0x7f0e54447fd0>,
#  [(array([1, 2]), 1.0), (array([2, 1]), 1.0), (array([1, 1]), -1.0)],
#  [2, 2],
#  0.1042815721148615,
#  56.0,
#  [0.30376974474763407, 0.16145426771529511],
#  [21, 34])

# %%
adaptiveCombiInstanceExtend.print_resulting_combi_scheme()
adaptiveCombiInstanceExtend.print_resulting_sparsegrid()

# %%
adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(minv=1,maxv=2,f=f,errorOperator=errorOperator,tol=1.6*10**-1, do_plot=True, reference_solution=reference_solution)
# Out:
# Reference solution: 0.124360029632
# 0 [1, 2] 1.0
# 1 [2, 1] 1.0
# 2 [1, 1] -1.0
# max surplus error: 0.0108229018968 total surplus error: 0.086583215174
# combiintegral: 0.086583215174
# Current error: 0.303769744748
# Finished refinement
# Refinement Graph:
# Combi Scheme:
# Resulting Sparse Grid:
# max surplus error: 0.00153269816572 total surplus error: 0.0176983569409
# combiintegral: 0.104281572115
# Current error: 0.161454267715
# Finished refinement
# Refinement Graph:
# Combi Scheme:
# Resulting Sparse Grid:
# max surplus error: 0.000317277544934 total surplus error: 0.00952980715818
# combiintegral: 0.108374607658
# Current error: 0.128541477688
# Number of refinements 2
# (<RefinementContainer.RefinementContainer at 0x7f0e53eb7710>,
#  [(array([1, 2]), 1.0), (array([2, 1]), 1.0), (array([1, 1]), -1.0)],
#  [2, 2],
#  0.10837460765796411,
#  80.0,
#  [0.30376974474763407, 0.16145426771529511, 0.12854147768775417],
#  [21, 34, 47])

# %%
adaptiveCombiInstanceExtend.print_resulting_combi_scheme()
adaptiveCombiInstanceExtend.print_resulting_sparsegrid()

# %% [markdown]
# # Extend

# %%
# %matplotlib inline
import numpy as np
from spatiallyAdaptiveExtendSplit import *
from Function import *
from ErrorCalculator import *

# dimensionality of problem
dim = 2

# integration boundaries
a = np.zeros(dim)
b = np.ones(dim)

# define function
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
# plot function
f.plot(np.ones(dim)*a,np.ones(dim)*b)

# error estimator
errorOperator=ErrorCalculatorExtendSplit()

# used grid
grid=TrapezoidalGrid(a=a, b=b, dim=dim)

# initialize Extend-Split Strategy
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(a, b, number_of_refinements_before_extend=0,grid=grid,version=0)

# reference solution for the integration
reference_solution = f.getAnalyticSolutionIntegral(a,b)

# perform spatially adaptive integration
adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(minv=1,maxv=2,f=f,errorOperator=errorOperator,tol=2*10**-1, do_plot=True, reference_solution=reference_solution)
# Out:
# Reference solution: 0.124360029632
# 0 [1, 2] 1.0
# 1 [2, 1] 1.0
# 2 [1, 1] -1.0
# max surplus error: 0.0108229018968 total surplus error: 0.086583215174
# combiintegral: 0.086583215174
# Current error: 0.303769744748
# New scheme
# 0 [1, 3] 1.0
# 1 [2, 2] 1.0
# 2 [3, 1] 1.0
# 3 [1, 2] -1.0
# 4 [2, 1] -1.0
# Finished refinement
# Refinement Graph:
# Combi Scheme:
# Resulting Sparse Grid:
# max surplus error: 0.000909970104967 total surplus error: 0.0154694917844
# combiintegral: 0.102052706958
# Current error: 0.179376948845
# Number of refinements 1
# (<RefinementContainer.RefinementContainer at 0x7f0e53e0cb38>,
#  [(array([1, 3]), 1.0),
#   (array([2, 2]), 1.0),
#   (array([3, 1]), 1.0),
#   (array([1, 2]), -1.0),
#   (array([2, 1]), -1.0)],
#  [3, 3],
#  0.10205270695843802,
#  41.0,
#  [0.30376974474763407, 0.17937694884536443],
#  [21, 30])

# %%
adaptiveCombiInstanceExtend.print_resulting_combi_scheme()
adaptiveCombiInstanceExtend.print_resulting_sparsegrid()
