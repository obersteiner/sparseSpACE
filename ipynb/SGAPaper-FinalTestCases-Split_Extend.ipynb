# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sys import path
path.append('../src/')
#path.append('../../../src/tools')
import numpy as np

#from numpy import *
import scipy as sp
from spatiallyAdaptiveExtendSplit import *
from spatiallyAdaptiveSplit import *
from spatiallyAdaptiveSingleDimension2 import *
from spatiallyAdaptiveCell import *

from PerformTestCase import *
from Function import *
from ErrorCalculator import *
import math
dim = 5
a = 0
b = 1
grid=TrapezoidalGrid(np.ones(dim)*a, np.ones(dim)*b, modified_basis=False, boundary=True)
grid_single_dim = GlobalBSplineGrid(a=a*np.ones(dim), b=b*np.ones(dim), p=3, modified_basis=False, boundary=True)
grid_single_dim2 = GlobalLagrangeGrid(a=a*np.ones(dim), b=b*np.ones(dim), p=3, modified_basis=False, boundary=True)
grid_single_dim_lin = GlobalTrapezoidalGrid(a=a*np.ones(dim), b=b*np.ones(dim), modified_basis=False, boundary=True)

# %%
f = FunctionExpVar()
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCell()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()

reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
#adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, no_initial_splitting=False,version=0, automatic_extend_split=True)
from GridOperation import *
operationSingleDim = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceSingleDim = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=5, operation=operationSingleDim)
adaptiveCombiInstanceSingleDim2 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=3, operation=operationSingleDim2)
adaptiveCombiInstanceSingleDim3 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=5, operation=operationSingleDim, rebalancing=False)
adaptiveCombiInstanceSingleDim4 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=3, operation=operationSingleDim2, rebalancing=False)

#operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0, operation=operation, no_initial_splitting=False,version=0, automatic_extend_split=True)

adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0, operation=operation, no_initial_splitting=False,version=0)
#adaptiveCombiInstanceCell = SpatiallyAdaptiveCellScheme(np.ones(dim)*a, np.ones(dim)*b,grid, operation=operation)

algorithmArray = [(adaptiveCombiInstanceExtend,1,2, errorOperator2, 'Split extend automatic'),(adaptiveCombiInstanceExtend2,1,2, errorOperator2, 'Split extend')]
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,9,grid,1,4, max_evaluations=1000000)
# Out:
# Cannot plot function with dim > 2
# Exact integral 1.0
# Reference solution: 1.0
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# Curent number of function evaluations 1053
# max surplus error: 0.00012988770665130976 total surplus error: 0.28487189042138844
# combiintegral: 0.603350063259646
# Current error: 0.396649936740354
# New scheme
# 0 [1, 1, 1, 1, 3] 1.0
# 1 [1, 1, 1, 2, 2] 1.0
# 2 [1, 1, 1, 3, 1] 1.0
# 3 [1, 1, 2, 1, 2] 1.0
# 4 [1, 1, 2, 2, 1] 1.0
# 5 [1, 1, 3, 1, 1] 1.0
# 6 [1, 2, 1, 1, 2] 1.0
# 7 [1, 2, 1, 2, 1] 1.0
# 8 [1, 2, 2, 1, 1] 1.0
# 9 [1, 3, 1, 1, 1] 1.0
# 10 [2, 1, 1, 1, 2] 1.0
# 11 [2, 1, 1, 2, 1] 1.0
# 12 [2, 1, 2, 1, 1] 1.0
# 13 [2, 2, 1, 1, 1] 1.0
# 14 [3, 1, 1, 1, 1] 1.0
# 15 [1, 1, 1, 1, 2] -4.0
# 16 [1, 1, 1, 2, 1] -4.0
# 17 [1, 1, 2, 1, 1] -4.0
# 18 [1, 2, 1, 1, 1] -4.0
# 19 [2, 1, 1, 1, 1] -4.0
# 20 [1, 1, 1, 1, 1] 6.0
# Finished refinement
# ...

# %%
midpoints = np.ones(dim) * 0.99
coefficients = np.array([10**2 * (d+1) for d in range(dim)])
f = GenzGaussian(midpoints,coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCell()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()
reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

from GridOperation import *
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
operationSingleDim = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceSingleDim = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=5, operation=operationSingleDim)
adaptiveCombiInstanceSingleDim2 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=3, operation=operationSingleDim2)
adaptiveCombiInstanceSingleDim3 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=5, operation=operationSingleDim, rebalancing=False)
adaptiveCombiInstanceSingleDim4 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=3, operation=operationSingleDim2, rebalancing=False)

#adaptiveCombiInstanceFixed = SpatiallyAdaptiveFixedScheme(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,5,False, version=0, automatic_extend_split=True,operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,3,False,version=0, operation=operation)
#adaptiveCombiInstanceCell = SpatiallyAdaptiveCellScheme(np.ones(dim)*a, np.ones(dim)*b,grid)
algorithmArray = [(adaptiveCombiInstanceExtend,1,2, errorOperator2, 'Split extend automatic'),(adaptiveCombiInstanceExtend2,1,2, errorOperator2, 'Split extend')]
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,9,grid,1,4, max_evaluations=1000000)
# Out:
# Cannot plot function with dim > 2
# Exact integral 1.1714979705007044e-06
# Reference solution: 1.1714979705007044e-06
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# Curent number of function evaluations 1053
# max surplus error: 2.675973386502165e-05 total surplus error: 0.002997090193437723
# combiintegral: -0.001258118918969234
# Current error: 1074.9403316520534
# Finished refinement
# Refined  1  times
# Curent number of function evaluations 1994
# max surplus error: 9.168976438419604e-07 total surplus error: 0.00010415186799288235
# combiintegral: -2.9975607044895386e-05
# Current error: 26.587416965036358
# Finished refinement
# Refined  1  times
# Curent number of function evaluations 2935
# max surplus error: 3.072819572764197e-08 total surplus error: 7.773689093905743e-06
# combiintegral: 7.682388724900002e-07
# Current error: 0.3442251785023146
# Finished refinement
# ...

# %%
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzCornerPeak(coeffs=coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCellPunishDepth()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()
reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

from GridOperation import *
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
operationSingleDim = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceSingleDim = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=5, operation=operationSingleDim)
adaptiveCombiInstanceSingleDim2 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=3, operation=operationSingleDim2)
adaptiveCombiInstanceSingleDim3 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=5, operation=operationSingleDim, rebalancing=False)
adaptiveCombiInstanceSingleDim4 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=3, operation=operationSingleDim2, rebalancing=False)

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,2,False,version=0, automatic_extend_split=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,3,False,version=0,operation=operation)
#adaptiveCombiInstanceCell = SpatiallyAdaptiveCellScheme(np.ones(dim)*a, np.ones(dim)*b,grid)

algorithmArray = [(adaptiveCombiInstanceExtend,1,2, errorOperator2, 'Split extend automatic'),(adaptiveCombiInstanceExtend2,1,2, errorOperator2, 'Split extend')]
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,9,grid,1,4, max_evaluations=1000000)
# Out:
# Cannot plot function with dim > 2
# Exact integral 2.6025382796216128e-05
# Reference solution: 2.6025382796216128e-05
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# Curent number of function evaluations 1053
# max surplus error: 2.9195896998526303e-05 total surplus error: 0.004356986880583267
# combiintegral: -0.001281837023768704
# Current error: 50.253339856928925
# Finished refinement
# Refined  1  times
# Curent number of function evaluations 1994
# max surplus error: 6.778859492342732e-06 total surplus error: 0.0012461450196703206
# combiintegral: -0.00011870168662741205
# Current error: 5.560996760619032
# Finished refinement
# Refined  1  times
# Curent number of function evaluations 2686
# max surplus error: 1.8103432736066232e-06 total surplus error: 0.0005057440334456428
# combiintegral: -3.185762710933914e-05
# Current error: 2.224098310437569
# Finished refinement
# ...

# %%
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ float(10**1) * (d+1) for d in range(dim)])
f = GenzProductPeak(midpoint=midpoint,coefficients=coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCell()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()
reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

from GridOperation import *
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
operationSingleDim = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceSingleDim = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=5, operation=operationSingleDim)
adaptiveCombiInstanceSingleDim2 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=3, operation=operationSingleDim2)
adaptiveCombiInstanceSingleDim3 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=5, operation=operationSingleDim, rebalancing=False)
adaptiveCombiInstanceSingleDim4 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=3, operation=operationSingleDim2, rebalancing=False)

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,3,False,version=0,operation=operation,automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,3,False,version=0,operation=operation)
#adaptiveCombiInstanceCell = SpatiallyAdaptiveCellScheme(np.ones(dim)*a, np.ones(dim)*b,grid)

algorithmArray = [(adaptiveCombiInstanceExtend,1,2, errorOperator2, 'Split extend automatic'),(adaptiveCombiInstanceExtend2,1,2, errorOperator2, 'Split extend')]
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,9,grid,1,4, max_evaluations=1000000)
# Out:
# Cannot plot function with dim > 2
# Exact integral 2295.504403148864
# Reference solution: 2295.504403148864
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# Curent number of function evaluations 1053
# max surplus error: 26111.031354021852 total surplus error: 3210732.0237879064
# combiintegral: -1213724.237573469
# Current error: 529.7396686795894
# Finished refinement
# Refined  1  times
# Curent number of function evaluations 1994
# max surplus error: 1622.36475190095 total surplus error: 401249.1085586206
# combiintegral: -102007.29125906448
# Current error: 45.437854756077016
# Finished refinement
# Refined  1  times
# Curent number of function evaluations 2686
# max surplus error: 728.1813811368137 total surplus error: 224498.78272924447
# combiintegral: -57658.6043341029
# Current error: 26.118054339172495
# Finished refinement
# Refined  1  times
# ...

# %%
midpoint = np.ones(dim) * 0.2
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCell()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()
reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

from GridOperation import *
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
operationSingleDim = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceSingleDim = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=5, operation=operationSingleDim)
adaptiveCombiInstanceSingleDim2 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=3, operation=operationSingleDim2)
adaptiveCombiInstanceSingleDim3 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=5, operation=operationSingleDim, rebalancing=False)
adaptiveCombiInstanceSingleDim4 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=3, operation=operationSingleDim2, rebalancing=False)

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,1,False,version=0, operation=operation, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,3,False,version=0,operation=operation)
#adaptiveCombiInstanceCell = SpatiallyAdaptiveCellScheme(np.ones(dim)*a, np.ones(dim)*b,grid)

algorithmArray = [(adaptiveCombiInstanceExtend,1,2, errorOperator2, 'Split extend automatic'),(adaptiveCombiInstanceExtend2,1,2, errorOperator2, 'Split extend')]
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,9,grid,1,4, max_evaluations=1000000)
# Out:
# Cannot plot function with dim > 2
# Exact integral 7.821417442052503e-05
# Reference solution: 7.821417442052503e-05
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# Curent number of function evaluations 1053
# max surplus error: 3.106253487723214e-05 total surplus error: 0.00347900390625
# combiintegral: -0.00146484375
# Current error: 19.728622540003368
# Finished refinement
# Refined  1  times
# Curent number of function evaluations 1994
# max surplus error: 1.92175703121692e-06 total surplus error: 0.00021523678749629506
# combiintegral: 6.074154823848256e-05
# Current error: 0.22339462522610593
# Finished refinement
# Refined  1  times
# Curent number of function evaluations 2935
# max surplus error: 3.044370204738299e-08 total surplus error: 4.568167565634831e-05
# combiintegral: 0.00010642322389483092
# Current error: 0.36066415944810193
# Finished refinement
# Refined  1  times
# ...

# %%
grid=TrapezoidalGrid(np.ones(dim)*a, np.ones(dim)*b, modified_basis=False, boundary=False)

midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
f = GenzC0(midpoint=midpoint,coeffs=coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCell()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()
reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

from GridOperation import *
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
operationSingleDim = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceSingleDim = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=5, operation=operationSingleDim)
adaptiveCombiInstanceSingleDim2 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=3, operation=operationSingleDim2)
adaptiveCombiInstanceSingleDim3 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=5, operation=operationSingleDim, rebalancing=False)
adaptiveCombiInstanceSingleDim4 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=3, operation=operationSingleDim2, rebalancing=False)

adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,4,False,version=0, operation=operation, automatic_extend_split=True)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,4,False,version=0,operation=operation)
#adaptiveCombiInstanceCell = SpatiallyAdaptiveCellScheme(np.ones(dim)*a, np.ones(dim)*b,grid)

algorithmArray = [(adaptiveCombiInstanceExtend,1,2, errorOperator2, 'Split extend automatic'),(adaptiveCombiInstanceExtend2,1,2, errorOperator2, 'Split extend')]
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,9,grid,1,4, max_evaluations=1000000)
# Out:
# Cannot plot function with dim > 2
# Exact integral 2.6485777415603576e-06
# Reference solution: 2.6485777415603576e-06
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# Curent number of function evaluations 11
# max surplus error: 0.0002295857492551975 total surplus error: 0.0440804638569979
# combiintegral: -0.044080463856997834
# Current error: 16644.069661617217
# Finished refinement
# Refined  32  times
# Curent number of function evaluations 1863
# max surplus error: 9.229637748856776e-07 total surplus error: 0.004803335448608249
# combiintegral: -0.0012920063442282165
# Current error: 488.8113728566851
# Finished refinement
# Refined  32  times
# Curent number of function evaluations 16435
# max surplus error: 6.696219353535111e-07 total surplus error: 0.0016585309180387508
# combiintegral: -0.0001324541676623212
# Current error: 51.00954496592893
# Finished refinement
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sys import path
path.append('../src/')
#path.append('../../../src/tools')
import numpy as np

#from numpy import *
import scipy as sp
from spatiallyAdaptiveExtendSplit import *
from spatiallyAdaptiveSplit import *
from spatiallyAdaptiveSingleDimension2 import *
from spatiallyAdaptiveCell import *

from PerformTestCase import *
from Function import *
from ErrorCalculator import *
import math
dim = 5
a = 0
b = 1
grid=TrapezoidalGrid(np.ones(dim)*a, np.ones(dim)*b, modified_basis=False, boundary=True)
grid_single_dim = GlobalBSplineGrid(a=a*np.ones(dim), b=b*np.ones(dim), p=3, modified_basis=False, boundary=True, chebyshev=True)
grid_single_dim2 = GlobalLagrangeGrid(a=a*np.ones(dim), b=b*np.ones(dim), p=3, modified_basis=False, boundary=True)
grid_single_dim_lin = GlobalTrapezoidalGrid(a=a*np.ones(dim), b=b*np.ones(dim), modified_basis=False, boundary=True)

# %% [markdown]
# # Gauss-Legendre quadrature

# %%
#New min
a = 0
b = 1
dim = 5
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
f = GenzGaussian(midpoints,coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCell()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()
reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

grid=GaussLegendreGrid(np.ones(dim)*a, np.ones(dim)*b)
from GridOperation import *
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
operationSingleDim = Integration(f=f, grid=grid_single_dim, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,5,False, version=0, automatic_extend_split=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,2,False,version=0, operation=operation)
algorithmArray = [(adaptiveCombiInstanceExtend2,1,2, errorOperator2, 'Split extend automatic'),(adaptiveCombiInstanceExtend,1,2, errorOperator2, 'Split extend')]
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,7,grid,1,4, max_evaluations=1000000)
# Out:
# Cannot plot function with dim > 2
# Exact integral 1.1714979705007044e-06
# Reference solution: 1.1714979705007044e-06
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# Curent number of function evaluations 8704
# max surplus error: 3.86045857640262e-12 total surplus error: 3.360143144900841e-08
# combiintegral: 3.360143144900863e-08
# Current error: 0.9713175504395904
# Finished refinement
# Refined  32  times
# Curent number of function evaluations 288544
# max surplus error: 1.9405774654315619e-10 total surplus error: 1.6890786259144527e-06
# combiintegral: 1.7226800573634597e-06
# Current error: 0.4704934201697141
# Finished refinement
# Refined  32  times
# Curent number of function evaluations 568112
# max surplus error: 7.211109980860042e-11 total surplus error: 6.279070301161132e-07
# combiintegral: 1.0947742907269336e-06
# Current error: 0.06549194425064066
# New scheme
# ...

# %%
#New min
a = 0
b = 1
dim = 5
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzCornerPeak(coeffs=coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCellPunishDepth()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()

reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

grid=GaussLegendreGrid(np.ones(dim)*a, np.ones(dim)*b)
from GridOperation import *
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
operationSingleDim = Integration(f=f, grid=grid_single_dim, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,2,False, version=0, automatic_extend_split=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,1,False,version=0, operation=operation)
algorithmArray = [(adaptiveCombiInstanceExtend2,1,2, errorOperator2, 'Split extend automatic'),(adaptiveCombiInstanceExtend,1,2, errorOperator2, 'Split extend')]
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,7,grid,1,4, max_evaluations=1000000)
# Out:
# Cannot plot function with dim > 2
# Exact integral 2.6025382796216128e-05
# Reference solution: 2.6025382796216128e-05
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# Curent number of function evaluations 8704
# max surplus error: 5.780154391334133e-10 total surplus error: 5.031046382217227e-06
# combiintegral: 2.49804369017446e-05
# Current error: 0.040151028811128794
# Finished refinement
# Refined  32  times
# Curent number of function evaluations 288544
# max surplus error: 9.467322595013544e-11 total surplus error: 9.761856115050803e-07
# combiintegral: 2.5956622513247564e-05
# Current error: 0.0026420469395962353
# New scheme
# 0 [1, 1, 1, 1, 3] 1.0
# 1 [1, 1, 1, 2, 2] 1.0
# 2 [1, 1, 1, 3, 1] 1.0
# 3 [1, 1, 2, 1, 2] 1.0
# 4 [1, 1, 2, 2, 1] 1.0
# 5 [1, 1, 3, 1, 1] 1.0
# 6 [1, 2, 1, 1, 2] 1.0
# 7 [1, 2, 1, 2, 1] 1.0
# 8 [1, 2, 2, 1, 1] 1.0
# 9 [1, 3, 1, 1, 1] 1.0
# ...

# %%
a = 0
b = 1
dim = 5
midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
f = GenzC0(midpoint=midpoint,coeffs=coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCell()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()

reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

grid=GaussLegendreGrid(np.ones(dim)*a, np.ones(dim)*b)
from GridOperation import *
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
operationSingleDim = Integration(f=f, grid=grid_single_dim, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,4,False, version=0, automatic_extend_split=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,1,False,version=0, operation=operation)
algorithmArray = [(adaptiveCombiInstanceExtend2,1,2, errorOperator2, 'Split extend automatic'),(adaptiveCombiInstanceExtend,1,2, errorOperator2, 'Split extend')]
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,7,grid,1,4, max_evaluations=1000000)
# Out:
# Cannot plot function with dim > 2
# Exact integral 2.6485777415603576e-06
# Reference solution: 2.6485777415603576e-06
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# Curent number of function evaluations 8704
# max surplus error: 5.7712438684627365e-12 total surplus error: 5.023290663109964e-08
# combiintegral: 5.0233043318936685e-08
# Current error: 0.9810339554959248
# Finished refinement
# Refined  32  times
# Curent number of function evaluations 288544
# max surplus error: 4.961909944615476e-12 total surplus error: 1.3820308530538625e-06
# combiintegral: 1.4322638963727567e-06
# Current error: 0.4592328275291755
# Finished refinement
# Refined  1024  times
# Curent number of function evaluations 9234720
# max surplus error: 3.7247437210656045e-12 total surplus error: 1.1308488025894863e-06
# combiintegral: 2.5631126989630847e-06
# Current error: 0.032268277897300024
# ...

# %%
a = 0
b = 1
dim = 5
midpoint = np.ones(dim) * 0.2
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCell()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()

reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

grid=GaussLegendreGrid(np.ones(dim)*a, np.ones(dim)*b)
from GridOperation import *
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
operationSingleDim = Integration(f=f, grid=grid_single_dim, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,1,False, version=0, automatic_extend_split=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,3,False,version=0, operation=operation)
algorithmArray = [(adaptiveCombiInstanceExtend2,1,2, errorOperator2, 'Split extend automatic'),(adaptiveCombiInstanceExtend,1,2, errorOperator2, 'Split extend')]
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,7,grid,1,4, max_evaluations=1000000)
# Out:
# Cannot plot function with dim > 2
# Exact integral 7.821417442052503e-05
# Reference solution: 7.821417442052503e-05
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# Curent number of function evaluations 8704
# max surplus error: 1.7741492725692263e-08 total surplus error: 0.00015442195268442537
# combiintegral: -0.00015442195268442545
# Current error: 2.974347409897379
# New scheme
# 0 [1, 1, 1, 1, 3] 1.0
# 1 [1, 1, 1, 2, 2] 1.0
# 2 [1, 1, 1, 3, 1] 1.0
# 3 [1, 1, 2, 1, 2] 1.0
# 4 [1, 1, 2, 2, 1] 1.0
# 5 [1, 1, 3, 1, 1] 1.0
# 6 [1, 2, 1, 1, 2] 1.0
# 7 [1, 2, 1, 2, 1] 1.0
# 8 [1, 2, 2, 1, 1] 1.0
# 9 [1, 3, 1, 1, 1] 1.0
# 10 [2, 1, 1, 1, 2] 1.0
# 11 [2, 1, 1, 2, 1] 1.0
# 12 [2, 1, 2, 1, 1] 1.0
# 13 [2, 2, 1, 1, 1] 1.0
# 14 [3, 1, 1, 1, 1] 1.0
# 15 [1, 1, 1, 1, 2] -4.0
# 16 [1, 1, 1, 2, 1] -4.0
# 17 [1, 1, 2, 1, 1] -4.0
# 18 [1, 2, 1, 1, 1] -4.0
# 19 [2, 1, 1, 1, 1] -4.0
# ...

# %%
a = 0
b = 1
dim = 5
f = FunctionExpVar()
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCell()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()

reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

grid=GaussLegendreGrid(np.ones(dim)*a, np.ones(dim)*b)
from GridOperation import *
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
operationSingleDim = Integration(f=f, grid=grid_single_dim, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,False, version=0, automatic_extend_split=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,False,version=0, operation=operation)
algorithmArray = [(adaptiveCombiInstanceExtend2,1,2, errorOperator2, 'Split extend automatic'),(adaptiveCombiInstanceExtend,1,2, errorOperator2, 'Split extend')]
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,7,grid,1,4, max_evaluations=1000000)
# Out:
# Cannot plot function with dim > 2
# Exact integral 1.0
# Reference solution: 1.0
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# Curent number of function evaluations 8704
# max surplus error: 1.655362894444216e-06 total surplus error: 0.014408278633242455
# combiintegral: 1.0111939447481066
# Current error: 0.011193944748106643
# New scheme
# 0 [1, 1, 1, 1, 3] 1.0
# 1 [1, 1, 1, 2, 2] 1.0
# 2 [1, 1, 1, 3, 1] 1.0
# 3 [1, 1, 2, 1, 2] 1.0
# 4 [1, 1, 2, 2, 1] 1.0
# 5 [1, 1, 3, 1, 1] 1.0
# 6 [1, 2, 1, 1, 2] 1.0
# 7 [1, 2, 1, 2, 1] 1.0
# 8 [1, 2, 2, 1, 1] 1.0
# 9 [1, 3, 1, 1, 1] 1.0
# 10 [2, 1, 1, 1, 2] 1.0
# 11 [2, 1, 1, 2, 1] 1.0
# 12 [2, 1, 2, 1, 1] 1.0
# 13 [2, 2, 1, 1, 1] 1.0
# 14 [3, 1, 1, 1, 1] 1.0
# 15 [1, 1, 1, 1, 2] -4.0
# 16 [1, 1, 1, 2, 1] -4.0
# 17 [1, 1, 2, 1, 1] -4.0
# 18 [1, 2, 1, 1, 1] -4.0
# 19 [2, 1, 1, 1, 1] -4.0
# 20 [1, 1, 1, 1, 1] 6.0
# Finished refinement
# ...

# %%
a = 0
b = 1
dim = 5
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ float(10**1) * (d+1) for d in range(dim)])
f = GenzProductPeak(midpoint=midpoint,coefficients=coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCell()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()

reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

grid=GaussLegendreGrid(np.ones(dim)*a, np.ones(dim)*b)
from GridOperation import *
operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)
operationSingleDim = Integration(f=f, grid=grid_single_dim, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,3,False, version=0, automatic_extend_split=True, operation=operation)
adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,1,False,version=0, operation=operation)
algorithmArray = [(adaptiveCombiInstanceExtend2,1,2, errorOperator2, 'Split extend automatic'),(adaptiveCombiInstanceExtend,1,2, errorOperator2, 'Split extend')]
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,7,grid,1,4, max_evaluations=1000000)
# Out:
# Cannot plot function with dim > 2
# Exact integral 2295.504403148864
# Reference solution: 2295.504403148864
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# Curent number of function evaluations 8704
# max surplus error: 0.039783645344526934 total surplus error: 346.27684907876227
# combiintegral: 362.4064834484457
# Current error: 0.8421233769138872
# Finished refinement
# Refined  32  times
# Curent number of function evaluations 288544
# max surplus error: 0.21199283498185617 total surplus error: 2102.2260807895896
# combiintegral: 2464.6325491462667
# Current error: 0.07367798805587152
# Finished refinement
# Refined  32  times
# Curent number of function evaluations 568112
# max surplus error: 0.019456040326989613 total surplus error: 494.2371360495328
# combiintegral: 2686.01341689923
# Current error: 0.17011904364665298
# New scheme
# 0 [1, 1, 1, 1, 3] 1.0
# ...
