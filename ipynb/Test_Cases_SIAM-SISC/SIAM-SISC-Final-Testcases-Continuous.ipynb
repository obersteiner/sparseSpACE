# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sys import path
path.append('../../src/')
#path.append('../../../src/tools')
import numpy as np

#from numpy import *
import scipy as sp
from spatiallyAdaptiveExtendSplit import *
from spatiallyAdaptiveSingleDimension2 import *
from spatiallyAdaptiveCell import *

from PerformTestCase import *
from Function import *
from ErrorCalculator import *
from Utils import *
import math
dim = 5
a = 0
b = 1

# %%
grid_single_dim_lin = GlobalTrapezoidalGrid(a=a*np.ones(dim), b=b*np.ones(dim), modified_basis=False, boundary=False)
grid=TrapezoidalGrid(np.ones(dim)*a, np.ones(dim)*b, modified_basis=False, boundary=False)

midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
f = GenzC0(midpoint=midpoint,coeffs=coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCell()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()

reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

#operation = Integration(f=f, grid=None, dim=dim, reference_solution=reference_solution)
#adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, no_initial_splitting=False,version=0, automatic_extend_split=True)
from GridOperation import *
operationSingleDim = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceSingleDim = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=6, operation=operationSingleDim)
adaptiveCombiInstanceSingleDim3 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=6, operation=operationSingleDim, rebalancing=False)

#operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)

#adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, operation=operation, no_initial_splitting=False,version=0, automatic_extend_split=True)

#adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, operation=operation, no_initial_splitting=False,version=0)
#adaptiveCombiInstanceCell = SpatiallyAdaptiveCellScheme(np.ones(dim)*a, np.ones(dim)*b,grid, operation=operation)

algorithmArray = [(adaptiveCombiInstanceSingleDim,1,2, errorOperatorSingleDim, 'SingleDim rebalance linear strategy 3')]
evaluation_points = get_cross_product_list([np.linspace(a, b, 11)[1:-1] for d in range(dim)])
#print(evaluation_points)
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,1,grid,1,2, max_evaluations=1000000, evaluation_points = evaluation_points )
# Out:
# Cannot plot function with dim > 2
# Exact integral 2.64857774156e-06
# Reference solution: 2.64857774156e-06
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# Curent number of function evaluations 11
# max surplus error: 0.00390622088552 total surplus error: 0.075330463857
# combiintegral: -0.044080463857
# Current error: 16644.0696616
# Finished refinement
# Refined  16  times
# New lmax: [2, 3, 2, 2, 2]
# New lmax: [2, 3, 3, 2, 2]
# New lmax: [2, 3, 3, 3, 2]
# New lmax: [2, 3, 3, 3, 3]
# Curent number of function evaluations 51
# max surplus error: 0.00326496094825 total surplus error: 0.0425332072172
# combiintegral: -0.0271197593479
# Current error: 10240.3669336
# Finished refinement
# Refined  4  times
# New lmax: [3, 3, 3, 3, 3]
# Curent number of function evaluations 71
# max surplus error: 0.00186577822795 total surplus error: 0.0398617858379
# combiintegral: -0.00534690895172
# Current error: 2019.78497573
# Finished refinement
# Refined  16  times
# New lmax: [3, 4, 3, 3, 3]
# New lmax: [3, 4, 4, 3, 3]
# New lmax: [3, 4, 4, 4, 3]
# New lmax: [3, 4, 4, 4, 4]
# Curent number of function evaluations 231
# max surplus error: 0.00253800161641 total surplus error: 0.0615876611241
# combiintegral: -0.0401691458679
# Current error: 15167.3080292
# Finished refinement
# Refined  12  times
# Curent number of function evaluations 291
# max surplus error: 0.00192045311893 total surplus error: 0.0283882679601
# combiintegral: -0.00609416927116
# Current error: 2301.92142493
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 311
# max surplus error: 0.00111502477065 total surplus error: 0.0230398990594
# combiintegral: 0.00437485320893
# Current error: 1650.77451289
# Finished refinement
# Refined  4  times
# New lmax: [4, 4, 4, 4, 4]
# Curent number of function evaluations 331
# max surplus error: 0.00119118047932 total surplus error: 0.023931577197
# combiintegral: 0.00485771708084
# Current error: 1833.0851411
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 351
# max surplus error: 0.000797396439319 total surplus error: 0.0199717525974
# combiintegral: 0.0116974296989
# Current error: 4415.49475316
# Finished refinement
# Refined  12  times
# New lmax: [4, 4, 5, 4, 4]
# New lmax: [4, 4, 5, 5, 4]
# New lmax: [4, 4, 5, 5, 5]
# Curent number of function evaluations 1051
# max surplus error: 0.00112534233064 total surplus error: 0.0260839405611
# combiintegral: -0.0120701673251
# Current error: 4558.22599179
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 1091
# max surplus error: 0.000893994373331 total surplus error: 0.0157893300531
# combiintegral: -0.00130965253371
# Current error: 495.473888065
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 1111
# max surplus error: 0.000420841935714 total surplus error: 0.0118878887609
# combiintegral: 0.00320776107368
# Current error: 1210.1258897
# Finished refinement
# Refined  4  times
# New lmax: [4, 5, 5, 5, 5]
# Curent number of function evaluations 1207
# max surplus error: 0.000665843312258 total surplus error: 0.013580925719
# combiintegral: 0.00349627907343
# Current error: 1319.05907116
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 1227
# max surplus error: 0.000295370337312 total surplus error: 0.0105543175675
# combiintegral: 0.00676630205899
# Current error: 2553.69263855
# Finished refinement
# Refined  4  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 1579
# max surplus error: 0.000415855940334 total surplus error: 0.0117199992772
# combiintegral: 0.00118812523312
# Current error: 447.589903357
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 1599
# max surplus error: 0.000263816526986 total surplus error: 0.00964366983614
# combiintegral: 0.00317208241882
# Current error: 1196.65501652
# Finished refinement
# Refined  4  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 1927
# max surplus error: 0.000382389192177 total surplus error: 0.00983683008599
# combiintegral: -0.00264351726163
# Current error: 999.089359487
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 1947
# max surplus error: 0.000203305655902 total surplus error: 0.00774917652866
# combiintegral: -0.000768503834193
# Current error: 291.157174597
# Finished refinement
# Refined  8  times
# Rebalancing!
# Rebalancing!
# New lmax: [4, 5, 6, 5, 5]
# Curent number of function evaluations 4127
# max surplus error: 0.000175748029146 total surplus error: 0.00397986643393
# combiintegral: -0.00666573131141
# Current error: 2517.72103364
# Finished refinement
# Refined  8  times
# New lmax: [5, 5, 6, 5, 5]
# Curent number of function evaluations 4567
# max surplus error: 0.000167453955743 total surplus error: 0.00301798805173
# combiintegral: -0.00624095755735
# Current error: 2357.34297586
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 4667
# max surplus error: 7.4490088191e-05 total surplus error: 0.00194310442695
# combiintegral: -0.00602283292238
# Current error: 2274.98759261
# Finished refinement
# Refined  4  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 5879
# max surplus error: 8.17644862424e-05 total surplus error: 0.00277479370878
# combiintegral: -0.00507728090382
# Current error: 1917.9839058
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 5975
# max surplus error: 5.02487656011e-05 total surplus error: 0.00227391057201
# combiintegral: -0.00496527515642
# Current error: 1875.69488945
# Finished refinement
# Refined  8  times
# New lmax: [6, 5, 6, 5, 5]
# New lmax: [6, 5, 6, 5, 6]
# Curent number of function evaluations 6015
# max surplus error: 0.000164774468179 total surplus error: 0.00486368586271
# combiintegral: -0.00175714545127
# Current error: 664.42981884
# Finished refinement
# Refined  8  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 6911
# max surplus error: 0.000125593551766 total surplus error: 0.00308337574885
# combiintegral: -0.00339463232303
# Current error: 1282.68120941
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 6931
# max surplus error: 6.84476534901e-05 total surplus error: 0.00246637395691
# combiintegral: -0.00272239030427
# Current error: 1028.86875445
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 6951
# max surplus error: 3.87503229882e-05 total surplus error: 0.00188815505058
# combiintegral: -0.00347131916394
# Current error: 1311.63517958
# Finished refinement
# Refined  4  times
# New lmax: [6, 5, 6, 6, 6]
# Curent number of function evaluations 6971
# max surplus error: 9.58787162943e-05 total surplus error: 0.00233090794763
# combiintegral: -0.00332931234581
# Current error: 1258.01892513
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 6991
# max surplus error: 2.88103576924e-05 total surplus error: 0.00181474695192
# combiintegral: -0.00283365984824
# Current error: 1070.87980899
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 7011
# max surplus error: 6.38178417463e-05 total surplus error: 0.00204972443073
# combiintegral: -0.00270677171966
# Current error: 1022.97178402
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 7031
# max surplus error: 2.2629953778e-05 total surplus error: 0.00168783024128
# combiintegral: -0.00238275153218
# Current error: 900.634356504
# Finished refinement
# Refined  16  times
# Rebalancing!
# New lmax: [6, 5, 6, 6, 7]
# Curent number of function evaluations 14375
# max surplus error: 1.72243827534e-05 total surplus error: 0.000893752391214
# combiintegral: -0.00125831781198
# Current error: 476.091892615
# Finished refinement
# Refined  4  times
# New lmax: [6, 6, 6, 6, 7]
# Curent number of function evaluations 14473
# max surplus error: 1.08403125086e-05 total surplus error: 0.000864021297896
# combiintegral: -0.00125326314995
# Current error: 474.183448717
# Finished refinement
# Refined  10  times
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 142275
# max surplus error: 4.19311666642e-07 total surplus error: 6.83160795596e-05
# combiintegral: -2.4392326369e-05
# Current error: 10.2095942612
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 142371
# max surplus error: 5.87651696829e-07 total surplus error: 6.91344872489e-05
# combiintegral: -2.43808014033e-05
# Current error: 10.2052428821
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 142467
# max surplus error: 3.67412859171e-07 total surplus error: 6.62570266305e-05
# combiintegral: -2.42712687262e-05
# Current error: 10.163887601
# Finished refinement
# Refined  12  times
# Curent number of function evaluations 143063
# max surplus error: 5.78664205499e-07 total surplus error: 6.83530722516e-05
# combiintegral: -1.63001675916e-05
# Current error: 7.15430966433
# Finished refinement
# Refined  8  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 145259
# max surplus error: 3.02931986697e-07 total surplus error: 6.13742291237e-05
# combiintegral: 7.34954585461e-05
# Current error: 26.7490282399
# Finished refinement
# Refined  4  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 147903
# max surplus error: 2.68503373106e-07 total surplus error: 6.14254779333e-05
# combiintegral: 7.76609430396e-05
# Current error: 28.3217532644
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 148423
# max surplus error: 2.04746814332e-07 total surplus error: 6.0186505734e-05
# combiintegral: 7.82743566872e-05
# Current error: 28.5533544132
# Finished refinement
# Refined  32  times
# Rebalancing!
# Rebalancing!
# New lmax: [9, 9, 8, 8, 8]
# New lmax: [9, 9, 9, 8, 8]
# Curent number of function evaluations 171755
# max surplus error: 5.82138099908e-07 total surplus error: 6.50908971669e-05
# combiintegral: -2.03984752982e-05
# Current error: 8.70167134538
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 171799
# max surplus error: 5.74116810429e-07 total surplus error: 6.55614185627e-05
# combiintegral: -7.04801191547e-06
# Current error: 3.66105532976
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 171839
# max surplus error: 4.29281547072e-07 total surplus error: 5.9414174133e-05
# combiintegral: -1.34867713408e-05
# Current error: 6.09208060206
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 171859
# max surplus error: 3.70544040002e-07 total surplus error: 5.64922967628e-05
# combiintegral: -1.1631759498e-05
# Current error: 5.391700238
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 171899
# max surplus error: 3.01400568403e-07 total surplus error: 5.27058458939e-05
# combiintegral: -1.56610321881e-05
# Current error: 6.91299698035
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 171919
# max surplus error: 2.09813969281e-07 total surplus error: 5.13521381636e-05
# combiintegral: -1.77275413453e-05
# Current error: 7.693230509
# Finished refinement
# Refined  16  times
# Curent number of function evaluations 173771
# max surplus error: 1.91408706476e-07 total surplus error: 4.62670436186e-05
# combiintegral: -1.11487670801e-05
# Current error: 5.20934107584
# Finished refinement
# Refined  20  times
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 180631
# max surplus error: 1.65252531666e-07 total surplus error: 4.29079716847e-05
# combiintegral: -5.26252864517e-06
# Current error: 2.986926252
# Finished refinement
# Refined  24  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 184795
# max surplus error: 2.5573806793e-07 total surplus error: 4.01680934539e-05
# combiintegral: -1.65025721034e-06
# Current error: 1.62307297401
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 184815
# max surplus error: 1.53031589694e-07 total surplus error: 3.86213740076e-05
# combiintegral: -4.17613179081e-07
# Current error: 1.15767450301
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 185295
# max surplus error: 1.32454960255e-07 total surplus error: 3.76532570057e-05
# combiintegral: 9.84846343267e-08
# Current error: 0.962816030362
# Finished refinement
# Refined  16  times
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 190463
# max surplus error: 2.27384460224e-07 total surplus error: 3.76678877808e-05
# combiintegral: 2.26812848488e-06
# Current error: 0.14364285054
# Finished refinement
# Refined  4  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 193831
# max surplus error: 1.76807796286e-07 total surplus error: 3.58037346126e-05
# combiintegral: 5.51827269303e-06
# Current error: 1.08348526322
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 193927
# max surplus error: 1.10255048663e-07 total surplus error: 3.49931318317e-05
# combiintegral: 5.60253159478e-06
# Current error: 1.11529814922
# Finished refinement
# Refined  16  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 212079
# max surplus error: 1.58809444839e-07 total surplus error: 3.50795820489e-05
# combiintegral: 2.72584898621e-06
# Current error: 0.0291746183012
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 212099
# max surplus error: 1.32041693296e-07 total surplus error: 3.44093552839e-05
# combiintegral: 1.69226175007e-06
# Current error: 0.361067744582
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 212511
# max surplus error: 1.07887755875e-07 total surplus error: 3.39659932954e-05
# combiintegral: 1.99804519426e-06
# Current error: 0.245615802435
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 212923
# max surplus error: 9.58814947826e-08 total surplus error: 3.36133049302e-05
# combiintegral: 2.26077723332e-06
# Current error: 0.146418397373
# Finished refinement
# Refined  44  times
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 227151
# max surplus error: 8.54827391514e-08 total surplus error: 3.11358750898e-05
# combiintegral: 8.70170781168e-06
# Current error: 2.28542661789
# Finished refinement
# Refined  28  times
# Curent number of function evaluations 228793
# max surplus error: 1.05446223045e-07 total surplus error: 3.02890607287e-05
# combiintegral: 1.31685564266e-05
# Current error: 3.97193502007
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 228913
# max surplus error: 7.37966881008e-08 total surplus error: 2.95126243896e-05
# combiintegral: 1.20480123051e-05
# Current error: 3.54886111744
# Finished refinement
# Refined  40  times
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 243803
# max surplus error: 2.32586357839e-07 total surplus error: 2.91573304151e-05
# combiintegral: 1.02981033575e-05
# Current error: 2.88816352107
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 243823
# max surplus error: 1.32769208907e-07 total surplus error: 2.80019840782e-05
# combiintegral: 1.14241772862e-05
# Current error: 3.31332526394
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 243843
# max surplus error: 9.78911368132e-08 total surplus error: 2.74109827217e-05
# combiintegral: 1.21288563444e-05
# Current error: 3.57938468412
# Finished refinement
# Refined  12  times
# New lmax: [9, 9, 9, 8, 9]
# Curent number of function evaluations 243903
# max surplus error: 1.10024857131e-07 total surplus error: 2.6648642051e-05
# combiintegral: 1.31990215611e-05
# Current error: 3.9834374706
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 243923
# max surplus error: 6.51364816245e-08 total surplus error: 2.58798638799e-05
# combiintegral: 1.37195817812e-05
# Current error: 4.17998077457
# Finished refinement
# Refined  32  times
# New lmax: [9, 10, 9, 8, 9]
# Curent number of function evaluations 382833
# max surplus error: 1.02447626328e-07 total surplus error: 2.10264019717e-05
# combiintegral: 1.25948368442e-05
# Current error: 3.75532080729
# Finished refinement
# Refined  12  times
# Curent number of function evaluations 384519
# max surplus error: 8.80334111588e-08 total surplus error: 1.95183330189e-05
# combiintegral: 1.38100369241e-05
# Current error: 4.21413312035
# Finished refinement
# Refined  12  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 389231
# max surplus error: 9.45968846152e-08 total surplus error: 1.87110412744e-05
# combiintegral: 1.47300679039e-05
# Current error: 4.56150105498
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 389607
# max surplus error: 7.74465136921e-08 total surplus error: 1.84183428664e-05
# combiintegral: 1.49871473622e-05
# Current error: 4.65856426529
# Finished refinement
# Refined  12  times
# Curent number of function evaluations 402543
# max surplus error: 6.71743136378e-08 total surplus error: 1.70513766263e-05
# combiintegral: 1.57797587631e-05
# Current error: 4.95782351995
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 402923
# max surplus error: 5.84510479263e-08 total surplus error: 1.68195470379e-05
# combiintegral: 1.59520296192e-05
# Current error: 5.02286629874
# Finished refinement
# Refined  12  times
# Curent number of function evaluations 403771
# max surplus error: 5.18009135865e-08 total surplus error: 1.65849619042e-05
# combiintegral: 1.75145780523e-05
# Current error: 5.61282384785
# Finished refinement
# Refined  24  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 406961
# max surplus error: 9.21468509716e-08 total surplus error: 1.6466579499e-05
# combiintegral: 1.77018557147e-05
# Current error: 5.68353261335
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 440353
# max surplus error: 5.87795278623e-08 total surplus error: 1.67299227369e-05
# combiintegral: 1.56931691131e-05
# Current error: 4.92513063401
# Finished refinement
# Refined  12  times
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 444539
# max surplus error: 5.41413488212e-08 total surplus error: 1.59795799507e-05
# combiintegral: 1.6563225267e-05
# Current error: 5.25363001702
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 444639
# max surplus error: 4.492856099e-08 total surplus error: 1.57427710362e-05
# combiintegral: 1.65897738455e-05
# Current error: 5.26365372826
# Finished refinement
# Refined  24  times
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 465791
# max surplus error: 4.65979850321e-08 total surplus error: 1.49855664764e-05
# combiintegral: 1.53276055819e-05
# Current error: 4.78710805478
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 467441
# max surplus error: 4.11417749957e-08 total surplus error: 1.44797845635e-05
# combiintegral: 1.56513401607e-05
# Current error: 4.90933764758
# Finished refinement
# Refined  12  times
# Curent number of function evaluations 468053
# max surplus error: 3.6024180994e-08 total surplus error: 1.39834515044e-05
# combiintegral: 1.57076948502e-05
# Current error: 4.93061498769
# Finished refinement
# Refined  16  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 482807
# max surplus error: 3.23388082767e-08 total surplus error: 1.34277162612e-05
# combiintegral: 1.68821421802e-05
# Current error: 5.37404064654
# Finished refinement
# Refined  48  times
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# New lmax: [10, 10, 9, 8, 9]
# Curent number of function evaluations 497615
# max surplus error: 8.10431977473e-08 total surplus error: 1.43749806841e-05
# combiintegral: 1.75472619416e-05
# Current error: 5.62516401398
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 497635
# max surplus error: 6.82091513725e-08 total surplus error: 1.39509290059e-05
# combiintegral: 1.80374346403e-05
# Current error: 5.81023417107
# Finished refinement
# Refined  16  times
# Curent number of function evaluations 497719
# max surplus error: 4.60559409352e-08 total surplus error: 1.31447114348e-05
# combiintegral: 1.88468545425e-05
# Current error: 6.11583966245
# Finished refinement
# Refined  8  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 500803
# max surplus error: 4.04769671122e-08 total surplus error: 1.25821931723e-05
# combiintegral: 1.90757162889e-05
# Current error: 6.20224896161
# Finished refinement
# Refined  12  times
# Curent number of function evaluations 501231
# max surplus error: 3.2320109345e-08 total surplus error: 1.22713004609e-05
# combiintegral: 1.998099586e-05
# Current error: 6.54404733772
# Finished refinement
# Refined  12  times
# New lmax: [10, 10, 10, 8, 9]
# Curent number of function evaluations 501567
# max surplus error: 2.84266902451e-08 total surplus error: 1.18498435337e-05
# combiintegral: 1.93532348828e-05
# Current error: 6.30702919502
# Finished refinement
# Refined  24  times
# Curent number of function evaluations 502127
# max surplus error: 2.53741878449e-08 total surplus error: 1.11334970354e-05
# combiintegral: 1.99644449775e-05
# Current error: 6.53779836785
# Finished refinement
# Refined  42  times
# Rebalancing!
# Rebalancing!
# New lmax: [10, 10, 10, 9, 9]
# Curent number of function evaluations 541395
# max surplus error: 3.04643977587e-08 total surplus error: 9.87946454729e-06
# combiintegral: 1.93541055338e-05
# Current error: 6.30735791896
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 541783
# max surplus error: 2.63520512675e-08 total surplus error: 9.80207396328e-06
# combiintegral: 1.94229987354e-05
# Current error: 6.33336931388
# Finished refinement
# Refined  14  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 541949
# max surplus error: 3.62934819369e-08 total surplus error: 9.79956394617e-06
# combiintegral: 2.06868562204e-05
# Current error: 6.81055277169
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 541959
# max surplus error: 2.34251890295e-08 total surplus error: 9.72241722257e-06
# combiintegral: 2.05576449834e-05
# Current error: 6.76176763129
# Finished refinement
# Refined  34  times
# Rebalancing!
# Curent number of function evaluations 543455
# max surplus error: 2.90525766745e-08 total surplus error: 9.16767526753e-06
# combiintegral: 2.10300208224e-05
# Current error: 6.94011838597
# Finished refinement
# Refined  6  times
# Curent number of function evaluations 548506
# max surplus error: 3.92511107522e-08 total surplus error: 9.11532447617e-06
# combiintegral: 2.03932013765e-05
# Current error: 6.69968011757
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 548556
# max surplus error: 2.18244885311e-08 total surplus error: 9.00175959703e-06
# combiintegral: 2.09430624362e-05
# Current error: 6.90728627958
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 549332
# max surplus error: 3.40349125648e-08 total surplus error: 9.02921114421e-06
# combiintegral: 2.11706050915e-05
# Current error: 6.9931975412
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 549720
# max surplus error: 2.96054693009e-08 total surplus error: 8.9532650572e-06
# combiintegral: 2.12421053023e-05
# Current error: 7.02019324145
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 550108
# max surplus error: 1.95451180071e-08 total surplus error: 8.85735006951e-06
# combiintegral: 2.13173306611e-05
# Current error: 7.04859541276
# Finished refinement
# Refined  16  times
# Curent number of function evaluations 551076
# max surplus error: 3.29000241974e-08 total surplus error: 8.85117029294e-06
# combiintegral: 2.14180359531e-05
# Current error: 7.08661781643
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 551464
# max surplus error: 2.44935075515e-08 total surplus error: 8.77487833204e-06
# combiintegral: 2.1486804764e-05
# Current error: 7.11258224627
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 551852
# max surplus error: 1.73101100012e-08 total surplus error: 8.69806929724e-06
# combiintegral: 2.1541611801e-05
# Current error: 7.13327525295
# Finished refinement
# Refined  48  times
# Rebalancing!
# Rebalancing!
# New lmax: [11, 10, 10, 9, 9]
# Curent number of function evaluations 1011369
# max surplus error: 3.0371860928e-08 total surplus error: 8.55426386276e-06
# combiintegral: 1.31648768004e-05
# Current error: 3.97054573623
# Number of refinements 1600
# Number of distinct points used during the refinement 1011369
0028032840885641773, 0.0028032840885641773, 0.0028032840885641773, 0.0028032840885641773, 0.0027134138835359189, 0.0027134138835359189, 0.0027134138835359189, 0.0027134138835359189, 0.0027134138835359189, 0.0027134138835359189, 0.0027816378981674775, 0.0027816378981674775, 0.0027816378981674775, 0.0027816378981674775, 0.0026326426122912912, 0.0026326426122912912, 0.0026326426122912912, 0.0026326426122912404, 0.0026326426122912404, 0.0014471414782635137, 0.0013658016752262699, 0.0013658016752262699, 0.0013658016752262699, 0.0013658016752262699, 0.0013658016752262699, 0.0013658016752262 ...

# %%
grid_single_dim_lin = GlobalTrapezoidalGrid(a=a*np.ones(dim), b=b*np.ones(dim), modified_basis=False, boundary=False)
grid=TrapezoidalGrid(np.ones(dim)*a, np.ones(dim)*b, modified_basis=False, boundary=False)

midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
f = GenzC0(midpoint=midpoint,coeffs=coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCell()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()

reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

#operation = Integration(f=f, grid=None, dim=dim, reference_solution=reference_solution)
#adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, no_initial_splitting=False,version=0, automatic_extend_split=True)
from GridOperation import *
operationSingleDim = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceSingleDim = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=6, operation=operationSingleDim)
adaptiveCombiInstanceSingleDim3 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=6, operation=operationSingleDim, rebalancing=False)

#operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)

#adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, operation=operation, no_initial_splitting=False,version=0, automatic_extend_split=True)

#adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, operation=operation, no_initial_splitting=False,version=0)
#adaptiveCombiInstanceCell = SpatiallyAdaptiveCellScheme(np.ones(dim)*a, np.ones(dim)*b,grid, operation=operation)

algorithmArray = [(adaptiveCombiInstanceSingleDim3,1,2, errorOperatorSingleDim, 'SingleDim  strategy 3')]
evaluation_points = get_cross_product_list([np.linspace(a, b, 11)[1:-1] for d in range(dim)])
#print(evaluation_points)
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,1,grid,1,2, max_evaluations=1000000, evaluation_points = evaluation_points )
# Out:
# Cannot plot function with dim > 2
# Exact integral 2.64857774156e-06
# Reference solution: 2.64857774156e-06
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# Curent number of function evaluations 11
# max surplus error: 0.00390622088552 total surplus error: 0.075330463857
# combiintegral: -0.044080463857
# Current error: 16644.0696616
# Finished refinement
# Refined  16  times
# New lmax: [2, 3, 2, 2, 2]
# New lmax: [2, 3, 3, 2, 2]
# New lmax: [2, 3, 3, 3, 2]
# New lmax: [2, 3, 3, 3, 3]
# Curent number of function evaluations 51
# max surplus error: 0.00326496094825 total surplus error: 0.0425332072172
# combiintegral: -0.0271197593479
# Current error: 10240.3669336
# Finished refinement
# Refined  4  times
# New lmax: [3, 3, 3, 3, 3]
# Curent number of function evaluations 71
# max surplus error: 0.00186577822795 total surplus error: 0.0398617858379
# combiintegral: -0.00534690895172
# Current error: 2019.78497573
# Finished refinement
# Refined  16  times
# New lmax: [3, 4, 3, 3, 3]
# New lmax: [3, 4, 4, 3, 3]
# New lmax: [3, 4, 4, 4, 3]
# New lmax: [3, 4, 4, 4, 4]
# Curent number of function evaluations 231
# max surplus error: 0.00253800161641 total surplus error: 0.0615876611241
# combiintegral: -0.0401691458679
# Current error: 15167.3080292
# Finished refinement
# Refined  12  times
# Curent number of function evaluations 291
# max surplus error: 0.00192045311893 total surplus error: 0.0283882679601
# combiintegral: -0.00609416927116
# Current error: 2301.92142493
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 311
# max surplus error: 0.00111502477065 total surplus error: 0.0230398990594
# combiintegral: 0.00437485320893
# Current error: 1650.77451289
# Finished refinement
# Refined  4  times
# New lmax: [4, 4, 4, 4, 4]
# Curent number of function evaluations 331
# max surplus error: 0.00119118047932 total surplus error: 0.023931577197
# combiintegral: 0.00485771708084
# Current error: 1833.0851411
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 351
# max surplus error: 0.000797396439319 total surplus error: 0.0199717525974
# combiintegral: 0.0116974296989
# Current error: 4415.49475316
# Finished refinement
# Refined  12  times
# New lmax: [4, 4, 5, 4, 4]
# New lmax: [4, 4, 5, 5, 4]
# New lmax: [4, 4, 5, 5, 5]
# Curent number of function evaluations 1051
# max surplus error: 0.00112534233064 total surplus error: 0.0260839405611
# combiintegral: -0.0120701673251
# Current error: 4558.22599179
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 1091
# max surplus error: 0.000893994373331 total surplus error: 0.0157893300531
# combiintegral: -0.00130965253371
# Current error: 495.473888065
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 1111
# max surplus error: 0.000420841935714 total surplus error: 0.0118878887609
# combiintegral: 0.00320776107368
# Current error: 1210.1258897
# Finished refinement
# Refined  4  times
# New lmax: [4, 5, 5, 5, 5]
# Curent number of function evaluations 1207
# max surplus error: 0.000665843312258 total surplus error: 0.013580925719
# combiintegral: 0.00349627907343
# Current error: 1319.05907116
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 1227
# max surplus error: 0.000295370337312 total surplus error: 0.0105543175675
# combiintegral: 0.00676630205899
# Current error: 2553.69263855
# Finished refinement
# Refined  4  times
# New lmax: [4, 5, 5, 5, 6]
# Curent number of function evaluations 2987
# max surplus error: 0.000405594059914 total surplus error: 0.00765018849145
# combiintegral: -0.00608068277028
# Current error: 2296.82944645
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 3007
# max surplus error: 0.000195161103198 total surplus error: 0.00567840326336
# combiintegral: -0.00409672558459
# Current error: 1547.76433329
# Finished refinement
# Refined  4  times
# New lmax: [4, 5, 5, 6, 6]
# Curent number of function evaluations 3027
# max surplus error: 0.000341700098189 total surplus error: 0.0065985671959
# combiintegral: -0.00396289411956
# Current error: 1497.23477437
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 3047
# max surplus error: 0.000150810422398 total surplus error: 0.00488132510201
# combiintegral: -0.00233453694535
# Current error: 882.430402709
# Finished refinement
# Refined  4  times
# New lmax: [4, 5, 6, 6, 6]
# Curent number of function evaluations 3275
# max surplus error: 0.000263376140935 total surplus error: 0.00569462051974
# combiintegral: -0.00214989447032
# Current error: 812.716581538
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 3295
# max surplus error: 0.000133574529751 total surplus error: 0.00426958647674
# combiintegral: -0.000958579183399
# Current error: 362.92223787
# Finished refinement
# Refined  4  times
# New lmax: [5, 5, 6, 6, 6]
# Curent number of function evaluations 3595
# max surplus error: 0.000291297863079 total surplus error: 0.00527030580952
# combiintegral: -0.000544425488111
# Current error: 206.553901465
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 3687
# max surplus error: 8.3497946635e-05 total surplus error: 0.00403745402003
# combiintegral: 0.000462732720799
# Current error: 173.70988808
# Finished refinement
# Refined  4  times
# New lmax: [5, 6, 6, 6, 6]
# Curent number of function evaluations 3739
# max surplus error: 0.000174162010461 total surplus error: 0.00461216602039
# combiintegral: 0.000682616994076
# Current error: 256.729642353
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 3759
# max surplus error: 7.04906037798e-05 total surplus error: 0.00361656814124
# combiintegral: 0.00138342239329
# Current error: 521.326519467
# Finished refinement
# Refined  4  times
# New lmax: [5, 6, 6, 6, 7]
# Curent number of function evaluations 7291
# max surplus error: 0.000106989994545 total surplus error: 0.00196832482124
# combiintegral: -0.00356078269
# Current error: 1345.4131294
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 7311
# max surplus error: 4.58803310741e-05 total surplus error: 0.00143485590378
# combiintegral: -0.00308677417988
# Current error: 1166.44594159
# Finished refinement
# Refined  4  times
# New lmax: [5, 6, 6, 7, 7]
# Curent number of function evaluations 7331
# max surplus error: 8.31233986208e-05 total surplus error: 0.00167410362852
# combiintegral: -0.00298674609229
# Current error: 1128.67922399
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 7351
# max surplus error: 2.77405279559e-05 total surplus error: 0.00123927920328
# combiintegral: -0.00263775498379
# Current error: 996.913747368
# Finished refinement
# Refined  8  times
# New lmax: [6, 6, 6, 7, 7]
# New lmax: [6, 6, 7, 7, 7]
# Curent number of function evaluations 7455
# max surplus error: 5.85972103522e-05 total surplus error: 0.00158666232251
# combiintegral: -0.0023296398676
# Current error: 880.58145651
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 7475
# max surplus error: 4.8236865792e-05 total surplus error: 0.00127226290602
# combiintegral: -0.00210293677443
# Current error: 794.987180906
# Finished refinement
# Refined  4  times
# Curent number of function evaluations
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 20279
# max surplus error: 2.73804139302e-06 total surplus error: 0.000368526574515
# combiintegral: -0.00182787249352
# Current error: 691.133600703
# Finished refinement
# Refined  12  times
# Curent number of function evaluations 20531
# max surplus error: 2.48002271485e-06 total surplus error: 0.000347090160564
# combiintegral: -0.0017972403927
# Current error: 679.568110157
# Finished refinement
# Refined  8  times
# New lmax: [7, 7, 8, 9, 8]
# Curent number of function evaluations 41131
# max surplus error: 3.20037739074e-06 total surplus error: 0.000437246415048
# combiintegral: -0.00121719111173
# Current error: 460.564049275
# Finished refinement
# Refined  8  times
# New lmax: [7, 8, 8, 9, 8]
# Curent number of function evaluations 43995
# max surplus error: 2.82998361711e-06 total surplus error: 0.000409742325454
# combiintegral: -0.00120084924747
# Current error: 454.393996569
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 44163
# max surplus error: 2.33507759286e-06 total surplus error: 0.000388254150796
# combiintegral: -0.00118319159901
# Current error: 447.727154895
# Finished refinement
# Refined  8  times
# New lmax: [7, 8, 8, 9, 9]
# Curent number of function evaluations 44267
# max surplus error: 3.01895955809e-06 total surplus error: 0.000386326358662
# combiintegral: -0.00116367657337
# Current error: 440.359039799
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 44287
# max surplus error: 2.06024826132e-06 total surplus error: 0.000368882010502
# combiintegral: -0.00115091921079
# Current error: 435.542355593
# Finished refinement
# Refined  16  times
# Curent number of function evaluations 46747
# max surplus error: 1.86872433157e-06 total surplus error: 0.000342800805907
# combiintegral: -0.00112766525054
# Current error: 426.762564128
# Finished refinement
# Refined  12  times
# Curent number of function evaluations 47707
# max surplus error: 1.66037430686e-06 total surplus error: 0.000315978384089
# combiintegral: -0.00111746927797
# Current error: 422.912961221
# Finished refinement
# Refined  16  times
# Curent number of function evaluations 47979
# max surplus error: 1.44439368281e-06 total surplus error: 0.000284746568
# combiintegral: -0.00110364769978
# Current error: 417.694470568
# Finished refinement
# Refined  12  times
# New lmax: [8, 8, 8, 9, 9]
# Curent number of function evaluations 50339
# max surplus error: 1.66020418439e-06 total surplus error: 0.000256834247161
# combiintegral: -0.00107404950036
# Current error: 406.519341007
# Finished refinement
# Refined  12  times
# Curent number of function evaluations 50595
# max surplus error: 1.22127178407e-06 total surplus error: 0.000242336780632
# combiintegral: -0.00107054552746
# Current error: 405.196377045
# Finished refinement
# Refined  16  times
# Curent number of function evaluations 51111
# max surplus error: 1.24113389411e-06 total surplus error: 0.000222637637118
# combiintegral: -0.00105952539973
# Current error: 401.035605188
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 51131
# max surplus error: 1.06197480479e-06 total surplus error: 0.000217450478027
# combiintegral: -0.00105368465354
# Current error: 398.830366466
# Finished refinement
# Refined  12  times
# Curent number of function evaluations 52331
# max surplus error: 9.20864919118e-07 total surplus error: 0.000207097423248
# combiintegral: -0.00104482747912
# Current error: 395.486241701
# Finished refinement
# Refined  12  times
# New lmax: [8, 8, 9, 9, 9]
# Curent number of function evaluations 53575
# max surplus error: 1.46505597256e-06 total surplus error: 0.000202708265221
# combiintegral: -0.00104006819575
# Current error: 393.689321303
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 53659
# max surplus error: 1.16247698007e-06 total surplus error: 0.000199337138959
# combiintegral: -0.00104608301003
# Current error: 395.960281368
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 53679
# max surplus error: 8.31622841182e-07 total surplus error: 0.00019394274224
# combiintegral: -0.00104112448274
# Current error: 394.088134209
# Finished refinement
# Refined  32  times
# Curent number of function evaluations 60615
# max surplus error: 8.29156715252e-07 total surplus error: 0.00017311919307
# combiintegral: -0.000999515863034
# Current error: 378.378336815
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 60635
# max surplus error: 6.69222663952e-07 total surplus error: 0.000169639002936
# combiintegral: -0.000996194437173
# Current error: 377.124295519
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 60807
# max surplus error: 5.93004320083e-07 total surplus error: 0.000164240764946
# combiintegral: -0.000998576156756
# Current error: 378.023540252
# Finished refinement
# Refined  28  times
# Curent number of function evaluations 61839
# max surplus error: 8.58115548469e-07 total surplus error: 0.000155425663394
# combiintegral: -0.00100266891619
# Current error: 379.568807121
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 62011
# max surplus error: 6.26821561705e-07 total surplus error: 0.00014884567781
# combiintegral: -0.00100454682699
# Current error: 380.277833243
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 62031
# max surplus error: 5.30048757278e-07 total surplus error: 0.000147642302863
# combiintegral: -0.0010014438599
# Current error: 379.106273487
# Finished refinement
# Refined  32  times
# Curent number of function evaluations 63043
# max surplus error: 4.76919484696e-07 total surplus error: 0.000143121154106
# combiintegral: -0.000989647841387
# Current error: 374.652555429
# Finished refinement
# Refined  32  times
# New lmax: [8, 8, 9, 9, 10]
# Curent number of function evaluations 127655
# max surplus error: 5.73664634983e-07 total surplus error: 0.000141554532311
# combiintegral: -0.000418126883385
# Current error: 158.868457785
# Finished refinement
# Refined  8  times
# New lmax: [8, 9, 9, 9, 10]
# Curent number of function evaluations 131983
# max surplus error: 4.81734610427e-07 total surplus error: 0.000137660873619
# combiintegral: -0.000415503222726
# Current error: 157.877865507
# Finished refinement
# Refined  12  times
# Curent number of function evaluations 133127
# max surplus error: 4.11163595766e-07 total surplus error: 0.000133118661186
# combiintegral: -0.000411991925805
# Current error: 156.552136281
# Finished refinement
# Refined  20  times
# Curent number of function evaluations 133983
# max surplus error: 3.57157758167e-07 total surplus error: 0.000121979418561
# combiintegral: -0.000407819026232
# Current error: 154.97661161
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 134351
# max surplus error: 3.20123342789e-07 total surplus error: 0.000118449475587
# combiintegral: -0.000405973706536
# Current error: 154.279890624
# Finished refinement
# Refined  16  times
# Curent number of function evaluations 134919
# max surplus error: 2.73496008103e-07 total surplus error: 0.000114011542419
# combiintegral: -0.000403360739105
# Current error: 153.293335693
# Finished refinement
# Refined  48  times
# New lmax: [9, 9, 9, 9, 10]
# Curent number of function evaluations 142543
# max surplus error: 3.44721499209e-07 total surplus error: 0.0001008950279
# combiintegral: -0.000414971257551
# Current error: 157.677016136
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 144799
# max surplus error: 2.8605220191e-07 total surplus error: 9.98270549386e-05
# combiintegral: -0.000414056850334
# Current error: 157.331771515
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 146435
# max surplus error: 4.28121692368e-07 total surplus error: 9.81620431696e-05
# combiintegral: -0.000398958602115
# Current error: 151.631259885
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 146519
# max surplus error: 2.43936437997e-07 total surplus error: 9.70114558305e-05
# combiintegral: -0.000400515541394
# Current error: 152.219099636
# Finished refinement
# Refined  44  times
# New lmax: [9, 9, 9, 10, 10]
# Curent number of function evaluations 148435
# max surplus error: 4.81606303896e-07 total surplus error: 9.14526652653e-05
# combiintegral: -0.000394340066025
# Current error: 149.887480189
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 148455
# max surplus error: 2.84897563584e-07 total surplus error: 8.83684690631e-05
# combiintegral: -0.000392585522433
# Current error: 149.225032731
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 148495
# max surplus error: 2.52204094693e-07 total surplus error: 8.53670569271e-05
# combiintegral: -0.00039046417841
# Current error: 148.424095688
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 148515
# max surplus error: 2.22940195213e-07 total surplus error: 8.45571569107e-05
# combiintegral: -0.000389276994831
# Current error: 147.975861317
# Finished refinement
# Refined  20  times
# Curent number of function evaluations 149007
# max surplus error: 1.91838060572e-07 total surplus error: 8.16594053596e-05
# combiintegral: -0.000385012559549
# Current error: 146.365776321
# Finished refinement
# Refined  20  times
# New lmax: [9, 9, 10, 10, 10]
# Curent number of function evaluations 149779
# max surplus error: 1.71267125128e-07 total surplus error: 7.75380994033e-05
# combiintegral: -0.00038285270466
# Current error: 145.550299073
# Finished refinement
# Refined  36  times
# Curent number of function evaluations 156907
# max surplus error: 1.53504108183e-07 total surplus error: 7.25030256131e-05
# combiintegral: -0.000380802266554
# Current error: 144.776133348
# Finished refinement
# Refined  36  times
# New lmax: [10, 9, 10, 10, 10]
# Curent number of function evaluations 159467
# max surplus error: 2.25054585699e-07 total surplus error: 8.35497058177e-05
# combiintegral: -0.000664861962836
# Current error: 252.026032728
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 159487
# max surplus error: 1.77864164271e-07 total surplus error: 8.27885721507e-05
# combiintegral: -0.000666089122899
# Current error: 252.489360666
# Finished refinement
# Refined  16  times
# Curent number of function evaluations 160959
# max surplus error: 1.56237426689e-07 total surplus error: 7.94564029236e-05
# combiintegral: -0.00066540378729
# Current error: 252.23060458
# Finished refinement
# Refined  28  times
# Curent number of function evaluations 162075
# max surplus error: 1.43897404422e-07 total surplus error: 7.41123770727e-05
# combiintegral: -0.000663922425401
# Current error: 251.671299914
# Finished refinement
# Refined  24  times
# Curent number of function evaluations 162519
# max surplus error: 1.27198697125e-07 total surplus error: 7.21230509912e-05
# combiintegral: -0.000662333777327
# Current error: 251.071488155
# Finished refinement
# Refined  80  times
# New lmax: [10, 10, 10, 10, 10]
# Curent number of function evaluations 163931
# max surplus error: 1.62192408736e-07 total surplus error: 6.28745864866e-05
# combiintegral: -0.000666093765882
# Current error: 252.491113676
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 164211
# max surplus error: 1.09078502412e-07 total surplus error: 6.24548776063e-05
# combiintegral: -0.000665405541498
# Current error: 252.231266901
# Finished refinement
# Refined  96  times
# New lmax: [10, 10, 11, 10, 10]
# New lmax: [10, 10, 11, 10, 11]
# Curent number of function evaluations 279463
# max surplus error: 1.16907785469e-07 total surplus error: 5.34539393085e-05
# combiintegral: -0.000203593007201
# Current error: 77.8688054749
# Finished refinement
# Refined  12  times
# Curent number of function evaluations 282087
# max surplus error: 1.01011770278e-07 total surplus error: 5.19256965408e-05
# combiintegral: -0.000202613257017
# Current error: 77.49888989
# Finished refinement
# Refined  32  times
# Curent number of function evaluations 286387
# max surplus error: 1.09786281146e-07 total surplus error: 4.94546534622e-05
# combiintegral: -0.000200704482985
# Current error: 76.7782110131
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 286471
# max surplus error: 1.06156211235e-07 total surplus error: 4.91571059832e-05
# combiintegral: -0.000200305603907
# Current error: 76.6276097786
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 286639
# max surplus error: 8.99406697356e-08 total surplus error: 4.84870900027e-05
# combiintegral: -0.000199709418103
# Current error: 76.4025131939
# Finished refinement
# Refined  16  times
# Curent number of function evaluations 288431
# max surplus error: 1.12574410753e-07 total surplus error: 4.76897385172e-05
# combiintegral: -0.000198867295861
# Current error: 76.0845605703
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 289211
# max surplus error: 8.92257427589e-08 total surplus error: 4.72672665557e-05
# combiintegral: -0.000199116519661
# Current error: 76.1786577893
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 289379
# max surplus error: 7.6775223945e-08 total surplus error: 4.67100967661e-05
# combiintegral: -0.000198811507443
# Current error: 76.063497032
# Finished refinement
# Refined  52  times
# Curent number of function evaluations 290847
# max surplus error: 7.67115678846e-08 total surplus error: 4.39117310877e-05
# combiintegral: -0.000197086936878
# Current error: 75.4123662242
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 291203
# max surplus error: 6.61511397138e-08 total surplus error: 4.32887310343e-05
# combiintegral: -0.00019663382419
# Current error: 75.2412884864
# Finished refinement
# Refined  28  times
# New lmax: [11, 10, 11, 10, 11]
# Curent number of function evaluations 291963
# max surplus error: 1.21820152605e-07 total surplus error: 4.21238729144e-05
# combiintegral: -0.000195373838945
# Current error: 74.765567036
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 291983
# max surplus error: 6.51397521834e-08 total surplus error: 4.17377608151e-05
# combiintegral: -0.000195987628747
# Current error: 74.9973102058
# Finished refinement
# Refined  16  times
# Curent number of function evaluations 294663
# max surplus error: 5.7978036408e-08 total surplus error: 4.10786596421e-05
# combiintegral: -0.000195514168924
# Current error: 74.8185501812
# Finished refinement
# Refined  16  times
# Curent number of function evaluations 295575
# max surplus error: 4.9954980759e-08 total surplus error: 4.01968299938e-05
# combiintegral: -0.000194851218194
# Current error: 74.5682457557
# Finished refinement
# Refined  28  times
# Curent number of function evaluations 298675
# max surplus error: 4.5417558578e-08 total surplus error: 3.89758822364e-05
# combiintegral: -0.0001941609134
# Current error: 74.3076134989
# Finished refinement
# Refined  68  times
# New lmax: [11, 10, 11, 11, 11]
# Curent number of function evaluations 300651
# max surplus error: 4.42963745737e-08 total surplus error: 3.64135341771e-05
# combiintegral: -0.000193369170762
# Current error: 74.0086822553
# Finished refinement
# Refined  20  times
# New lmax: [12, 10, 11, 11, 11]
# Curent number of function evaluations 642667
# max surplus error: 6.29163806127e-08 total surplus error: 2.58765913677e-05
# combiintegral: 1.0632287686e-05
# Current error: 3.01433853315
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 642687
# max surplus error: 5.22438777173e-08 total surplus error: 2.56993647984e-05
# combiintegral: 1.03253668614e-05
# Current error: 2.89845716036
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 644931
# max surplus error: 4.30116041176e-08 total surplus error: 2.55424660173e-05
# combiintegral: 1.04738781864e-05
# Current error: 2.95452926378
# Finished refinement
# Refined  12  times
# Curent number of function evaluations 645903
# max surplus error: 4.41865585451e-08 total surplus error: 2.51120294311e-05
# combiintegral: 1.08699026771e-05
# Current error: 3.10405271724
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 646071
# max surplus error: 3.83535733964e-08 total surplus error: 2.48169321494e-05
# combiintegral: 1.10870049696e-05
# Current error: 3.18602210371
# Finished refinement
# Refined  44  times
# Curent number of function evaluations 680435
# max surplus error: 3.58055160234e-08 total surplus error: 2.29539548705e-05
# combiintegral: 1.81165189779e-05
# Current error: 5.84009334278
# Finished refinement
# Refined  16  times
# Curent number of function evaluations 681163
# max surplus error: 3.12208521956e-08 total surplus error: 2.25235909327e-05
# combiintegral: 1.85572723268e-05
# Current error: 6.00650467441
# Finished refinement
# Refined  32  times
# Curent number of function evaluations 685651
# max surplus error: 2.99127717931e-08 total surplus error: 2.17246361662e-05
# combiintegral: 1.91779495646e-05
# Current error: 6.2408482725
# Finished refinement
# Refined  24  times
# Curent number of function evaluations 690727
# max surplus error: 2.80347007899e-08 total surplus error: 2.11027832669e-05
# combiintegral: 1.96719338508e-05
# Current error: 6.42735753687
# Finished refinement
# Refined  24  times

# %%
grid_single_dim_lin = GlobalTrapezoidalGrid(a=a*np.ones(dim), b=b*np.ones(dim), modified_basis=False, boundary=False)
grid=TrapezoidalGrid(np.ones(dim)*a, np.ones(dim)*b, modified_basis=False, boundary=False)

midpoint = np.ones(dim) * 0.5
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
f = GenzC0(midpoint=midpoint,coeffs=coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCell()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()

reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

#operation = Integration(f=f, grid=None, dim=dim, reference_solution=reference_solution)
#adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, no_initial_splitting=False,version=0, automatic_extend_split=True)
from GridOperation import *
operationSingleDim = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceSingleDim = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=6, operation=operationSingleDim)
adaptiveCombiInstanceSingleDim3 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=6, operation=operationSingleDim, rebalancing=False)

#operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)

#adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, operation=operation, no_initial_splitting=False,version=0, automatic_extend_split=True)

#adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, operation=operation, no_initial_splitting=False,version=0)
#adaptiveCombiInstanceCell = SpatiallyAdaptiveCellScheme(np.ones(dim)*a, np.ones(dim)*b,grid, operation=operation)

algorithmArray = []#[(adaptiveCombiInstanceSingleDim,1,2, errorOperatorSingleDim, 'SingleDim rebalance linear strategy 3'), (adaptiveCombiInstanceSingleDim3,1,2, errorOperatorSingleDim, 'SingleDim  strategy 3')]
evaluation_points = get_cross_product_list([np.linspace(a, b, 11)[1:-1] for d in range(dim)])
#print(evaluation_points)
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,12,grid,1,2, max_evaluations=1000000, evaluation_points = evaluation_points )
