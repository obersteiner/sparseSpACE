# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sys import path
path.append('../../src/')
#path.append('../../../src/tools')
import numpy as np

#from numpy import *
import scipy as sp
from spatiallyAdaptiveExtendSplit import *
from spatiallyAdaptiveSingleDimension2 import *
from spatiallyAdaptiveCell import *

from PerformTestCase import *
from Function import *
from ErrorCalculator import *
from Utils import *
import math
dim = 5
a = 0
b = 1
grid=TrapezoidalGrid(np.ones(dim)*a, np.ones(dim)*b, modified_basis=False, boundary=True)
grid_single_dim = GlobalBSplineGrid(a=a*np.ones(dim), b=b*np.ones(dim), p=3, modified_basis=False, boundary=True)
grid_single_dim2 = GlobalLagrangeGrid(a=a*np.ones(dim), b=b*np.ones(dim), p=3, modified_basis=False, boundary=True)
grid_single_dim_lin = GlobalTrapezoidalGrid(a=a*np.ones(dim), b=b*np.ones(dim), modified_basis=False, boundary=True)

# %%
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzCornerPeak(coeffs=coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCell()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()

reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

#operation = Integration(f=f, grid=None, dim=dim, reference_solution=reference_solution)
#adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, no_initial_splitting=False,version=0, automatic_extend_split=True)
from GridOperation import *
operationSingleDim = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceSingleDim = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=6, operation=operationSingleDim)
adaptiveCombiInstanceSingleDim3 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=6, operation=operationSingleDim, rebalancing=False)

#operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)

#adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, operation=operation, no_initial_splitting=False,version=0, automatic_extend_split=True)

#adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, operation=operation, no_initial_splitting=False,version=0)
#adaptiveCombiInstanceCell = SpatiallyAdaptiveCellScheme(np.ones(dim)*a, np.ones(dim)*b,grid, operation=operation)

algorithmArray = [(adaptiveCombiInstanceSingleDim,1,2, errorOperatorSingleDim, 'SingleDim rebalance linear strategy 3')]
evaluation_points = get_cross_product_list([np.linspace(a, b, 11)[1:-1] for d in range(dim)])
print(len(evaluation_points))
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,9,grid,1,2, max_evaluations=1000000, evaluation_points = evaluation_points )
# Out:
# Cannot plot function with dim > 2
# 59049
# Exact integral 2.60253827962e-05
# Reference solution: 2.60253827962e-05
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# Curent number of function evaluations 1053
# max surplus error: 0.000301497157693 total surplus error: 0.00253418612504
# combiintegral: -0.00128183702377
# Current error: 50.2533398569
# Finished refinement
# Refined  6  times
# New lmax: [2, 2, 3, 2, 2]
# New lmax: [2, 2, 3, 3, 2]
# New lmax: [2, 2, 3, 3, 3]
# Curent number of function evaluations 1620
# max surplus error: 0.000239166696043 total surplus error: 0.00150050690057
# combiintegral: -0.00119444595343
# Current error: 46.8954230486
# Finished refinement
# Refined  2  times
# New lmax: [2, 3, 3, 3, 3]
# Curent number of function evaluations 1863
# max surplus error: 0.00014043353606 total surplus error: 0.00120063816932
# combiintegral: -0.000670569012291
# Current error: 26.7659615438
# Finished refinement
# Refined  2  times
# New lmax: [3, 3, 3, 3, 3]
# Curent number of function evaluations 2133
# max surplus error: 0.000115390421712 total surplus error: 0.00118997686792
# combiintegral: -0.000218732831849
# Current error: 9.40459614223
# Finished refinement
# Refined  6  times
# New lmax: [3, 3, 4, 3, 3]
# New lmax: [3, 3, 4, 4, 3]
# New lmax: [3, 3, 4, 4, 4]
# Curent number of function evaluations 3033
# max surplus error: 0.000163770559111 total surplus error: 0.00149487757016
# combiintegral: -0.00105382448858
# Current error: 41.4921801472
# Finished refinement
# Refined  4  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 4562
# max surplus error: 3.57629787365e-05 total surplus error: 0.000249195657612
# combiintegral: -0.000213322649123
# Current error: 9.19671513743
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 5524
# max surplus error: 7.34806708936e-06 total surplus error: 0.000100419093784
# combiintegral: -8.97470305085e-05
# Current error: 4.44844228464
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 5821
# max surplus error: 6.4366795498e-06 total surplus error: 8.79037180074e-05
# combiintegral: -5.7761383368e-05
# Current error: 3.21942492913
# Finished refinement
# Refined  4  times
# New lmax: [3, 4, 4, 4, 4]
# Curent number of function evaluations 6418
# max surplus error: 1.41692018021e-05 total surplus error: 0.000121241676394
# combiintegral: -5.39762845293e-05
# Current error: 3.07398619079
# Finished refinement
# Refined  4  times
# Rebalancing!
# Curent number of function evaluations 8059
# max surplus error: 3.68574220838e-06 total surplus error: 4.15336036303e-05
# combiintegral: -1.39377938378e-06
# Current error: 1.05355461607
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 8383
# max surplus error: 5.95053319112e-06 total surplus error: 4.80798565203e-05
# combiintegral: 5.31574362045e-08
# Current error: 0.997957477259
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 8707
# max surplus error: 2.69373544387e-06 total surplus error: 3.87759216254e-05
# combiintegral: 1.19247269475e-05
# Current error: 0.541803974955
# Finished refinement
# Refined  4  times
# New lmax: [4, 4, 4, 4, 4]
# Curent number of function evaluations 9375
# max surplus error: 3.65941763243e-06 total surplus error: 4.41651218642e-05
# combiintegral: 1.51152810631e-05
# Current error: 0.41921003885
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 10912
# max surplus error: 2.43102940757e-06 total surplus error: 3.21350750889e-05
# combiintegral: 2.17358419447e-05
# Current error: 0.164821431643
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 11236
# max surplus error: 1.67899360922e-06 total surplus error: 2.82816247948e-05
# combiintegral: 2.6816700864e-05
# Current error: 0.0304056264603
# Finished refinement
# Refined  4  times
# New lmax: [4, 4, 4, 4, 5]
# Curent number of function evaluations 15610
# max surplus error: 2.43365881167e-06 total surplus error: 2.50114644681e-05
# combiintegral: 1.13008118761e-05
# Current error: 0.565777304236
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 19015
# max surplus error: 1.35737976903e-06 total surplus error: 1.62850407077e-05
# combiintegral: 1.37939097119e-05
# Current error: 0.469982446756
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 19750
# max surplus error: 1.0009911755e-06 total surplus error: 1.40577456462e-05
# combiintegral: 1.51633102454e-05
# Current error: 0.417364564274
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 20512
# max surplus error: 9.00311652011e-07 total surplus error: 1.23839247195e-05
# combiintegral: 1.60220329329e-05
# Current error: 0.384368980917
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 21325
# max surplus error: 7.05886723715e-07 total surplus error: 1.05141417274e-05
# combiintegral: 1.68724521996e-05
# Current error: 0.351692448419
# Finished refinement
# Refined  4  times
# New lmax: [4, 4, 4, 5, 5]
# Curent number of function evaluations 22443
# max surplus error: 1.20541678762e-06 total surplus error: 1.06855221273e-05
# combiintegral: 1.7929651888e-05
# Current error: 0.311070579503
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 22749
# max surplus error: 4.52474914323e-07 total surplus error: 7.95070718795e-06
# combiintegral: 1.97848309302e-05
# Current error: 0.239787130699
# Finished refinement
# Refined  4  times
# New lmax: [4, 4, 5, 5, 5]
# Curent number of function evaluations 23341
# max surplus error: 7.52221410422e-07 total surplus error: 8.00503705662e-06
# combiintegral: 2.03658258646e-05
# Current error: 0.217462965904
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 23647
# max surplus error: 3.65729899479e-07 total surplus error: 6.30960055758e-06
# combiintegral: 2.15563670273e-05
# Current error: 0.171717580635
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 25568
# max surplus error: 3.95677757405e-07 total surplus error: 5.86576455099e-06
# combiintegral: 2.09194923449e-05
# Current error: 0.196188870355
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 26432
# max surplus error: 2.70357425103e-07 total surplus error: 5.16672549182e-06
# combiintegral: 2.35031297923e-05
# Current error: 0.0969151164336
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 26783
# max surplus error: 4.53059053779e-07 total surplus error: 5.61054243028e-06
# combiintegral: 2.37815311569e-05
# Current error: 0.0862178150034
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 27134
# max surplus error: 2.03925923912e-07 total surplus error: 4.62203688248e-06
# combiintegral: 2.45193051201e-05
# Current error: 0.05786956864
# Finished refinement
# Refined  2  times
# New lmax: [4, 5, 5, 5, 5]
# Curent number of function evaluations 27665
# max surplus error: 3.63460606834e-07 total surplus error: 4.98294198054e-06
# combiintegral: 2.56752450998e-05
# Current error: 0.0134537001497
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 28016
# max surplus error: 1.32023332338e-07 total surplus error: 4.17745577743e-06
# combiintegral: 2.62893431226e-05
# Current error: 0.0101424185936
# Finished refinement
# Refined  2  times
# New lmax: [5, 5, 5, 5, 5]
# Curent number of function evaluations 28367
# max surplus error: 3.01790005591e-07 total surplus error: 4.99014369084e-06
# combiintegral: 2.53141984632e-05
# Current error: 0.0273265657047
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 28718
# max surplus error: 1.20967348138e-07 total surplus error: 4.33731186573e-06
# combiintegral: 2.57667454015e-05
# Current error: 0.0099378901269
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 29420
# max surplus error: 2.98557233937e-07 total surplus error: 4.85112375692e-06
# combiintegral: 2.55726637375e-05
# Current error: 0.0173952891394
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 29771
# max surplus error: 1.35874165097e-07 total surplus error: 4.25904612994e-06
# combiintegral: 2.59281330989e-05
# Current error: 0.00373672495395
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 30428
# max surplus error: 2.14186856529e-07 total surplus error: 4.12611785442e-06
# combiintegral: 2.62726619875e-05
# Current error: 0.00950146221437
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 30734
# max surplus error: 1.0938263682e-07 total surplus error: 3.63961237562e-06
# combiintegral: 2.65848752395e-05
# Current error: 0.0214979525058
# Finished refinement
# Refined  6  times
# Rebalancing!
# Curent number of function evaluations 33158
# max surplus error: 2.35249221082e-07 total surplus error: 4.62462518006e-06
# combiintegral: 2.62052132232e-05
# Current error: 0.0069098091039
# Finished refinement
# Refined  6  times
# Curent number of function evaluations 34081
# max surplus error: 1.04219300351e-07 total surplus error: 3.13827225195e-06
# combiintegral: 2.70579691348e-05
# Current error: 0.0396761249074
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 34432
# max surplus error: 2.07370677181e-07 total surplus error: 3.27798289396e-06
# combiintegral: 2.71047310621e-05
# Current error: 0.0414729064438
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 34783
# max surplus error: 7.58442813487e-08 total surplus error: 2.87093455326e-06
# combiintegral: 2.73168306028e-05
# Current error: 0.0496226248327
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 36398
# max surplus error: 7.22239066329e-08 total surplus error: 2.80659729318e-06
# combiintegral: 2.79849051671e-05
# Current error: 0.0752927396403
# Finished refinement
# Refined  4  times
# New lmax: [5, 5, 5, 5, 6]
# Curent number of function evaluations 55150
# max surplus error: 1.64839723545e-07 total surplus error: 2.47741259585e-06
# combiintegral: 2.30994437708e-05
# Current error: 0.112426358848
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 59239
# max surplus error: 6.89435720911e-08 total surplus error: 2.10424895256e-06
# combiintegral: 2.30160369075e-05
# Current error: 0.11563118638
# Finished refinement
# Refined  6  times
# New lmax: [5, 5, 5, 6, 6]
# Curent number of function evaluations 61261
# max surplus error: 1.63190607157e-07 total surplus error: 2.60673395103e-06
# combiintegral: 2.32047991287e-05
# Current error: 0.108378181779
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 62446
# max surplus error: 1.24324334025e-07 total surplus error: 2.00933907764e-06
# combiintegral: 2.3537519848e-05
# Current error: 0.09559371202
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 63283
# max surplus error: 6.55674896635e-08 total surplus error: 1.75514514577e-06
# combiintegral: 2.36917665694e-05
# Current error: 0.089666931897
# Finished refinement
# Refined  2  times
# New lmax: [5, 5, 6, 6, 6]
# Curent number of function evaluations 63634
# max surplus error: 1.34251410358e-07 total surplus error: 1.9549040884e-06
# combiintegral: 2.380939102e-05
# Current error: 0.0851473268825
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 63985
# max surplus error: 5.80708840241e-08 total surplus error: 1.68664460471e-06
# combiintegral: 2.40149284687e-05
# Current error: 0.0772497504957
# Finished refinement
# Refined  4  times
# Curent number of function evaluations
012826254463164941, 0.0012826254463164941, 0.0012826254463164941, 0.0012826254463164941, 0.0012826254463164941, 0.0012826254463164941, 0.0012826254463164941, 0.0012826254463164941, 0.0012826254463164941, 0.0012826254463164941, 0.0010626581350536074, 0.0010626581350536074, 0.0010626581350540515, 0.0010626581350540515, 0.0010626581350540515, 0.0010626581350540515, 0.0010626581350540515, 0.0010626581350540515, 0.0010626581350540515, 0.0011101700498342892, 0.0011101700498342892, 0.0011101700498342892, 0.0011101700498342892, 0.0011101700498342892, 0.0011101700498342892, 0.0011101700498342892, 0.0011101700498342892, 0.0011101700498342892, 0.0011101700498342892, 0.0011101700498342892, 0.0011101700498342892, 0.00070969617571550649, 0.00070969617571550649, 0.00070969617571550649, 0.000709696 ...

# %%
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzCornerPeak(coeffs=coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCell()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()

reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

#operation = Integration(f=f, grid=None, dim=dim, reference_solution=reference_solution)
#adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, no_initial_splitting=False,version=0, automatic_extend_split=True)
from GridOperation import *
operationSingleDim = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceSingleDim = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=6, operation=operationSingleDim)
adaptiveCombiInstanceSingleDim3 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=6, operation=operationSingleDim, rebalancing=False)

#operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)

#adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, operation=operation, no_initial_splitting=False,version=0, automatic_extend_split=True)

#adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, operation=operation, no_initial_splitting=False,version=0)
#adaptiveCombiInstanceCell = SpatiallyAdaptiveCellScheme(np.ones(dim)*a, np.ones(dim)*b,grid, operation=operation)

algorithmArray = [(adaptiveCombiInstanceSingleDim3,1,2, errorOperatorSingleDim, 'SingleDim  strategy 3')]
evaluation_points = get_cross_product_list([np.linspace(a, b, 11)[1:-1] for d in range(dim)])
print(len(evaluation_points))
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,9,grid,1,2, max_evaluations=1000000, evaluation_points = evaluation_points )
# Out:
# Cannot plot function with dim > 2
# 59049
# Exact integral 2.60253827962e-05
# Reference solution: 2.60253827962e-05
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# Curent number of function evaluations 1053
# max surplus error: 0.000301497157693 total surplus error: 0.00253418612504
# combiintegral: -0.00128183702377
# Current error: 50.2533398569
# Finished refinement
# Refined  6  times
# New lmax: [2, 2, 3, 2, 2]
# New lmax: [2, 2, 3, 3, 2]
# New lmax: [2, 2, 3, 3, 3]
# Curent number of function evaluations 1620
# max surplus error: 0.000239166696043 total surplus error: 0.00150050690057
# combiintegral: -0.00119444595343
# Current error: 46.8954230486
# Finished refinement
# Refined  2  times
# New lmax: [2, 3, 3, 3, 3]
# Curent number of function evaluations 1863
# max surplus error: 0.00014043353606 total surplus error: 0.00120063816932
# combiintegral: -0.000670569012291
# Current error: 26.7659615438
# Finished refinement
# Refined  2  times
# New lmax: [3, 3, 3, 3, 3]
# Curent number of function evaluations 2133
# max surplus error: 0.000115390421712 total surplus error: 0.00118997686792
# combiintegral: -0.000218732831849
# Current error: 9.40459614223
# Finished refinement
# Refined  6  times
# New lmax: [3, 3, 4, 3, 3]
# New lmax: [3, 3, 4, 4, 3]
# New lmax: [3, 3, 4, 4, 4]
# Curent number of function evaluations 3033
# max surplus error: 0.000163770559111 total surplus error: 0.00149487757016
# combiintegral: -0.00105382448858
# Current error: 41.4921801472
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 3573
# max surplus error: 0.000122799469789 total surplus error: 0.000812322879619
# combiintegral: -0.000416544456455
# Current error: 17.0053152615
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 3843
# max surplus error: 6.95137606836e-05 total surplus error: 0.000609510410744
# combiintegral: -0.000132506888996
# Current error: 6.09144822321
# Finished refinement
# Refined  2  times
# New lmax: [3, 4, 4, 4, 4]
# Curent number of function evaluations 4113
# max surplus error: 8.99170650952e-05 total surplus error: 0.000686414023237
# combiintegral: -0.0001185822895
# Current error: 5.55640904221
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 4383
# max surplus error: 4.3310908701e-05 total surplus error: 0.000561393858112
# combiintegral: 0.000107250492562
# Current error: 3.1209957756
# Finished refinement
# Refined  6  times
# New lmax: [4, 4, 4, 4, 4]
# New lmax: [4, 4, 4, 5, 4]
# New lmax: [4, 4, 4, 5, 5]
# Curent number of function evaluations 6558
# max surplus error: 5.79820522227e-05 total surplus error: 0.000629220129358
# combiintegral: -0.000341132100981
# Current error: 14.1076689112
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 6828
# max surplus error: 4.91885182521e-05 total surplus error: 0.000486269945985
# combiintegral: -0.000214049819787
# Current error: 9.22465596235
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 7098
# max surplus error: 4.3001507094e-05 total surplus error: 0.00037496170481
# combiintegral: -0.000104271559348
# Current error: 5.00653316666
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 7638
# max surplus error: 2.45109086902e-05 total surplus error: 0.000298980134969
# combiintegral: -2.85382753578e-05
# Current error: 2.09655545055
# Finished refinement
# Refined  2  times
# New lmax: [4, 4, 5, 5, 5]
# Curent number of function evaluations 7908
# max surplus error: 3.85378669147e-05 total surplus error: 0.00034279720364
# combiintegral: -1.94440115971e-05
# Current error: 1.74711721819
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 8178
# max surplus error: 1.67468593742e-05 total surplus error: 0.000259170591325
# combiintegral: 6.69122103537e-05
# Current error: 1.57103654834
# Finished refinement
# Refined  2  times
# New lmax: [4, 5, 5, 5, 5]
# Curent number of function evaluations 8448
# max surplus error: 2.5675617131e-05 total surplus error: 0.000287792629575
# combiintegral: 7.80047192176e-05
# Current error: 1.99725540363
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 8718
# max surplus error: 1.21160679512e-05 total surplus error: 0.000224336392546
# combiintegral: 0.000134202252405
# Current error: 4.15659091186
# Finished refinement
# Refined  2  times
# New lmax: [4, 5, 5, 5, 6]
# Curent number of function evaluations 12349
# max surplus error: 1.65599589472e-05 total surplus error: 0.000161301800127
# combiintegral: -0.000115019212399
# Current error: 5.41950127302
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 12619
# max surplus error: 8.8928813773e-06 total surplus error: 0.000121886454691
# combiintegral: -7.96121795314e-05
# Current error: 4.05902050144
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 13603
# max surplus error: 7.79194568613e-06 total surplus error: 0.000108397412879
# combiintegral: -6.82692664728e-05
# Current error: 3.62318010872
# Finished refinement
# Refined  2  times
# New lmax: [4, 5, 5, 6, 6]
# Curent number of function evaluations 13873
# max surplus error: 1.31662415937e-05 total surplus error: 0.00012603598628
# combiintegral: -6.29158041191e-05
# Current error: 3.41747852901
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 14143
# max surplus error: 5.30044913152e-06 total surplus error: 9.35526253181e-05
# combiintegral: -3.5483764357e-05
# Current error: 2.36342910438
# Finished refinement
# Refined  2  times
# New lmax: [4, 5, 6, 6, 6]
# Curent number of function evaluations 14413
# max surplus error: 9.55289248787e-06 total surplus error: 0.000106841551649
# combiintegral: -2.87025615729e-05
# Current error: 2.10286798844
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 14683
# max surplus error: 4.32019587268e-06 total surplus error: 8.19344571127e-05
# combiintegral: -9.74163825014e-06
# Current error: 1.37431296694
# Finished refinement
# Refined  2  times
# New lmax: [5, 5, 6, 6, 6]
# Curent number of function evaluations 15223
# max surplus error: 8.64177587699e-06 total surplus error: 9.89498443695e-05
# combiintegral: 3.11106821896e-07
# Current error: 0.98804602321
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 15763
# max surplus error: 3.51155921325e-06 total surplus error: 8.04154899454e-05
# combiintegral: 1.4680697258e-05
# Current error: 0.435908498526
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 16774
# max surplus error: 2.42748170819e-06 total surplus error: 7.48764274762e-05
# combiintegral: 1.92664449804e-05
# Current error: 0.259705606204
# Finished refinement
# Refined  2  times
# New lmax: [5, 6, 6, 6, 6]
# Curent number of function evaluations 17044
# max surplus error: 5.94625311349e-06 total surplus error: 8.62932646858e-05
# combiintegral: 2.67175670307e-05
# Current error: 0.026596505417
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 17314
# max surplus error: 2.11621945057e-06 total surplus error: 7.1126999178e-05
# combiintegral: 3.72942153921e-05
# Current error: 0.432993923051
# Finished refinement
# Refined  4  times
# New lmax: [5, 6, 6, 6, 7]
# Curent number of function evaluations 24491
# max surplus error: 2.63922385711e-06 total surplus error: 4.86186060828e-05
# combiintegral: -5.51761476586e-05
# Current error: 3.12008976354
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 24761
# max surplus error: 3.38981140547e-06 total surplus error: 4.98772707963e-05
# combiintegral: -5.27571900701e-05
# Current error: 3.0271436729
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 25031
# max surplus error: 1.50674588598e-06 total surplus error: 4.23498516325e-05
# combiintegral: -4.55157404561e-05
# Current error: 2.74889802054
# Finished refinement
# Refined  4  times
# New lmax: [5, 6, 6, 7, 7]
# Curent number of function evaluations 26997
# max surplus error: 2.783294693e-06 total surplus error: 4.40094633675e-05
# combiintegral: -4.16397210448e-05
# Current error: 2.5999657477
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 27267
# max surplus error: 1.33017059345e-06 total surplus error: 3.73320116951e-05
# combiintegral: -3.64643679685e-05
# Current error: 2.4011078436
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 30055
# max surplus error: 1.87582172401e-06 total surplus error: 3.72141839807e-05
# combiintegral: -3.59133938511e-05
# Current error: 2.37993719948
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 31066
# max surplus error: 1.11096934946e-06 total surplus error: 3.43136951749e-05
# combiintegral: -3.30155335218e-05
# Current error: 2.26858973719
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 33989
# max surplus error: 1.02541835576e-06 total surplus error: 3.23585524754e-05
# combiintegral: -3.18225924941e-05
# Current error: 2.22275213945
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 35135
# max surplus error: 8.09807162013e-07 total surplus error: 3.09788024443e-05
# combiintegral: -3.02291543485e-05
# Current error: 2.16152582981
# Finished refinement
# Refined  8  times
# New lmax: [6, 6, 6, 7, 7]
# New lmax: [6, 6, 7, 7, 7]
# Curent number of function evaluations 39498
# max surplus error: 1.91525458093e-06 total surplus error: 3.3849678874e-05
# combiintegral: -2.19735330249e-05
# Current error: 1.84431161674
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 39768
# max surplus error: 1.32224255017e-06 total surplus error: 2.94843219528e-05
# combiintegral: -1.87002245057e-05
# Current error: 1.71853792323
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 40362
# max surplus error: 7.00875914016e-07 total surplus error: 2.61978017309e-05
# combiintegral: -1.64391486164e-05
# Current error: 1.63165828319
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 42210
# max surplus error: 5.89316867827e-07 total surplus error: 2.42342075244e-05
# combiintegral: -1.72056878414e-05
# Current error: 1.66111180673
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 43410
# max surplus error: 8.4176280596e-07 total surplus error: 2.47017599675e-05
# combiintegral: -1.69532188606e-05
# Current error: 1.65141093191
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 44556
# max surplus error: 5.08097462636e-07 total surplus error: 2.34123959608e-05
# combiintegral: -1.55206172502e-05
# Current error: 1.59636460957
# Finished refinement
# Refined  8  times
# New lmax: [6, 6, 7, 8, 7]
# Curent number of function evaluations 64284
# max surplus error: 6.20500749424e-07 total surplus error: 2.46582473169e-05
# combiintegral: -2.43599854614e-05
# Current error: 1.93600872856
# Finished refinement
# Refined  6  times
# Curent number of function evaluations 68920
# max surplus error: 5.03119368337e-07 total surplus error: 2.26325645119e-05
# combiintegral: -2.24891059546e-05
# Current error: 1.86412200469
# Finished refinement
# Refined  4  times
# New lmax: [6, 7, 7, 8, 7]
# Curent number of function evaluations 73473
# max surplus error: 6.74630915622e-07 total surplus error: 2.15613413299e-05
# combiintegral: -2.08574540325e-05
# Current error: 1.80142736788
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 74013
# max surplus error: 4.42678872368e-07 total surplus error: 1.99836802672e-05
# combiintegral: -1.9659830094e-05
# Current error: 1.75540983385
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 79809
# max surplus error: 4.04600211272e-07 total surplus error: 1.91457576201e-05
# combiintegral: -1.92397233359e-05
# Current error: 1.73926764062
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 82371
# max surplus error: 4.22685534339e-07 total surplus error: 1.87630826187e-05
# combiintegral: -1.84453323623e-05
# Current error: 1.70874394074
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 83679
# max surplus error: 3.38109432548e-07 total surplus error: 1.8166388434e-05
# combiintegral: -1.78268476355e-05
# Current error: 1.68497926717
# Finished refinement
# Refined  4  times
# New lmax: [6, 7, 7, 8, 8]
# Curent number of function evaluations 84489
# max surplus error: 6.61047275645e-07 total surplus error: 1.89215631883e-05
# combiintegral: -1.67922837414e-05
# Current error: 1.64522715661
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 84759
# max surplus error: 4.05336369366e-07 total surplus error: 1.75477582109e-05
# combiintegral: -1.55986575089e-05
# Current error: 1.59936323055
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 85299
# max surplus error: 2.84381796644e-07 total surplus error: 1.6655503378e-05
# combiintegral: -1.489973938e-05

# %%
midpoint = np.ones(dim) * 0.99
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzCornerPeak(coeffs=coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCell()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()

reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

#operation = Integration(f=f, grid=None, dim=dim, reference_solution=reference_solution)
#adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, no_initial_splitting=False,version=0, automatic_extend_split=True)
from GridOperation import *
operationSingleDim = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceSingleDim = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=6, operation=operationSingleDim)
adaptiveCombiInstanceSingleDim3 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=6, operation=operationSingleDim, rebalancing=False)

#operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)

#adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, operation=operation, no_initial_splitting=False,version=0, automatic_extend_split=True)

#adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, operation=operation, no_initial_splitting=False,version=0)
#adaptiveCombiInstanceCell = SpatiallyAdaptiveCellScheme(np.ones(dim)*a, np.ones(dim)*b,grid, operation=operation)

algorithmArray = [] #[(adaptiveCombiInstanceSingleDim,1,2, errorOperatorSingleDim, 'SingleDim rebalance linear strategy 3'), (adaptiveCombiInstanceSingleDim3,1,2, errorOperatorSingleDim, 'SingleDim  strategy 3')]
evaluation_points = get_cross_product_list([np.linspace(a, b, 11)[1:-1] for d in range(dim)])
print(len(evaluation_points))
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,9,grid,1,2, max_evaluations=1000000, evaluation_points = evaluation_points )
