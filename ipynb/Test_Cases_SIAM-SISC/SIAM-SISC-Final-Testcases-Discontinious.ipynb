# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sys import path
path.append('../../src/')
#path.append('../../../src/tools')
import numpy as np

#from numpy import *
import scipy as sp
from spatiallyAdaptiveExtendSplit import *
from spatiallyAdaptiveSingleDimension2 import *
from spatiallyAdaptiveCell import *

from PerformTestCase import *
from Function import *
from ErrorCalculator import *
from Utils import *
import math
dim = 5
a = 0
b = 1
grid=TrapezoidalGrid(np.ones(dim)*a, np.ones(dim)*b, modified_basis=False, boundary=True)
grid_single_dim = GlobalBSplineGrid(a=a*np.ones(dim), b=b*np.ones(dim), p=3, modified_basis=False, boundary=True)
grid_single_dim2 = GlobalLagrangeGrid(a=a*np.ones(dim), b=b*np.ones(dim), p=3, modified_basis=False, boundary=True)
grid_single_dim_lin = GlobalTrapezoidalGrid(a=a*np.ones(dim), b=b*np.ones(dim), modified_basis=False, boundary=True)

# %%
midpoint = np.ones(dim) * 0.2
coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
f = GenzDiscontinious(border=midpoint,coeffs=coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorSurplusCell()
errorOperator2=ErrorCalculatorExtendSplit()
errorOperatorSingleDim = ErrorCalculatorSingleDimVolumeGuided()

reference_solution = f.getAnalyticSolutionIntegral(np.ones(dim)*a, np.ones(dim)*b)

#operation = Integration(f=f, grid=None, dim=dim, reference_solution=reference_solution)
#adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, no_initial_splitting=False,version=0, automatic_extend_split=True)
from GridOperation import *
operationSingleDim = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
operationSingleDim2 = Integration(f=f, grid=grid_single_dim_lin, dim=dim, reference_solution=reference_solution)
adaptiveCombiInstanceSingleDim = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=6, operation=operationSingleDim)
adaptiveCombiInstanceSingleDim3 = SpatiallyAdaptiveSingleDimensions2(np.ones(dim) * a, np.ones(dim) * b, dim_adaptive=True, version=6, operation=operationSingleDim, rebalancing=False)

#operation = Integration(f=f, grid=grid, dim=dim, reference_solution=reference_solution)

#adaptiveCombiInstanceExtend2 = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, operation=operation, no_initial_splitting=False,version=0, automatic_extend_split=True)

#adaptiveCombiInstanceExtend = SpatiallyAdaptiveExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, operation=operation, no_initial_splitting=False,version=0)
#adaptiveCombiInstanceCell = SpatiallyAdaptiveCellScheme(np.ones(dim)*a, np.ones(dim)*b,grid, operation=operation)

algorithmArray = [(adaptiveCombiInstanceSingleDim,1,2, errorOperatorSingleDim, 'SingleDim rebalance linear strategy 3'), (adaptiveCombiInstanceSingleDim3,1,2, errorOperatorSingleDim, 'SingleDim  strategy 3')]
evaluation_points = get_cross_product_list([np.linspace(a, b, 11)[1:-1] for d in range(dim)])
#print(evaluation_points)
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,10,dim,9,grid,1,2, max_evaluations=1000000, evaluation_points = evaluation_points )
# Out:
# Cannot plot function with dim > 2
# Exact integral 7.82141744205e-05
# Reference solution: 7.82141744205e-05
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# Curent number of function evaluations 1053
# max surplus error: 0.000244140625 total surplus error: 0.00244140625
# combiintegral: -0.00146484375
# Current error: 19.72862254
# Finished refinement
# Refined  10  times
# New lmax: [3, 2, 2, 2, 2]
# New lmax: [3, 3, 2, 2, 2]
# New lmax: [3, 3, 3, 2, 2]
# New lmax: [3, 3, 3, 3, 2]
# New lmax: [3, 3, 3, 3, 3]
# Curent number of function evaluations 2133
# max surplus error: 0.0001220703125 total surplus error: 0.00195782272818
# combiintegral: 0.00146014602182
# Current error: 17.6685601764
# Finished refinement
# Refined  12  times
# Rebalancing!
# New lmax: [4, 3, 3, 3, 3]
# New lmax: [4, 4, 3, 3, 3]
# New lmax: [4, 4, 4, 3, 3]
# New lmax: [4, 4, 4, 4, 3]
# New lmax: [4, 4, 4, 4, 4]
# Curent number of function evaluations 4221
# max surplus error: 5.61466468707e-05 total surplus error: 0.000494861828758
# combiintegral: 0.000263266328072
# Current error: 2.36596697494
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 5106
# max surplus error: 2.10669116327e-05 total surplus error: 0.000207865330515
# combiintegral: 0.000117020802386
# Current error: 0.496158506466
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 6201
# max surplus error: 7.83069235754e-06 total surplus error: 7.77982423419e-05
# combiintegral: 0.000119384594386
# Current error: 0.526380547651
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 7011
# max surplus error: 6.13782235426e-06 total surplus error: 5.63734400731e-05
# combiintegral: 6.68378118873e-05
# Current error: 0.145451417438
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 8447
# max surplus error: 3.90937740032e-06 total surplus error: 3.61940996521e-05
# combiintegral: 8.95758914781e-05
# Current error: 0.145264169081
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 8798
# max surplus error: 3.26823922891e-06 total surplus error: 3.55822170672e-05
# combiintegral: 8.6543292422e-05
# Current error: 0.106491157941
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 9401
# max surplus error: 2.72010195329e-06 total surplus error: 2.91634754501e-05
# combiintegral: 8.43317494384e-05
# Current error: 0.0782156823003
# Finished refinement
# Refined  4  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 11654
# max surplus error: 1.95506340286e-06 total surplus error: 2.1026764261e-05
# combiintegral: 8.81910432081e-05
# Current error: 0.127558321256
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 12032
# max surplus error: 1.67644066954e-06 total surplus error: 2.05117452248e-05
# combiintegral: 8.95537912166e-05
# Current error: 0.144981608259
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 12761
# max surplus error: 1.4034146202e-06 total surplus error: 1.8809180498e-05
# combiintegral: 8.70976843678e-05
# Current error: 0.11357928423
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 13598
# max surplus error: 1.2283513086e-06 total surplus error: 1.80824285973e-05
# combiintegral: 8.4902577775e-05
# Current error: 0.0855139545237
# Finished refinement
# Refined  4  times
# New lmax: [5, 4, 4, 4, 4]
# Curent number of function evaluations 16833
# max surplus error: 1.21543432029e-06 total surplus error: 1.51208415524e-05
# combiintegral: 8.3360222116e-05
# Current error: 0.0657943107326
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 18282
# max surplus error: 9.9283920604e-07 total surplus error: 1.47625203832e-05
# combiintegral: 7.86158393734e-05
# Current error: 0.0051354496272
# Finished refinement
# Refined  4  times
# New lmax: [5, 5, 4, 4, 4]
# New lmax: [5, 5, 5, 4, 4]
# Curent number of function evaluations 18984
# max surplus error: 7.86718142026e-07 total surplus error: 1.19712887634e-05
# combiintegral: 7.66137293918e-05
# Current error: 0.0204623399867
# Finished refinement
# Refined  2  times
# New lmax: [5, 5, 5, 5, 4]
# Curent number of function evaluations 19335
# max surplus error: 7.03683380636e-07 total surplus error: 1.08427347567e-05
# combiintegral: 7.57051272408e-05
# Current error: 0.0320791876707
# Finished refinement
# Refined  2  times
# New lmax: [5, 5, 5, 5, 5]
# Curent number of function evaluations 19686
# max surplus error: 5.88181068787e-07 total surplus error: 9.78803257598e-06
# combiintegral: 7.48859131598e-05
# Current error: 0.0425531725598
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 19980
# max surplus error: 4.87768597241e-07 total surplus error: 8.68179765746e-06
# combiintegral: 7.38912407202e-05
# Current error: 0.0552704638559
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 20871
# max surplus error: 4.39833160689e-07 total surplus error: 7.87183966139e-06
# combiintegral: 7.50309669089e-05
# Current error: 0.0406986014393
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 21681
# max surplus error: 3.93946005397e-07 total surplus error: 7.22424638277e-06
# combiintegral: 7.60010685254e-05
# Current error: 0.0282954580993
# Finished refinement
# Refined  4  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 23274
# max surplus error: 3.58109242108e-07 total surplus error: 6.2050763489e-06
# combiintegral: 7.73904297438e-05
# Current error: 0.0105319103968
# Finished refinement
# Refined  4  times
# Rebalancing!
# Curent number of function evaluations 24435
# max surplus error: 2.19004447063e-07 total surplus error: 4.98688832802e-06
# combiintegral: 7.72046370209e-05
# Current error: 0.0129073458507
# Finished refinement
# Refined  2  times
# New lmax: [6, 5, 5, 5, 5]
# Curent number of function evaluations 32851
# max surplus error: 2.19404324951e-07 total surplus error: 4.72455906584e-06
# combiintegral: 8.01677343614e-05
# Current error: 0.0249770576165
# Finished refinement
# Refined  2  times
# New lmax: [6, 6, 5, 5, 5]
# Curent number of function evaluations 33202
# max surplus error: 1.94346937824e-07 total surplus error: 4.47865388537e-06
# combiintegral: 8.03063323712e-05
# Current error: 0.0267490894858
# Finished refinement
# Refined  4  times
# New lmax: [6, 6, 6, 5, 5]
# Curent number of function evaluations 34210
# max surplus error: 1.63579338502e-07 total surplus error: 3.79963433143e-06
# combiintegral: 8.01396808187e-05
# Current error: 0.0246183816732
# Finished refinement
# Refined  2  times
# New lmax: [6, 6, 6, 6, 5]
# Curent number of function evaluations 34534
# max surplus error: 1.42989685922e-07 total surplus error: 3.54796758486e-06
# combiintegral: 8.034480868e-05
# Current error: 0.0272410247285
# Finished refinement
# Refined  6  times
# Rebalancing!
# Rebalancing!
# New lmax: [6, 6, 6, 6, 6]
# Curent number of function evaluations 41355
# max surplus error: 2.39118204836e-07 total surplus error: 3.90107593767e-06
# combiintegral: 8.31116245381e-05
# Current error: 0.0626158896879
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 42075
# max surplus error: 1.93737338966e-07 total surplus error: 3.5607503971e-06
# combiintegral: 8.21197389405e-05
# Current error: 0.0499342292991
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 42813
# max surplus error: 1.55410352231e-07 total surplus error: 3.33860500566e-06
# combiintegral: 8.12380897204e-05
# Current error: 0.0386619857881
# Finished refinement
# Refined  4  times
# Rebalancing!
# Curent number of function evaluations 44605
# max surplus error: 1.17454879014e-07 total surplus error: 2.95870632221e-06
# combiintegral: 8.06045943595e-05
# Current error: 0.0305624901971
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 45280
# max surplus error: 1.01716307639e-07 total surplus error: 2.81937461209e-06
# combiintegral: 7.9991488475e-05
# Current error: 0.0227236823456
# Finished refinement
# Refined  2  times
# New lmax: [7, 6, 6, 6, 6]
# Curent number of function evaluations 60927
# max surplus error: 9.05833226379e-08 total surplus error: 2.05742662364e-06
# combiintegral: 7.77956778146e-05
# Current error: 0.00535064915084
# Finished refinement
# Refined  4  times
# Rebalancing!
# Rebalancing!
# New lmax: [7, 7, 6, 6, 6]
# Curent number of function evaluations 66398
# max surplus error: 7.55140814092e-08 total surplus error: 1.70691703653e-06
# combiintegral: 7.75141399563e-05
# Current error: 0.00895022506336
# Finished refinement
# Refined  2  times
# New lmax: [7, 7, 7, 6, 6]
# Curent number of function evaluations 66722
# max surplus error: 6.43462330963e-08 total surplus error: 1.62238589272e-06
# combiintegral: 7.74867901314e-05
# Current error: 0.00929990368771
# Finished refinement
# Refined  4  times
# Rebalancing!
# New lmax: [7, 7, 7, 7, 6]
# Curent number of function evaluations 69409
# max surplus error: 5.31089896427e-08 total surplus error: 1.44276922743e-06
# combiintegral: 7.74084046015e-05
# Current error: 0.0103020945374
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 70120
# max surplus error: 4.75620776725e-08 total surplus error: 1.41742050163e-06
# combiintegral: 7.76520413388e-05
# Current error: 0.00718709985636
# Finished refinement
# Refined  6  times
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 83363
# max surplus error: 8.21326677848e-08 total surplus error: 2.35097420904e-06
# combiintegral: 7.72709542348e-05
# Current error: 0.0120594533244
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 84101
# max surplus error: 6.80866835799e-08 total surplus error: 2.19419447988e-06
# combiintegral: 7.76912455982e-05
# Current error: 0.00668585747015
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 87200
# max surplus error: 5.63624583604e-08 total surplus error: 2.0005532482e-06
# combiintegral: 7.77395585755e-05
# Current error: 0.00606815642548
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 87935
# max surplus error: 7.62745457744e-08 total surplus error: 2.02891764015e-06
# combiintegral: 7.77548812996e-05
# Current error: 0.00587224917099
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 88662
# max surplus error: 4.84270272841e-08 total surplus error: 1.95676698163e-06
# combiintegral: 7.78895360963e-05
# Current error: 0.00415063288289
# Finished refinement
# Refined  6  times
# Rebalancing!
# Rebalancing!
# New lmax: [8, 7, 7, 7, 6]
# Curent number of function evaluations 137104
# max surplus error: 1.15995372459e-07 total surplus error: 6.43523564902e-06
# combiintegral: 7.21139057682e-05
# Current error: 0.0779944133852
# Finished refinement
# Refined  10  times
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 172927
# max surplus error: 3.46131116322e-07 total surplus error: 1.65612703483e-05
# combiintegral: 8.04941818324e-05
# Current error: 0.0291508211752
# Finished refinement
# Refined  4  times
# New lmax: [9, 7, 7, 7, 6]
# Curent number of function evaluations 227921
# max surplus error: 5.33395052344e-07 total surplus error: 7.13496786688e-06
# combiintegral: 7.55570790745e-05
# Current error: 0.0339720436315
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 229556
# max surplus error: 2.90570089181e-07 total surplus error: 7.07773532259e-06
# combiintegral: 7.56523635304e-05
# Current error: 0.0327537931475
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 232912
# max surplus error: 3.30501201521e-07 total surplus error: 9.38307879916e-06
# combiintegral: 7.78708216347e-05
# Current error: 0.00438990487851
# Finished refinement
# Refined  4  times
# Rebalancing!
# Curent number of function evaluations 233614
# max surplus error: 1.9601521531e-07 total surplus error: 1.46479988486e-05
# combiintegral: 8.07522109968e-05
# Current error: 0.0324498288842
# Finished refinement
# Refined  6  times
# Rebalancing!
# Rebalancing!
# New lmax: [9, 7, 7, 7, 7]
# Curent number of function evaluations 244872
# max surplus error: 4.90042229981e-07 total surplus error: 2.30265649187e-05
# combiintegral: 7.10798780126e-05
# Current error: 0.0912148783874
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 264291
# max surplus error: 1.69621956648e-07 total surplus error: 6.50042048673e-06
# combiintegral: 7.79817490103e-05
# Current error: 0.00297165330901
# Finished refinement
# Refined  4  times
# Rebalancing!
# Curent number of function evaluations 296297
# max surplus error: 6.00816821603e-07 total surplus error: 1.80319041846e-05
# combiintegral: 6.75943409638e-05
# Current error: 0.135778885802
# Finished refinement
# Refined  6  times
# Curent number of function evaluations 307850
# max surplus error: 6.16362036625e-07 total surplus error: 1.55552918227e-05
# combiintegral: 6.79699464384e-05
# Current error: 0.130976617193
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 314093
# max surplus error: 4.29521656037e-07 total surplus error: 1.46407669124e-05
# combiintegral: 6.88643501912e-05
# Current error: 0.119541301799
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 317274
# max surplus error: 4.87969507108e-07 total surplus error: 1.40290591544e-05
# combiintegral: 6.95032086785e-05
# Current error: 0.111373236457
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 320455
# max surplus error: 3.33161889357e-07 total surplus error: 1.32121523673e-05
# combiintegral: 7.02501099204e-05
# Current error: 0.101823800597
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 330345
# max surplus error: 3.57139917362e-07 total surplus error: 1.23772023799e-05
# combiintegral: 7.11671143471e-05
# Current error: 0.0900995264048
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 340343
# max surplus error: 2.60511828222e-07 total surplus error: 1.1256279021e-05
# combiintegral: 7.22230038687e-05
# Current error: 0.076599549841
# Finished refinement
# Refined  8  times
# Rebalancing!
# New lmax: [9, 7, 8, 7, 7]
# New lmax: [9, 7, 8, 8, 7]
# Curent number of function evaluations 347912
# max surplus error: 2.94502718331e-07 total surplus error: 9.91463035116e-06
# combiintegral: 7.34826103435e-05
# Current error: 0.0604949692574
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 350960
# max surplus error: 2.34537275053e-07 total surplus error: 9.41569599446e-06
# combiintegral: 7.39306945133e-05
# Current error: 0.0547660310798
# Finished refinement
# Refined  2  times
# New lmax: [9, 7, 8, 8, 8]
# Curent number of function evaluations 351599
# max surplus error: 2.02628403856e-07 total surplus error: 9.2248059123e-06
# combiintegral: 7.44369151933e-05
# Current error: 0.0482937939981
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 354698
# max surplus error: 2.29484162397e-07 total surplus error: 8.92607694112e-06
# combiintegral: 7.47448786393e-05
# Current error: 0.0443563562097
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 357797
# max surplus error: 1.41809245063e-07 total surplus error: 8.53778515409e-06
# combiintegral: 7.50938469417e-05
# Current error: 0.0398946546706
# Finished refinement
# Refined  4  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 366050
# max surplus error: 1.87425228134e-07 total surplus error: 8.31992447712e-06
# combiintegral: 7.45755595295e-05
# Current error: 0.0465211698264
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 373543
# max surplus error: 1.93532867707e-07 total surplus error: 8.09581247644e-06
# combiintegral: 7.68223907135e-05
# Current error: 0.0177945202043
# Finished refinement
# Refined  2  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 390613
# max surplus error: 1.19691185007e-07 total surplus error: 7.75521295538e-06
# combiintegral: 7.5485810455e-05
# Current error: 0.0348832418892
# Finished refinement
# Refined  12  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 422203
# max surplus error: 1.5622449727e-07 total surplus error: 7.22106417816e-06
# combiintegral: 7.42489340669e-05
# Current error: 0.0506972090799
# Finished refinement
# Refined  2  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 433796
# max surplus error: 2.09900502373e-07 total surplus error: 9.71625418877e-06
# combiintegral: 7.83921276626e-05
# Current error: 0.00227520450635
# Finished refinement
# Refined  4  times
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 466054
# max surplus error: 1.35058577835e-07 total surplus error: 6.4469612967e-06
# combiintegral: 7.57271764913e-05
# Current error: 0.0317972790441
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 474724
# max surplus error: 1.06937979863e-07 total surplus error: 6.18680207005e-06
# combiintegral: 7.59341183602e-05
# Current error: 0.0291514431649
# Finished refinement
# Refined  6  times
# New lmax: [9, 8, 8, 8, 8]
# Curent number of function evaluations 478645
# max surplus error: 7.58469345318e-08 total surplus error: 5.49682416108e-06
# combiintegral: 7.66925447301e-05
# Current error: 0.0194546538615
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 485827
# max surplus error: 6.49118019827e-08 total surplus error: 5.23194203441e-06
# combiintegral: 7.69481473025e-05
# Current error: 0.016186671117
# Finished refinement
# Refined  6  times
# Curent number of function evaluations 497935
# max surplus error: 5.7129492233e-08 total surplus error: 4.98644751278e-06
# combiintegral: 7.71739636752e-05
# Current error: 0.0132995170384
# Finished refinement
# Refined  12  times
# Rebalancing!
# Rebalancing!
# New lmax: [9, 9, 8, 8, 8]
# Curent number of function evaluations 527724
# max surplus error: 1.15151855761e-07 total surplus error: 6.19649365752e-06
# combiintegral: 7.54237512228e-05
# Current error: 0.0356766943893
# Finished refinement
# Refined  2  times
# Rebalancing!
# Curent number of function evaluations 529737
# max surplus error: 6.28862423145e-08 total surplus error: 5.99219621605e-06
# combiintegral: 7.49213119026e-05
# Current error: 0.0421005852494
# Finished refinement
# Refined  4  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 544625
# max surplus error: 1.61474045465e-07 total surplus error: 5.65418025604e-06
# combiintegral: 7.8319456925e-05
# Current error: 0.0013460795979
# Finished refinement
# Refined  6  times
# Rebalancing!
# Curent number of function evaluations 553632
# max surplus error: 5.10296832184e-08 total surplus error: 5.68010511542e-06
# combiintegral: 7.52253444093e-05
# Current error: 0.0382134061164
# Finished refinement
# Refined  2  times
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 570298
# max surplus error: 9.24862195116e-08 total surplus error: 4.73818727393e-06
# combiintegral: 7.67677841887e-05
# Current error: 0.0184926868124
# Finished refinement
# Refined  4  times
# Rebalancing!
# Curent number of function evaluations 577174
# max surplus error: 1.40833560968e-07 total surplus error: 1.3962175413e-05
# combiintegral: 8.36990820296e-05
# Current error: 0.0701267724127
# Finished refinement
# Refined  28  times
# Rebalancing!
# Curent number of function evaluations 663020
# max surplus error: 6.06027942361e-08 total surplus error: 2.87780320031e-06
# combiintegral: 7.5314247625e-05
# Current error: 0.0370767423811
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 664550
# max surplus error: 3.56922218337e-08 total surplus error: 2.67784949602e-06
# combiintegral: 7.53709894924e-05
# Current error: 0.0363512745504
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 665846
# max surplus error: 2.82117614833e-08 total surplus error: 2.56031235722e-06
# combiintegral: 7.53903494666e-05
# Current error: 0.0361037494141
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 670753
# max surplus error: 2.04526756715e-08 total surplus error: 2.4772461556e-06
# combiintegral: 7.52928289346e-05
# Current error: 0.0373505890408
# Finished refinement
# Refined  40  times
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 704818
# max surplus error: 6.55620432695e-08 total surplus error: 1.06853042565e-05
# combiintegral: 8.46123070122e-05
# Current error: 0.0818027248776
# Finished refinement
# Refined  6  times
# Rebalancing!
# Curent number of function evaluations 726461
# max surplus error: 5.88634210199e-08 total surplus error: 1.06885857083e-05
# combiintegral: 8.52227776247e-05
# Current error: 0.0896078397057
# Finished refinement
# Refined  28  times
# Rebalancing!
# Curent number of function evaluations 809972
# max surplus error: 4.00762151947e-08 total surplus error: 2.18492757742e-06
# combiintegral: 7.64448336026e-05
# Current error: 0.0226217412765
# Finished refinement
# Refined  4  times
# Rebalancing!
# Curent number of function evaluations 815186
# max surplus error: 2.53619416014e-08 total surplus error: 1.96888521615e-06
# combiintegral: 7.63849533544e-05
# Current error: 0.0233873345812
# Finished refinement
# Refined  26  times
# Rebalancing!
# Curent number of function evaluations 856347
# max surplus error: 1.62699562491e-08 total surplus error: 8.95104850049e-07
# combiintegral: 7.70784895837e-05
# Current error: 0.0145201920905
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 859371
# max surplus error: 1.17845463399e-08 total surplus error: 8.95757678992e-07
# combiintegral: 7.74838243367e-05
# Current error: 0.00933782257755
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 861030
# max surplus error: 8.71796604794e-09 total surplus error: 8.75800641635e-07
# combiintegral: 7.75013537369e-05
# Current error: 0.00911370207404
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 868335
# max surplus error: 9.16204046014e-09 total surplus error: 8.08788262278e-07
# combiintegral: 7.75589413288e-05
# Current error: 0.00837742131303
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 872469
# max surplus error: 7.38242562149e-09 total surplus error: 7.93929798046e-07
# combiintegral: 7.75699940296e-05
# Current error: 0.00823610804127
# Finished refinement
# Refined  6  times
# Curent number of function evaluations 882396
# max surplus error: 6.30674859571e-09 total surplus error: 7.62704074252e-07
# combiintegral: 7.7601307418e-05
# Current error: 0.0078357536474
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 889032
# max surplus error: 7.39380484701e-09 total surplus error: 7.24261404475e-07
# combiintegral: 7.76383118476e-05
# Current error: 0.00736263697932
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 890691
# max surplus error: 5.74472116071e-09 total surplus error: 7.11810891214e-07
# combiintegral: 7.7649251635e-05
# Current error: 0.00722276735222
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 892350
# max surplus error: 5.01913243707e-09 total surplus error: 7.02094759301e-07
# combiintegral: 7.76577715501e-05
# Current error: 0.00711383677652
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 922443
# max surplus error: 4.24686569866e-09 total surplus error: 6.68423048182e-07
# combiintegral: 7.76994911133e-05
# Current error: 0.00658043520976
# Finished refinement
# Refined  12  times
# New lmax: [9, 9, 9, 8, 8]
# Curent number of function evaluations 931548
# max surplus error: 3.60570128732e-09 total surplus error: 5.91840665991e-07
# combiintegral: 7.77020268158e-05
# Current error: 0.00654801522268
# Finished refinement
# Refined  8  times
# New lmax: [9, 9, 9, 9, 8]
# New lmax: [9, 9, 9, 9, 9]
# Curent number of function evaluations 940820
# max surplus error: 3.1298635576e-09 total surplus error: 4.80555176503e-07
# combiintegral: 7.76266771616e-05
# Current error: 0.00751139116702
# Finished refinement
# Refined  16  times
# Rebalancing!
# Curent number of function evaluations 959686
# max surplus error: 3.73780349173e-08 total surplus error: 2.72476002714e-06
# combiintegral: 7.7663244501e-05
# Current error: 0.00704386287569
# Finished refinement
# Refined  8  times
# Curent number of function evaluations 967312
# max surplus error: 2.65345161848e-08 total surplus error: 2.57968451703e-06
# combiintegral: 7.77275162207e-05
# Current error: 0.00622212282412
# Finished refinement
# Refined  6  times
# Curent number of function evaluations 968122
# max surplus error: 1.3257998946e-08 total surplus error: 2.40630026812e-06
# combiintegral: 7.78714528717e-05
# Current error: 0.00438183425704
# Finished refinement
# Refined  24  times
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Rebalancing!
# Curent number of function evaluations 1001323
# max surplus error: 1.31453597218e-08 total surplus error: 2.3668187316e-06
# combiintegral: 7.74921833669e-05
# Current error: 0.0092309489802
# Number of refinements 550
# Number of distinct points used during the refinement 1001323
# Time used (s): 26389.39431476593
# Final error: 0.0092309489802
# Reference solution: 7.82141744205e-05
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# Curent number of function evaluations 1053
# max surplus error: 0.000244140625 total surplus error: 0.00244140625
# combiintegral: -0.00146484375
# Current error: 19.72862254
# Finished refinement
# Refined  10  times
# New lmax: [3, 2, 2, 2, 2]
# New lmax: [3, 3, 2, 2, 2]
# New lmax: [3, 3, 3, 2, 2]
# New lmax: [3, 3, 3, 3, 2]
# New lmax: [3, 3, 3, 3, 3]
# Curent number of function evaluations 2133
# max surplus error: 0.0001220703125 total surplus error: 0.00195782272818
# combiintegral: 0.00146014602182
# Current error: 17.6685601764
# Finished refinement
# Refined  12  times
# New lmax: [4, 3, 3, 3, 3]
# New lmax: [4, 4, 3, 3, 3]
# New lmax: [4, 4, 4, 3, 3]
# New lmax: [4, 4, 4, 4, 3]
# New lmax: [4, 4, 4, 4, 4]
# Curent number of function evaluations 3843
# max surplus error: 0.000134551400757 total surplus error: 0.00165935488941
# combiintegral: 0.000226482475192
# Current error: 1.89567046983
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 4113
# max surplus error: 0.000114422911599 total surplus error: 0.00152916115663
# combiintegral: -5.28247347518e-05
# Current error: 1.67538569758
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 4383
# max surplus error: 9.58627133845e-05 total surplus error: 0.0013611358463
# combiintegral: -0.000254049767462
# Current error: 4.24812950267
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 4653
# max surplus error: 7.86865270697e-05 total surplus error: 0.00119991133398
# combiintegral: -0.000385308178361
# Current error: 5.92632161902
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 4923
# max surplus error: 4.10044354746e-05 total surplus error: 0.00108362400313
# combiintegral: -0.000454030337236
# Current error: 6.80496234346
# Finished refinement
# Refined  4  times
# New lmax: [4, 4, 4, 5, 4]
# New lmax: [4, 4, 4, 5, 5]
# Curent number of function evaluations 7098
# max surplus error: 2.92913060041e-05 total surplus error: 0.000575236253739
# combiintegral: 0.000466055579357
# Current error: 4.95870995008
# Finished refinement
# Refined  2  times
# New lmax: [5, 4, 4, 5, 5]
# Curent number of function evaluations 7368
# max surplus error: 2.07339048433e-05 total surplus error: 0.000502041513175
# combiintegral: 0.000226058642135
# Current error: 1.89025159199
# Finished refinement
# Refined  2  times
# New lmax: [5, 5, 4, 5, 5]
# Curent number of function evaluations 7638
# max surplus error: 1.51248920282e-05 total surplus error: 0.000447453936319
# combiintegral: 3.84817878381e-05
# Current error: 0.507994706545
# Finished refinement
# Refined  4  times
# New lmax: [5, 5, 4, 6, 5]
# New lmax: [5, 5, 4, 6, 6]
# Curent number of function evaluations 10150
# max surplus error: 1.83575000491e-05 total surplus error: 0.000302297539864
# combiintegral: 8.41909065108e-05
# Current error: 0.0764149482433
# Finished refinement
# Refined  4  times
# New lmax: [5, 5, 5, 6, 6]
# Curent number of function evaluations 10933
# max surplus error: 1.52113416889e-05 total surplus error: 0.000240265194913
# combiintegral: 8.68889703324e-05
# Current error: 0.110910790482
# Finished refinement
# Refined  4  times
# New lmax: [6, 5, 5, 6, 6]
# Curent number of function evaluations 11473
# max surplus error: 1.27913444968e-05 total surplus error: 0.000195718702571
# combiintegral: 0.000198641418897
# Current error: 1.53971125271
# Finished refinement
# Refined  4  times
# New lmax: [6, 6, 5, 6, 6]
# New lmax: [6, 6, 6, 6, 6]
# Curent number of function evaluations 12013
# max surplus error: 8.35741717661e-06 total surplus error: 0.000161921877846
# combiintegral: 0.000313729807281
# Current error: 3.01116306099
# Finished refinement
# Refined  2  times
# New lmax: [7, 6, 6, 6, 6]
# Curent number of function evaluations 15927
# max surplus error: 1.66911554587e-05 total surplus error: 0.000212908414519
# combiintegral: -0.000202415263562
# Current error: 3.58796139015
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 16197
# max surplus error: 8.21287776716e-06 total surplus error: 0.000177156901488
# combiintegral: -0.000139362247215
# Current error: 2.7818029564
# Finished refinement
# Refined  6  times
# New lmax: [7, 7, 6, 6, 6]
# New lmax: [7, 7, 7, 6, 6]
# New lmax: [7, 7, 7, 7, 6]
# Curent number of function evaluations 17007
# max surplus error: 6.56572771049e-06 total surplus error: 0.000149276006093
# combiintegral: -8.58804640523e-06
# Current error: 1.10980166279
# Finished refinement
# Refined  4  times
# New lmax: [7, 7, 7, 7, 7]
# Curent number of function evaluations 18072
# max surplus error: 4.22042519467e-06 total surplus error: 0.000129687820012
# combiintegral: 2.71359457975e-05
# Current error: 0.653055907084
# Finished refinement
# Refined  4  times
# New lmax: [8, 7, 7, 7, 7]
# Curent number of function evaluations 25105
# max surplus error: 8.11348893658e-06 total surplus error: 9.49054156997e-05
# combiintegral: 6.00627522696e-05
# Current error: 0.232073307498
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 25375
# max surplus error: 2.94494537481e-06 total surplus error: 7.87632406346e-05
# combiintegral: 4.1383301916e-05
# Current error: 0.470897670114
# Finished refinement
# Refined  2  times
# New lmax: [8, 8, 7, 7, 7]
# Curent number of function evaluations 25645
# max surplus error: 2.24239977299e-06 total surplus error: 7.2769452576e-05
# combiintegral: 2.61408958852e-05
# Current error: 0.665778024523
# Finished refinement
# Refined  4  times
# New lmax: [9, 8, 7, 7, 7]
# New lmax: [9, 8, 8, 7, 7]
# Curent number of function evaluations 34679
# max surplus error: 3.91228623047e-06 total surplus error: 5.39417020581e-05
# combiintegral: 0.000155727963605
# Current error: 0.991045290179
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 34949
# max surplus error: 1.9068327749e-06 total surplus error: 4.62710278739e-05
# combiintegral: 0.000140148630835
# Current error: 0.791857190504
# Finished refinement
# Refined  2  times
# New lmax: [9, 8, 8, 8, 7]
# Curent number of function evaluations 35408
# max surplus error: 2.52546641436e-06 total surplus error: 4.75805762264e-05
# combiintegral: 0.000140148630835
# Current error: 0.791857190504
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 35867
# max surplus error: 1.63117065521e-06 total surplus error: 4.50532980207e-05
# combiintegral: 0.000143139610598
# Current error: 0.830098082077
# Finished refinement
# Refined  2  times
# New lmax: [9, 8, 8, 8, 8]
# Curent number of function evaluations 36299
# max surplus error: 1.98210719241e-06 total surplus error: 4.61232346058e-05
# combiintegral: 0.000143139610598
# Current error: 0.830098082077
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 36731
# max surplus error: 1.37060357034e-06 total surplus error: 4.39783951146e-05
# combiintegral: 0.000145776780132
# Current error: 0.863815366109
# Finished refinement
# Refined  6  times
# New lmax: [9, 9, 8, 8, 8]
# Curent number of function evaluations 38652
# max surplus error: 1.19080575914e-06 total surplus error: 3.87697613803e-05
# combiintegral: 0.000135907972032
# Current error: 0.737638644647
# Finished refinement
# Refined  6  times
# New lmax: [10, 9, 8, 8, 8]
# New lmax: [10, 10, 8, 8, 8]
# New lmax: [10, 10, 8, 9, 8]
# Curent number of function evaluations 49667
# max surplus error: 2.04543539095e-06 total surplus error: 3.31496583712e-05
# combiintegral: 7.45541308264e-05
# Current error: 0.0467951445027
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 49937
# max surplus error: 1.74059092781e-06 total surplus error: 2.91280128764e-05
# combiintegral: 7.92426072157e-05
# Current error: 0.0131489311594
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 50207
# max surplus error: 1.31136632902e-06 total surplus error: 2.5653211604e-05
# combiintegral: 8.30842070985e-05
# Current error: 0.0622653465831
# Finished refinement
# Refined  2  times
# New lmax: [10, 10, 9, 9, 8]
# Curent number of function evaluations 50666
# max surplus error: 9.25182624724e-07 total surplus error: 2.32629062437e-05
# combiintegral: 8.05773338671e-05
# Current error: 0.0302139537246
# Finished refinement
# Refined  4  times
# New lmax: [10, 10, 9, 9, 9]
# Curent number of function evaluations 53095
# max surplus error: 7.64013857448e-07 total surplus error: 1.9921258016e-05
# combiintegral: 8.0002767725e-05
# Current error: 0.0228678921405
# Finished refinement
# Refined  2  times
# New lmax: [10, 10, 10, 9, 9]
# Curent number of function evaluations 53365
# max surplus error: 6.33052423774e-07 total surplus error: 1.89320194764e-05
# combiintegral: 8.31504618659e-05
# Current error: 0.0631124407041
# Finished refinement
# Refined  2  times
# New lmax: [10, 10, 10, 10, 9]
# Curent number of function evaluations 53635
# max surplus error: 5.64141781195e-07 total surplus error: 1.80095873413e-05
# combiintegral: 8.58864760207e-05
# Current error: 0.098093493373
# Finished refinement
# Refined  4  times
# New lmax: [11, 10, 10, 10, 9]
# New lmax: [11, 10, 10, 10, 10]
# Curent number of function evaluations 68637
# max surplus error: 1.03255325483e-06 total surplus error: 1.41889909541e-05
# combiintegral: 4.11107378198e-05
# Current error: 0.474382512833
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 68907
# max surplus error: 5.04302156807e-07 total surplus error: 1.2273871165e-05
# combiintegral: 4.50170385655e-05
# Current error: 0.424438870589
# Finished refinement
# Refined  2  times
# New lmax: [11, 11, 10, 10, 10]
# Curent number of function evaluations 69177
# max surplus error: 4.06628684641e-07 total surplus error: 1.1829826759e-05
# combiintegral: 4.82168656445e-05
# Current error: 0.383527781227
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 72953
# max surplus error: 6.2130369671e-07 total surplus error: 1.19861155525e-05
# combiintegral: 4.94129089876e-05
# Current error: 0.368235881108
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 75667
# max surplus error: 3.57381126936e-07 total surplus error: 1.09063688994e-05
# combiintegral: 5.01353392509e-05
# Current error: 0.358999316654
# Finished refinement
# Refined  2  times
# New lmax: [11, 11, 11, 10, 10]
# Curent number of function evaluations 75937
# max surplus error: 2.77197125519e-07 total surplus error: 1.04535272146e-05
# combiintegral: 5.27568818667e-05
# Current error: 0.325481829124
# Finished refinement
# Refined  8  times
# New lmax: [12, 11, 11, 10, 10]
# New lmax: [12, 11, 11, 11, 10]
# Curent number of function evaluations 105527
# max surplus error: 4.9776384419e-07 total surplus error: 9.9599699289e-06
# combiintegral: 7.78750030023e-05
# Current error: 0.00433644439453
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 105797
# max surplus error: 3.742197432e-07 total surplus error: 8.97644063288e-06
# combiintegral: 7.67040283197e-05
# Current error: 0.0193078315032
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 108836
# max surplus error: 2.32445798206e-07 total surplus error: 8.41178654292e-06
# combiintegral: 7.71889604173e-05
# Current error: 0.0131077775972
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 112064
# max surplus error: 2.04821124716e-07 total surplus error: 8.15715433191e-06
# combiintegral: 7.74259548892e-05
# Current error: 0.0100777069781
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 115292
# max surplus error: 1.76779533934e-07 total surplus error: 7.88440196877e-06
# combiintegral: 7.771182479e-05
# Current error: 0.00642274414108
# Finished refinement
# Refined  8  times
# New lmax: [12, 12, 11, 11, 10]
# New lmax: [12, 12, 11, 11, 11]
# Curent number of function evaluations 119455
# max surplus error: 1.41444016284e-07 total surplus error: 7.07519516518e-06
# combiintegral: 7.74614497221e-05
# Current error: 0.00962389111664
# Finished refinement
# Refined  4  times
# New lmax: [13, 12, 11, 11, 11]
# New lmax: [13, 12, 12, 11, 11]
# Curent number of function evaluations 146844
# max surplus error: 2.49551653743e-07 total surplus error: 4.65674230089e-06
# combiintegral: 8.61406699588e-05
# Current error: 0.101343466156
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 147114
# max surplus error: 1.23543567808e-07 total surplus error: 4.18817764095e-06
# combiintegral: 8.51648098425e-05
# Current error: 0.0888666980561
# Finished refinement
# Refined  2  times
# New lmax: [13, 12, 12, 12, 11]
# Curent number of function evaluations 147546
# max surplus error: 1.04276226205e-07 total surplus error: 4.01784359517e-06
# combiintegral: 8.53540321214e-05
# Current error: 0.0912859817769
# Finished refinement
# Refined  4  times
# New lmax: [13, 12, 12, 12, 12]
# Curent number of function evaluations 154330
# max surplus error: 1.08216788981e-07 total surplus error: 3.77597928937e-06
# combiintegral: 8.55793029672e-05
# Current error: 0.0941661610735
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 159025
# max surplus error: 9.31479072907e-08 total surplus error: 3.63040762731e-06
# combiintegral: 8.57299774651e-05
# Current error: 0.0960925957513
# Finished refinement
# Refined  4  times
# New lmax: [13, 13, 12, 12, 12]
# Curent number of function evaluations 162468
# max surplus error: 8.13477315104e-08 total surplus error: 3.35115721105e-06
# combiintegral: 8.50765672896e-05
# Current error: 0.0877384811626
# Finished refinement
# Refined  2  times
# New lmax: [13, 13, 13, 12, 12]
# Curent number of function evaluations 162738
# max surplus error: 7.04870459371e-08 total surplus error: 3.20243197212e-06
# combiintegral: 8.44226205146e-05
# Current error: 0.0793775059324
# Finished refinement
# Refined  4  times
# New lmax: [14, 13, 13, 12, 12]
# New lmax: [14, 13, 13, 13, 12]
# Curent number of function evaluations 203734
# max surplus error: 1.27894151319e-07 total surplus error: 2.65455385576e-06
# combiintegral: 7.47349381156e-05
# Current error: 0.0444834498443
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 204004
# max surplus error: 5.49315520808e-08 total surplus error: 2.41912244217e-06
# combiintegral: 7.50277533471e-05
# Current error: 0.0407396881323
# Finished refinement
# Refined  6  times
# New lmax: [14, 14, 13, 13, 12]
# New lmax: [14, 14, 13, 13, 13]
# Curent number of function evaluations 208965
# max surplus error: 9.70467189616e-08 total surplus error: 2.29818928434e-06
# combiintegral: 7.52707917326e-05
# Current error: 0.0376323436216
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 213224
# max surplus error: 4.63271478004e-08 total surplus error: 2.09326895222e-06
# combiintegral: 7.53818034344e-05
# Current error: 0.036213013908
# Finished refinement
# Refined  2  times
# New lmax: [14, 14, 14, 13, 13]
# Curent number of function evaluations 213494
# max surplus error: 3.84286495131e-08 total surplus error: 2.03737241625e-06
# combiintegral: 7.56912220437e-05
# Current error: 0.032256971266
# Finished refinement
# Refined  4  times
# New lmax: [14, 14, 14, 14, 13]
# Curent number of function evaluations 217869
# max surplus error: 7.09218372728e-08 total surplus error: 2.00474772763e-06
# combiintegral: 7.59213776501e-05
# Current error: 0.0293143383202
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 221974
# max surplus error: 3.28158994985e-08 total surplus error: 1.8560658945e-06
# combiintegral: 7.60025514828e-05
# Current error: 0.0282764978868
# Finished refinement
# Refined  8  times
# New lmax: [15, 14, 14, 14, 13]
# New lmax: [15, 14, 14, 14, 14]
# Curent number of function evaluations 284214
# max surplus error: 6.35308400878e-08 total surplus error: 1.67083382206e-06
# combiintegral: 7.41712774565e-05
# Current error: 0.0516900803981
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 284484
# max surplus error: 5.43803279337e-08 total surplus error: 1.56035679189e-06
# combiintegral: 7.44152871708e-05
# Current error: 0.0485703170543
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 290685
# max surplus error: 4.63648277214e-08 total surplus error: 1.47129443564e-06
# combiintegral: 7.44828233088e-05
# Current error: 0.0477068400889
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 296616
# max surplus error: 3.18251111418e-08 total surplus error: 1.39406191531e-06
# combiintegral: 7.45370736276e-05
# Current error: 0.04701322772
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 302907
# max surplus error: 4.30175278347e-08 total surplus error: 1.37534830883e-06
# combiintegral: 7.45834953955e-05
# Current error: 0.0464197065553
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 309198
# max surplus error: 2.62094492845e-08 total surplus error: 1.30435066071e-06
# combiintegral: 7.46360981505e-05
# Current error: 0.045747158958
# Finished refinement
# Refined  4  times
# New lmax: [15, 15, 14, 14, 14]
# Curent number of function evaluations 316686
# max surplus error: 2.359382466e-08 total surplus error: 1.22173993627e-06
# combiintegral: 7.48686242845e-05
# Current error: 0.0427742178546
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 336835
# max surplus error: 3.43177264971e-08 total surplus error: 1.22481792322e-06
# combiintegral: 7.50012132134e-05
# Current error: 0.0410790145253
# Finished refinement
# Refined  4  times
# Curent number of function evaluations 350633
# max surplus error: 2.11325010794e-08 total surplus error: 1.11513856447e-06
# combiintegral: 7.50815520371e-05
# Current error: 0.0400518500208
# Finished refinement
# Refined  8  times
# New lmax: [15, 15, 15, 14, 14]
# Curent number of function evaluations 370965
# max surplus error: 2.85941745503e-08 total surplus error: 9.83074491085e-07
# combiintegral: 7.52945158432e-05
# Current error: 0.0373290212292
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 376015
# max surplus error: 1.67966846738e-08 total surplus error: 9.35400101544e-07
# combiintegral: 7.53297354205e-05
# Current error: 0.0368787246224
# Finished refinement
# Refined  6  times
# New lmax: [16, 15, 15, 14, 14]
# New lmax: [16, 15, 15, 15, 14]
# Curent number of function evaluations 491001
# max surplus error: 3.11623970915e-08 total surplus error: 9.27406960248e-07
# combiintegral: 7.86113453067e-05
# Current error: 0.00507799115892
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 491271
# max surplus error: 2.22176298859e-08 total surplus error: 8.67597915557e-07
# combiintegral: 7.85381459669e-05
# Current error: 0.00414210785631
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 498648
# max surplus error: 1.26581454575e-08 total surplus error: 8.30455025713e-07
# combiintegral: 7.85652475398e-05
# Current error: 0.00448861247769
# Finished refinement
# Refined  8  times
# New lmax: [16, 15, 15, 15, 15]
# Curent number of function evaluations 522102
# max surplus error: 1.17798343805e-08 total surplus error: 7.61533642296e-07
# combiintegral: 7.86385168543e-05
# Current error: 0.00542539043478
# Finished refinement
# Refined  4  times
# New lmax: [16, 16, 15, 15, 15]
# Curent number of function evaluations 530046
# max surplus error: 9.28386976483e-09 total surplus error: 7.19311407221e-07
# combiintegral: 7.85946150983e-05
# Current error: 0.00486408864677
# Finished refinement
# Refined  6  times
# New lmax: [17, 16, 15, 15, 15]
# New lmax: [17, 16, 16, 15, 15]
# Curent number of function evaluations 681112
# max surplus error: 1.57437670177e-08 total surplus error: 5.5231033569e-07
# combiintegral: 7.86075760621e-05
# Current error: 0.00502979983486
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 681382
# max surplus error: 1.15751790776e-08 total surplus error: 5.23222167494e-07
# combiintegral: 7.8546576426e-05
# Current error: 0.00424989470201
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 691140
# max surplus error: 8.77126945718e-09 total surplus error: 5.03016952956e-07
# combiintegral: 7.85594435233e-05
# Current error: 0.00441440576866
# Finished refinement
# Refined  6  times
# New lmax: [17, 16, 16, 16, 15]
# Curent number of function evaluations 712198
# max surplus error: 6.4662716322e-09 total surplus error: 4.77535365062e-07
# combiintegral: 7.86274203444e-05
# Current error: 0.00528351704755
# Finished refinement
# Refined  6  times
# New lmax: [17, 17, 16, 16, 15]
# New lmax: [17, 17, 16, 16, 16]
# Curent number of function evaluations 722226
# max surplus error: 9.80339252652e-09 total surplus error: 4.56458643989e-07
# combiintegral: 7.85981191696e-05
# Current error: 0.00490888962162
# Finished refinement
# Refined  2  times
# Curent number of function evaluations 731552
# max surplus error: 5.42129683085e-09 total surplus error: 4.39519057589e-07
# combiintegral: 7.86091186989e-05
# Current error: 0.00504952307357
# Finished refinement
# Refined  8  times
# New lmax: [17, 17, 17, 16, 16]
